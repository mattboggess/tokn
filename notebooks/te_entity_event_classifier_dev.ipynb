# %%
import json
import spacy
import stanfordnlp
import pandas as pd
import warnings
import os
import sys
from spacy_stanfordnlp import StanfordNLPLanguage

# nlp preprocessing pipeline
warnings.filterwarnings('ignore')
snlp = stanfordnlp.Pipeline(lang="en")
nlp = StanfordNLPLanguage(snlp)

module_path = os.path.abspath(os.path.join('../data_processing'))
if module_path not in sys.path:
    sys.path.append(module_path)
from data_processing_utils import read_spacy_docs, write_spacy_docs 

with open("../data/preprocessed_data/Life_Biology_kb_lexicon.json", "r") as f:
    lexicon = json.load(f)
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_tagger.pt', 'pretrain_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_lemmatizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_parser.pt', 'pretrain_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Done loading processors!
# ---

# %%
texts = []
labels = []
for concept in lexicon:
    class_label = lexicon[concept]["class_label"]
    for tr in lexicon[concept]["text_representations"]:
        if tr not in texts:
            texts.append(tr)
            labels.append(class_label)

# %%
spacy_texts = [nlp(text) for text in texts]
print(len(spacy_texts))
#write_spacy_docs(spacy_texts, "../data/term_extraction/summary/lexicon_entries_spacy")
# Out:
# 9167

# %%
#spacy_texts = read_spacy_docs("../data/term_extraction/summary/lexicon_entries_spacy", nlp)

# %%
def determine_term_type(term):
    """ Categorizes a term as either entity or event based on several derived rules.

    Parameters
    ----------
    term: spacy.tokens.doc.Doc
        Spacy preprocessed representation of the term 

    Returns
    -------
    str ('entity' | 'event')
        The class of the term
    """
    
    NOMINALS = ["ation", "ition", "ption", "ing", "sis", "lism", "ment", "sion"]
    EVENT_KEYWORDS = ["process", "cycle"]
    
    # key words that indicate events despite being nouns 
    if any([ek in term.text.lower() for ek in EVENT_KEYWORDS]):
        term_type = "event"
    # key endings indicating a nominalized form of an event 
    elif any([term[i].text.endswith(ne) for ne in NOMINALS for i in range(len(term))]):
        term_type = "event"
    # POS = Verb implies event 
    elif any([t.pos_ == "VERB" for t in term]):
        term_type = "event"
    # default is otherwise entity 
    else:
        term_type = "entity"
    
    return term_type

# %%
errors = []
correct = []
for term, label in zip(spacy_texts, labels):
    pred = determine_term_type(term)
    
    if pred == label.lower():
        correct.append(term)
    else:
        print(term)
        print([t.pos_ for t in term])
        print(label)
        print(pred)
        print()
        
        #if label == "Event":
            #print(term)
            #print(" ".join([t.pos_ for t in term]))
        errors.append(term)
# Out:
# acquired immune deficiency syndrome
# ['VERB', 'ADJ', 'NOUN', 'NOUN']
# Entity
# event
#
# ATP hydrolyzing transport protein
# ['PROPN', 'NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# atp hydrolyzing transport protein
# ['NOUN', 'NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# start codon
# ['VERB', 'NOUN']
# Entity
# event
#
# abnormal cloned embryo
# ['ADJ', 'VERB', 'NOUN']
# Entity
# event
#
# abortion
# ['NOUN']
# Event
# entity
#
# abrade
# ['PROPN']
# Event
# entity
#
# absorption spectrum
# ['NOUN', 'NOUN']
# Entity
# event
#
# accessory pigment
# ['NOUN', 'NOUN']
# Entity
# event
#
# acid-rain
# ['NOUN', 'PUNCT', 'NOUN']
# Event
# entity
#
# fall
# ['NOUN']
# Event
# entity
#
# acid reflux
# ['NOUN', 'NOUN']
# Event
# entity
#
# acrosomal reaction
# ['ADJ', 'NOUN']
# Event
# entity
#
# action potential
# ['NOUN', 'NOUN']
# Event
# entity
#
# energy-of-activation
# ['NOUN', 'PUNCT', 'ADP', 'PUNCT', 'NOUN']
# Entity
# event
#
# activation energy
# ['NOUN', 'NOUN']
# Entity
# event
#
# free-energy-of-activation
# ['ADJ', 'PUNCT', 'NOUN', 'PUNCT', 'ADP', 'PUNCT', 'NOUN']
# Entity
# event
#
# transport
# ['NOUN']
# Event
# entity
#
# move
# ['NOUN']
# Event
# entity
#
# active transport
# ['ADJ', 'NOUN']
# Event
# entity
#
# active transport by proton pump
# ['ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN']
# Event
# entity
#
# active transport by sodium potassium pump
# ['ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# primary active transport
# ['ADJ', 'ADJ', 'NOUN']
# Event
# entity
#
# adaptive immunity
# ['ADJ', 'NOUN']
# Event
# entity
#
# specific-immunity
# ['NOUN']
# Event
# entity
#
# specific immunity
# ['ADJ', 'NOUN']
# Event
# entity
#
# adulthood
# ['NOUN']
# Event
# entity
#
# aerobic
# ['NOUN']
# Event
# entity
#
# human-african-trypanosomiasis
# ['ADJ']
# Entity
# event
#
# African sleeping sickness
# ['ADJ', 'NOUN', 'NOUN']
# Entity
# event
#
# congo-trypanosomiasis
# ['NOUN']
# Entity
# event
#
# african sleeping sickness
# ['ADJ', 'NOUN', 'NOUN']
# Entity
# event
#
# age structure
# ['NOUN', 'NOUN']
# Event
# entity
#
# conglomeration
# ['NOUN']
# Entity
# event
#
# whole_thing
# ['NOUN']
# Entity
# event
#
# grouping
# ['NOUN']
# Entity
# event
#
# agonistic behavior
# ['ADJ', 'NOUN']
# Event
# entity
#
# red-tide
# ['ADJ', 'PUNCT', 'NOUN']
# Event
# entity
#
# algal-bloom
# ['NOUN', 'PUNCT', 'NOUN']
# Event
# entity
#
# harmful-algal-bloom
# ['ADV']
# Event
# entity
#
# algae bloom
# ['NOUN', 'NOUN']
# Event
# entity
#
# hab
# ['INTJ']
# Event
# entity
#
# allee effect
# ['PROPN', 'NOUN']
# Event
# entity
#
# allergy
# ['NOUN']
# Event
# entity
#
# allosteric-reaction
# ['ADJ']
# Event
# entity
#
# alternating generation organ
# ['VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# splice
# ['NOUN']
# Event
# entity
#
# altruism
# ['NOUN']
# Event
# entity
#
# Alu element
# ['NOUN', 'NOUN']
# Entity
# event
#
# alu element
# ['NOUN', 'NOUN']
# Entity
# event
#
# activated-amino-acid
# ['VERB', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# ammonifying bacterium
# ['NOUN', 'NOUN']
# Entity
# event
#
# anabolic reactions
# ['ADJ', 'NOUN']
# Event
# entity
#
# biosynthetic-pathway
# ['NOUN', 'PUNCT', 'NOUN']
# Event
# entity
#
# anabolic pathway
# ['ADJ', 'NOUN']
# Event
# entity
#
# anabolic-pathway
# ['ADJ']
# Event
# entity
#
# phyletic-evolution
# ['ADJ']
# Event
# entity
#
# anaphase
# ['PROPN']
# Event
# entity
#
# anaphase-I
# ['NOUN', 'PUNCT', 'NUM']
# Event
# entity
#
# anaphase i
# ['NOUN', 'X']
# Event
# entity
#
# anaphase-II
# ['PROPN', 'PUNCT', 'NUM']
# Event
# entity
#
# anaphase ii
# ['PROPN', 'NUM']
# Event
# entity
#
# anaphase-promoting complex
# ['NOUN', 'PUNCT', 'NOUN', 'NOUN']
# Entity
# event
#
# anaphase promoting complex
# ['NOUN', 'VERB', 'NOUN']
# Entity
# event
#
# anatomical-terms-of-location
# ['ADJ', 'PUNCT', 'NOUN']
# Entity
# event
#
# anatomy
# ['NOUN']
# Event
# entity
#
# anchor
# ['NOUN']
# Event
# entity
#
# Anchorage dependence
# ['PROPN', 'NOUN']
# Event
# entity
#
# anchorage dependence
# ['PROPN', 'NOUN']
# Event
# entity
#
# flowering-plant
# ['NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# animate_being
# ['NOUN']
# Entity
# event
#
# animal cell growth
# ['NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# cell growth in animals
# ['NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# animal development cell
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# animal growth
# ['NOUN', 'NOUN']
# Event
# entity
#
# animal husbandry
# ['NOUN', 'NOUN']
# Event
# entity
#
# animal nutritional requirement
# ['NOUN', 'ADJ', 'NOUN']
# Entity
# event
#
# culture
# ['NOUN']
# Event
# entity
#
# animal transcription factor gene
# ['NOUN', 'NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# animal transport
# ['NOUN', 'NOUN']
# Event
# entity
#
# anneal
# ['NOUN']
# Event
# entity
#
# segmented-worm
# ['VERB', 'PUNCT', 'NOUN']
# Entity
# event
#
# sucking-louse
# ['VERB', 'PUNCT', 'NOUN']
# Entity
# event
#
# antennae pigment
# ['ADJ', 'NOUN']
# Entity
# event
#
# antenna pigment
# ['NOUN', 'NOUN']
# Entity
# event
#
# adenohypophysis
# ['NOUN']
# Entity
# event
#
# antibiotic resistance
# ['ADJ', 'NOUN']
# Event
# entity
#
# be resistant
# ['AUX', 'ADJ']
# Event
# entity
#
# antigen-binding site
# ['NOUN', 'PUNCT', 'NOUN', 'NOUN']
# Entity
# event
#
# antigen binding site
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# present
# ['ADJ']
# Event
# entity
#
# antigen-presenting cell
# ['NOUN', 'PUNCT', 'VERB', 'NOUN']
# Entity
# event
#
# antigen presenting cell
# ['NOUN', 'VERB', 'NOUN']
# Entity
# event
#
# anti parallel arrangement
# ['ADJ', 'ADJ', 'NOUN']
# Entity
# event
#
# antiparallel arrangement
# ['ADJ', 'NOUN']
# Entity
# event
#
# apical dominance
# ['ADJ', 'NOUN']
# Event
# entity
#
# apomixis
# ['PROPN']
# Event
# entity
#
# apoplastic transport
# ['ADJ', 'NOUN']
# Event
# entity
#
# Arabidopsis
# ['NOUN']
# Entity
# event
#
# arabidopsis
# ['NOUN']
# Entity
# event
#
# Arabidopsis thaliana
# ['NOUN', 'NOUN']
# Entity
# event
#
# arabidopsis thaliana
# ['NOUN', 'NOUN']
# Entity
# event
#
# hardening-of-the-arteries
# ['VERB', 'PUNCT', 'ADP', 'PUNCT', 'DET', 'PUNCT', 'NOUN']
# Entity
# event
#
# arteriosclerosis
# ['NOUN']
# Entity
# event
#
# jointed-appendage
# ['VERB', 'PUNCT', 'NOUN']
# Entity
# event
#
# artificial selection
# ['ADJ', 'NOUN']
# Event
# entity
#
# artificial selection with antibiotics
# ['ADJ', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# selection with antibiotics
# ['NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# selection against untransformed cells
# ['NOUN', 'ADP', 'ADJ', 'NOUN']
# Event
# entity
#
# ascent of xylem sap
# ['NOUN', 'ADP', 'PROPN', 'PROPN', 'PROPN']
# Event
# entity
#
# asexual reproduction
# ['ADJ', 'NOUN']
# Event
# entity
#
# asymmetrical distribution
# ['ADJ', 'NOUN']
# Event
# entity
#
# atherosclerosis
# ['NOUN']
# Entity
# event
#
# attack
# ['NOUN']
# Event
# entity
#
# affinity for
# ['NOUN', 'ADP']
# Event
# entity
#
# electrical-attraction
# ['ADJ']
# Event
# entity
#
# Australopithecus afarensis
# ['PROPN', 'NOUN']
# Entity
# event
#
# australopithecus afarensis
# ['NOUN', 'NOUN']
# Entity
# event
#
# signal
# ['NOUN']
# Event
# entity
#
# digest
# ['NOUN']
# Event
# entity
#
# autodigestion
# ['ADJ']
# Event
# entity
#
# autoionize
# ['PROPN']
# Event
# entity
#
# autophagy
# ['NOUN']
# Event
# entity
#
# self digestion
# ['PRON', 'NOUN']
# Event
# entity
#
# autoradiography
# ['NOUN']
# Event
# entity
#
# autoreplicate
# ['PROPN']
# Event
# entity
#
# form
# ['NOUN']
# Event
# entity
#
# bacterial infection
# ['ADJ', 'NOUN']
# Event
# entity
#
# bacterial infection in human
# ['ADJ', 'NOUN', 'ADP', 'ADJ']
# Event
# entity
#
# human bacterial infection
# ['ADJ', 'ADJ', 'NOUN']
# Event
# entity
#
# artificial version of bacterial chromosome
# ['ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN']
# Entity
# event
#
# inactivated x chromosome
# ['VERB', 'PROPN', 'NOUN']
# Entity
# event
#
# substitute
# ['NOUN']
# Event
# entity
#
# base pair substitution
# ['NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# pair
# ['NOUN']
# Event
# entity
#
# basement membrane
# ['NOUN', 'NOUN']
# Entity
# event
#
# cation amino acid
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# positively charged amino-acid
# ['ADV', 'VERB', 'NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# batesian mimicry
# ['ADJ', 'NOUN']
# Event
# entity
#
# behavior
# ['NOUN']
# Event
# entity
#
# behavioral ecology
# ['ADJ', 'NOUN']
# Event
# entity
#
# Be
# ['VERB']
# Entity
# event
#
# beta pleated sheet
# ['PROPN', 'VERB', 'NOUN']
# Entity
# event
#
# beta-pleated-sheet
# ['NOUN', 'PUNCT', 'VERB', 'PUNCT', 'NOUN']
# Entity
# event
#
# bicoid protein hypothesis
# ['ADJ', 'NOUN', 'NOUN']
# Entity
# event
#
# binding site
# ['NOUN', 'NOUN']
# Entity
# event
#
# scientific-name
# ['ADJ', 'PUNCT', 'NOUN']
# Event
# entity
#
# binomial nomenclature
# ['ADJ', 'NOUN']
# Event
# entity
#
# biochemical change
# ['ADJ', 'NOUN']
# Event
# entity
#
# biodiesel production
# ['NOUN', 'NOUN']
# Event
# entity
#
# bioenergetics
# ['NOUN']
# Event
# entity
#
# bioethanol production
# ['NOUN', 'NOUN']
# Event
# entity
#
# biofuel production
# ['NOUN', 'NOUN']
# Event
# entity
#
# biogeography
# ['NOUN']
# Event
# entity
#
# bioinformatics
# ['NOUN']
# Event
# entity
#
# biological clock
# ['ADJ', 'NOUN']
# Event
# entity
#
# biology
# ['NOUN']
# Event
# entity
#
# bioluminescence
# ['NOUN']
# Event
# entity
#
# biomembrane containing double lipid bilayer
# ['NOUN', 'VERB', 'ADJ', 'NOUN', 'NOUN']
# Entity
# event
#
# biophilia
# ['NOUN']
# Event
# entity
#
# biotechnology
# ['NOUN']
# Event
# entity
#
# bioterrorism
# ['NOUN']
# Event
# entity
#
# birth control
# ['NOUN', 'NOUN']
# Event
# entity
#
# birth control pill
# ['NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# blot
# ['NOUN']
# Event
# entity
#
# blunt cut
# ['ADJ', 'NOUN']
# Event
# entity
#
# blunt end fragment
# ['ADJ', 'NOUN', 'NOUN']
# Entity
# event
#
# segment of body
# ['NOUN', 'ADP', 'NOUN']
# Entity
# event
#
# body segment
# ['NOUN', 'NOUN']
# Entity
# event
#
# body segment pair
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# Bohr shift
# ['PROPN', 'NOUN']
# Event
# entity
#
# bohr shift
# ['PROPN', 'NOUN']
# Event
# entity
#
# book lung
# ['VERB', 'NOUN']
# Entity
# event
#
# botany
# ['NOUN']
# Event
# entity
#
# bottleneck effect
# ['NOUN', 'NOUN']
# Event
# entity
#
# branch point
# ['NOUN', 'NOUN']
# Event
# entity
#
# dichotomy
# ['NOUN']
# Event
# entity
#
# breathing control center
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# bronsted lowry acid
# ['VERB', 'PROPN', 'NOUN']
# Entity
# event
#
# brown-headed cowbird
# ['ADJ', 'PUNCT', 'VERB', 'NOUN']
# Entity
# event
#
# brown headed cowbird
# ['ADJ', 'VERB', 'NOUN']
# Entity
# event
#
# buffered solution
# ['VERB', 'NOUN']
# Entity
# event
#
# bulk flow
# ['NOUN', 'NOUN']
# Event
# entity
#
# bulk transport
# ['NOUN', 'NOUN']
# Event
# entity
#
# c4 pathway
# ['PROPN', 'NUM', 'NOUN']
# Event
# entity
#
# CAMP receptor protein with cyclic AMP
# ['NOUN', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN']
# Event
# entity
#
# camp receptor protein with cyclic amp
# ['NOUN', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN']
# Event
# entity
#
# methylamonia cation
# ['ADJ', 'NOUN']
# Entity
# event
#
# dark reaction
# ['ADJ', 'NOUN']
# Event
# entity
#
# dark-reaction
# ['ADJ', 'PUNCT', 'NOUN']
# Event
# entity
#
# light-independent-reaction
# ['NOUN', 'PUNCT', 'ADJ', 'PUNCT', 'NOUN']
# Event
# entity
#
# unregulated cell growth
# ['VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# unrestricted cell division
# ['VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# capillary action
# ['ADJ', 'NOUN']
# Event
# entity
#
# capillary exchange
# ['ADJ', 'NOUN']
# Event
# entity
#
# cascade
# ['NOUN']
# Event
# entity
#
# catabolic reactions
# ['NOUN', 'NOUN']
# Event
# entity
#
# breakdown-pathway
# ['ADJ', 'NOUN']
# Event
# entity
#
# catabolic pathway
# ['NOUN', 'NOUN']
# Event
# entity
#
# catabolize
# ['PROPN']
# Event
# entity
#
# catastrophism
# ['NOUN']
# Event
# entity
#
# cation
# ['NOUN']
# Entity
# event
#
# cell adhesion molecule
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# cell reproduction
# ['NOUN', 'NOUN']
# Event
# entity
#
# elongate
# ['ADJ']
# Event
# entity
#
# cell fate
# ['NOUN', 'NOUN']
# Event
# entity
#
# fractionate
# ['PROPN']
# Event
# entity
#
# cell growth
# ['NOUN', 'NOUN']
# Event
# entity
#
# cell plate growth
# ['NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# cell shape change
# ['NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# signal transduction with g-protein
# ['NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# cell survival
# ['NOUN', 'NOUN']
# Event
# entity
#
# building material of cell wall
# ['NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN']
# Entity
# event
#
# clone
# ['NOUN']
# Event
# entity
#
# cell motility
# ['NOUN', 'NOUN']
# Event
# entity
#
# cellular potency
# ['ADJ', 'NOUN']
# Event
# entity
#
# cellular activity
# ['ADJ', 'NOUN']
# Event
# entity
#
# cellular response
# ['ADJ', 'NOUN']
# Event
# entity
#
# response
# ['NOUN']
# Event
# entity
#
# cellular transport
# ['ADJ', 'NOUN']
# Event
# entity
#
# cellular work
# ['ADJ', 'NOUN']
# Event
# entity
#
# cellulose-digesting bacterium
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# cellulose digesting bacteria
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# cellulose digesting fungus
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# cellulose digestion
# ['NOUN', 'NOUN']
# Event
# entity
#
# central dogma
# ['ADJ', 'NOUN']
# Event
# entity
#
# microtubule organising centre
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# microtubule organizing center
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# microtubule organising center
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# microtubule organizing centre
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# cervical cap
# ['ADJ', 'NOUN']
# Event
# entity
#
# change
# ['NOUN']
# Event
# entity
#
# change of [h+]
# ['NOUN', 'ADP', 'PUNCT', 'NOUN']
# Event
# entity
#
# change of [oh-]
# ['NOUN', 'ADP', 'PUNCT', 'INTJ', 'SYM']
# Event
# entity
#
# change of shape
# ['NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# change of state
# ['NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# dna sequence change
# ['NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# checkpoint
# ['NOUN']
# Event
# entity
#
# chemical digestion
# ['ADJ', 'NOUN']
# Event
# entity
#
# chemical digestion in mouth
# ['ADJ', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# chemical digestion in small intestine
# ['ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN']
# Event
# entity
#
# chemical digestion in stomach
# ['ADJ', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# chemical ecology
# ['ADJ', 'NOUN']
# Event
# entity
#
# element
# ['NOUN']
# Entity
# event
#
# chemical element
# ['ADJ', 'NOUN']
# Entity
# event
#
# chemical equilibrium
# ['ADJ', 'NOUN']
# Event
# entity
#
# chemical equilibrium reaction
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# chemical reaction
# ['ADJ', 'NOUN']
# Event
# entity
#
# chemical reaction between methane and oxygen
# ['ADJ', 'NOUN', 'ADP', 'NOUN', 'CCONJ', 'NOUN']
# Event
# entity
#
# chemical representation
# ['ADJ', 'NOUN']
# Entity
# event
#
# chemical stability
# ['ADJ', 'NOUN']
# Event
# entity
#
# chemical work
# ['ADJ', 'NOUN']
# Event
# entity
#
# chemotaxis
# ['NOUN']
# Event
# entity
#
# chemotherapy
# ['NOUN']
# Event
# entity
#
# childbirth
# ['NOUN']
# Event
# entity
#
# cvs
# ['PROPN']
# Event
# entity
#
# pack
# ['NOUN']
# Event
# entity
#
# chromosomal arrangement
# ['ADJ', 'NOUN']
# Entity
# event
#
# chromosome-aberration
# ['ADJ']
# Entity
# event
#
# chromosomal inheritance
# ['ADJ', 'NOUN']
# Event
# entity
#
# chromosome fragment
# ['NOUN', 'NOUN']
# Entity
# event
#
# circadian rhythm
# ['NOUN', 'NOUN']
# Event
# entity
#
# cladistics
# ['NOUN']
# Event
# entity
#
# class as classification
# ['NOUN', 'ADP', 'NOUN']
# Entity
# event
#
# class i mhc molecule
# ['NOUN', 'PRON', 'VERB', 'NOUN']
# Entity
# event
#
# classification unit
# ['NOUN', 'NOUN']
# Entity
# event
#
# clawed lobster
# ['VERB', 'NOUN']
# Entity
# event
#
# cleavage
# ['NOUN']
# Event
# entity
#
# climate
# ['NOUN']
# Event
# entity
#
# climate change
# ['NOUN', 'NOUN']
# Event
# entity
#
# clonal selection
# ['ADJ', 'NOUN']
# Event
# entity
#
# cloned dna
# ['VERB', 'NOUN']
# Entity
# event
#
# cloned embryo
# ['VERB', 'NOUN']
# Entity
# event
#
# cloned gene
# ['VERB', 'NOUN']
# Entity
# event
#
# cloning vector
# ['NOUN', 'NOUN']
# Entity
# event
#
# bacteriophage cloning vector
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# cloning phage
# ['NOUN', 'NOUN']
# Entity
# event
#
# cloning plasmid
# ['NOUN', 'NOUN']
# Entity
# event
#
# cloning bacterial plasmid
# ['VERB', 'ADJ', 'NOUN']
# Entity
# event
#
# bacterial plasmid for cloning
# ['ADJ', 'NOUN', 'ADP', 'NOUN']
# Entity
# event
#
# closed circulatory system
# ['VERB', 'ADJ', 'NOUN']
# Entity
# event
#
# closed system
# ['VERB', 'NOUN']
# Entity
# event
#
# close
# ['ADJ']
# Event
# entity
#
# clot
# ['NOUN']
# Event
# entity
#
# clotting protein
# ['NOUN', 'NOUN']
# Entity
# event
#
# blood clotting protein
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# clotting agent
# ['NOUN', 'NOUN']
# Entity
# event
#
# blood clotting factor
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# clotting factor
# ['NOUN', 'NOUN']
# Entity
# event
#
# clump
# ['NOUN']
# Event
# entity
#
# coated pit
# ['VERB', 'NOUN']
# Entity
# event
#
# coated vesicle
# ['VERB', 'NOUN']
# Entity
# event
#
# code for
# ['NOUN', 'ADP']
# Event
# entity
#
# code
# ['NOUN']
# Event
# entity
#
# coding segment
# ['NOUN', 'NOUN']
# Entity
# event
#
# codominate
# ['PROPN']
# Event
# entity
#
# codominance
# ['PROPN']
# Event
# entity
#
# cognitive activity
# ['ADJ', 'NOUN']
# Event
# entity
#
# coil
# ['NOUN']
# Event
# entity
#
# wrap
# ['NOUN']
# Event
# entity
#
# coitus
# ['NOUN']
# Event
# entity
#
# cold
# ['ADJ']
# Event
# entity
#
# collecting duct
# ['VERB', 'NOUN']
# Entity
# event
#
# coloring pigments
# ['NOUN', 'NOUN']
# Entity
# event
#
# coloring pigment
# ['NOUN', 'NOUN']
# Entity
# event
#
# combustion of fossil fuel
# ['NOUN', 'ADP', 'NOUN', 'NOUN']
# Event
# entity
#
# combustion reaction
# ['NOUN', 'NOUN']
# Event
# entity
#
# committed cell
# ['VERB', 'NOUN']
# Entity
# event
#
# community ecology
# ['NOUN', 'NOUN']
# Event
# entity
#
# compaction
# ['NOUN']
# Event
# entity
#
# complement system
# ['VERB', 'NOUN']
# Entity
# event
#
# complete dominance
# ['ADJ', 'NOUN']
# Event
# entity
#
# completed valence shell
# ['VERB', 'ADJ', 'NOUN']
# Entity
# event
#
# closed shell
# ['VERB', 'NOUN']
# Entity
# event
#
# filled outer shell
# ['VERB', 'ADJ', 'NOUN']
# Entity
# event
#
# concentration gradient
# ['NOUN', 'NOUN']
# Entity
# event
#
# condensed chromosome
# ['VERB', 'NOUN']
# Entity
# event
#
# condensed diploid chromosome
# ['VERB', 'ADJ', 'NOUN']
# Entity
# event
#
# condom
# ['NOUN']
# Event
# entity
#
# conduction
# ['NOUN']
# Event
# entity
#
# conduct
# ['NOUN']
# Event
# entity
#
# confocal microscopy
# ['ADJ', 'NOUN']
# Event
# entity
#
# conformational change
# ['ADJ', 'NOUN']
# Event
# entity
#
# shape change
# ['NOUN', 'NOUN']
# Event
# entity
#
# conjugate
# ['NOUN']
# Event
# entity
#
# conservative model
# ['ADJ', 'NOUN']
# Event
# entity
#
# constant motion
# ['ADJ', 'NOUN']
# Event
# entity
#
# contained volume
# ['VERB', 'NOUN']
# Entity
# event
#
# continental drift
# ['ADJ', 'NOUN']
# Event
# entity
#
# contraceptive procedure
# ['ADJ', 'NOUN']
# Event
# entity
#
# birth-control-procedure
# ['ADJ']
# Event
# entity
#
# contractile ring
# ['ADJ', 'NOUN']
# Entity
# event
#
# control element
# ['NOUN', 'NOUN']
# Entity
# event
#
# convection
# ['NOUN']
# Event
# entity
#
# convect
# ['PROPN']
# Event
# entity
#
# convergent evolution
# ['ADJ', 'NOUN']
# Event
# entity
#
# cooperativity
# ['NOUN']
# Event
# entity
#
# express
# ['PROPN']
# Event
# entity
#
# cortical reaction
# ['ADJ', 'NOUN']
# Event
# entity
#
# secondary active transport
# ['ADJ', 'ADJ', 'NOUN']
# Event
# entity
#
# co-transport
# ['NOUN']
# Event
# entity
#
# cotransport
# ['NOUN']
# Event
# entity
#
# cotransport of sucrose and hydrogen ion by plant cell
# ['NOUN', 'ADP', 'NOUN', 'CCONJ', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN']
# Event
# entity
#
# countercurrent exchange
# ['ADJ', 'NOUN']
# Event
# entity
#
# countercurrent multiplier system
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# courtship
# ['NOUN']
# Event
# entity
#
# cam pathway
# ['NOUN', 'NOUN']
# Event
# entity
#
# cri du chat syndrome
# ['NOUN', 'ADP', 'VERB', 'NOUN']
# Entity
# event
#
# cross over
# ['NOUN', 'ADV']
# Event
# entity
#
# crosstalk
# ['NOUN']
# Event
# entity
#
# crush
# ['NOUN']
# Event
# entity
#
# cultured stem cell
# ['VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# cyclic electron flow
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# cyclic-electron-pathway
# ['ADJ']
# Event
# entity
#
# cyclic electron pathway
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# cyclic reaction
# ['ADJ', 'NOUN']
# Event
# entity
#
# mucoviscidosis
# ['NOUN']
# Entity
# event
#
# cystic fibrosis
# ['ADJ', 'NOUN']
# Entity
# event
#
# communicating junctions
# ['VERB', 'NOUN']
# Entity
# event
#
# cytoplasmic response
# ['ADJ', 'NOUN']
# Event
# entity
#
# DNA-binding domain
# ['NOUN', 'PUNCT', 'NOUN', 'NOUN']
# Entity
# event
#
# dna binding domain
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# DNA breakdown
# ['PROPN', 'NOUN', 'PROPN']
# Event
# entity
#
# dna breakdown
# ['NOUN', 'NOUN', 'PROPN']
# Event
# entity
#
# DNA damage
# ['NOUN', 'NOUN']
# Event
# entity
#
# damage
# ['NOUN']
# Event
# entity
#
# dna damage
# ['NOUN', 'NOUN']
# Event
# entity
#
# hypermethylate
# ['NOUN']
# Event
# entity
#
# map
# ['NOUN']
# Event
# entity
#
# methylate
# ['PROPN']
# Event
# entity
#
# DNA microarray
# ['PROPN', 'NOUN']
# Event
# entity
#
# dna microarray
# ['NOUN', 'NOUN']
# Event
# entity
#
# repair
# ['NOUN']
# Event
# entity
#
# DNA repair
# ['NOUN', 'NOUN']
# Event
# entity
#
# dna repair
# ['NOUN', 'NOUN']
# Event
# entity
#
# copy
# ['NOUN']
# Event
# entity
#
# sequence
# ['NOUN']
# Event
# entity
#
# DNA technique
# ['NOUN', 'NOUN']
# Event
# entity
#
# dna technique
# ['NOUN', 'NOUN']
# Event
# entity
#
# bacterial gene transfer
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# transfer
# ['NOUN']
# Event
# entity
#
# DNA transfer
# ['NOUN', 'NOUN']
# Event
# entity
#
# dna transfer
# ['NOUN', 'NOUN']
# Event
# entity
#
# DNA with shortened telomere
# ['NOUN', 'ADP', 'VERB', 'NOUN']
# Entity
# event
#
# dna with shortened telomere
# ['NOUN', 'ADP', 'VERB', 'NOUN']
# Entity
# event
#
# cell-showing-damage
# ['NOUN', 'PUNCT', 'VERB', 'NOUN']
# Entity
# event
#
# damaged cell
# ['VERB', 'NOUN']
# Entity
# event
#
# damaged DNA strand
# ['VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# damaged dna strand
# ['VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# de-etiolate
# ['PROPN']
# Event
# entity
#
# deacetylate
# ['NOUN']
# Event
# entity
#
# nonliving cell
# ['NOUN', 'NOUN']
# Entity
# event
#
# nonliving-cell
# ['NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# lost cell
# ['VERB', 'NOUN']
# Entity
# event
#
# nonliving-organism
# ['NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# deaminate
# ['PROPN']
# Event
# entity
#
# death
# ['NOUN']
# Event
# entity
#
# decarboxylate
# ['NOUN']
# Event
# entity
#
# deep green
# ['ADJ', 'NOUN']
# Event
# entity
#
# deep-sea-hot-spring
# ['ADJ']
# Entity
# event
#
# deep-sea-volcanic-spring
# ['ADJ']
# Entity
# event
#
# degenerative model
# ['ADJ', 'NOUN']
# Event
# entity
#
# degranulate
# ['PROPN']
# Event
# entity
#
# deletion
# ['NOUN']
# Event
# entity
#
# demography
# ['NOUN']
# Event
# entity
#
# denaturation agent
# ['NOUN', 'NOUN']
# Entity
# event
#
# denaturing-agent
# ['NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# denatured protein
# ['VERB', 'NOUN']
# Entity
# event
#
# denitrify
# ['NOUN']
# Event
# entity
#
# denitrifying bacterium
# ['NOUN', 'NOUN']
# Entity
# event
#
# dentition
# ['NOUN']
# Entity
# event
#
# dephosphorylate
# ['NOUN']
# Event
# entity
#
# depletion
# ['NOUN']
# Event
# entity
#
# desert plant
# ['VERB', 'NOUN']
# Entity
# event
#
# determinate cleavage
# ['ADJ', 'NOUN']
# Event
# entity
#
# determinate growth
# ['ADJ', 'NOUN']
# Event
# entity
#
# developmental biology
# ['ADJ', 'NOUN']
# Event
# entity
#
# developmental genetics
# ['ADJ', 'NOUN']
# Event
# entity
#
# developmental stage
# ['ADJ', 'NOUN']
# Event
# entity
#
# renal insufficiency
# ['ADJ', 'NOUN']
# Event
# entity
#
# diagnostic procedure
# ['ADJ', 'NOUN']
# Event
# entity
#
# diaphragm birth control
# ['NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# diastole
# ['NOUN']
# Event
# entity
#
# differentiated cell
# ['VERB', 'NOUN']
# Entity
# event
#
# transplant
# ['NOUN']
# Event
# entity
#
# differentiated embryonic cell
# ['VERB', 'ADJ', 'NOUN']
# Entity
# event
#
# diffuse
# ['ADJ']
# Event
# entity
#
# digestion
# ['NOUN']
# Event
# entity
#
# directional selection
# ['ADJ', 'NOUN']
# Event
# entity
#
# discovery science
# ['NOUN', 'NOUN']
# Event
# entity
#
# dispersal
# ['NOUN']
# Event
# entity
#
# dispersive model
# ['ADJ', 'NOUN']
# Event
# entity
#
# disruptive selection
# ['ADJ', 'NOUN']
# Event
# entity
#
# dissolution of salt molecule in water
# ['NOUN', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# dissolution of sugar molecule in water
# ['NOUN', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# distilled water
# ['VERB', 'NOUN']
# Entity
# event
#
# distribution of daughter chromosomes
# ['NOUN', 'ADP', 'NOUN', 'NOUN']
# Event
# entity
#
# disturbance
# ['NOUN']
# Event
# entity
#
# close diurnally
# ['ADJ', 'ADV']
# Event
# entity
#
# eukaryotic-cell-undergoing-cell division
# ['ADJ', 'PUNCT', 'NOUN', 'NOUN']
# Entity
# event
#
# dividing eukaryotic cell
# ['VERB', 'ADJ', 'NOUN']
# Entity
# event
#
# dominance hierarchy
# ['NOUN', 'NOUN']
# Event
# entity
#
# dormancy
# ['NOUN']
# Event
# entity
#
# double circulation
# ['ADJ', 'NOUN']
# Entity
# event
#
# drought
# ['NOUN']
# Event
# entity
#
# drug resistance
# ['NOUN', 'NOUN']
# Event
# entity
#
# duplication
# ['NOUN']
# Entity
# event
#
# duplicate
# ['NOUN']
# Event
# entity
#
# early atherosclerosis
# ['ADJ', 'NOUN']
# Entity
# event
#
# community as ecological grouping
# ['NOUN', 'ADP', 'ADJ', 'NOUN']
# Entity
# event
#
# ecological grouping
# ['ADJ', 'NOUN']
# Entity
# event
#
# ecology
# ['NOUN']
# Event
# entity
#
# ecosystem ecology
# ['NOUN', 'NOUN']
# Event
# entity
#
# ecosystem service
# ['NOUN', 'NOUN']
# Event
# entity
#
# cold-blooded
# ['ADJ', 'PUNCT', 'ADJ']
# Event
# entity
#
# ectothermy
# ['NOUN']
# Event
# entity
#
# ectothermic
# ['PROPN']
# Event
# entity
#
# unfertilized egg cell
# ['VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# unfertilized egg
# ['VERB', 'NOUN']
# Entity
# event
#
# egg laying animal
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# eight cell stage
# ['NUM', 'NOUN', 'NOUN']
# Event
# entity
#
# electrically charged amino acid
# ['ADV', 'VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# electrocardiogram
# ['NOUN']
# Event
# entity
#
# electromagnetic-radiation
# ['ADJ']
# Entity
# event
#
# electron microscopy
# ['NOUN', 'NOUN']
# Event
# entity
#
# electron transport chain pathway
# ['NOUN', 'NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# etc-reaction
# ['X', 'PUNCT', 'NOUN']
# Event
# entity
#
# electron transport chain reaction
# ['NOUN', 'NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# electron transport chain reaction in prokaryote
# ['NOUN', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# electron carrier of cellular respiration
# ['NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN']
# Entity
# event
#
# nadp+ of photosynthesis
# ['NOUN', 'ADP', 'NOUN']
# Entity
# event
#
# electron carrier of photosynthesis
# ['NOUN', 'NOUN', 'ADP', 'NOUN']
# Entity
# event
#
# nadph of photosynthesis
# ['NOUN', 'ADP', 'NOUN']
# Entity
# event
#
# electronegative element
# ['ADJ', 'NOUN']
# Entity
# event
#
# elongation factor
# ['NOUN', 'NOUN']
# Entity
# event
#
# elongation-factor
# ['NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# embryonic-stage
# ['ADJ', 'PUNCT', 'NOUN']
# Event
# entity
#
# embryonic-phase
# ['ADJ']
# Event
# entity
#
# embryonic-period
# ['ADJ']
# Event
# entity
#
# embryogenic-stage
# ['NOUN', 'PUNCT', 'NOUN']
# Event
# entity
#
# embryo-stage
# ['NOUN', 'PUNCT', 'NOUN']
# Event
# entity
#
# embryo stage
# ['NOUN', 'NOUN']
# Event
# entity
#
# embryology
# ['NOUN']
# Event
# entity
#
# embryonic induction
# ['ADJ', 'NOUN']
# Event
# entity
#
# embryonic lethal
# ['ADJ', 'ADJ']
# Event
# entity
#
# stages-of-embryo-development
# ['X']
# Entity
# event
#
# emerging virus
# ['VERB', 'NOUN']
# Entity
# event
#
# emotion
# ['NOUN']
# Event
# entity
#
# endemic
# ['ADJ']
# Event
# entity
#
# unfavorable-reaction
# ['ADJ']
# Event
# entity
#
# unfavorable reaction
# ['ADJ', 'NOUN']
# Event
# entity
#
# endergonic reaction
# ['ADJ', 'NOUN']
# Event
# entity
#
# non-spontaneous reaction
# ['ADJ', 'PUNCT', 'ADJ', 'NOUN']
# Event
# entity
#
# nonspontaneous-reaction
# ['ADJ']
# Event
# entity
#
# endometriosis
# ['NOUN']
# Entity
# event
#
# endosymbiont theory
# ['NOUN', 'NOUN']
# Event
# entity
#
# warm-blooded
# ['ADJ', 'PUNCT', 'ADJ']
# Event
# entity
#
# endothermic
# ['ADJ']
# Event
# entity
#
# energy budget
# ['NOUN', 'NOUN']
# Event
# entity
#
# energy flow
# ['NOUN', 'NOUN']
# Event
# entity
#
# energy flow in ecosystem
# ['NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# energy reaction
# ['NOUN', 'NOUN']
# Event
# entity
#
# enteric division
# ['ADJ', 'NOUN']
# Entity
# event
#
# entry of arsenic in groundwater
# ['NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# entry of glucose in liver cell
# ['NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', 'NOUN']
# Event
# entity
#
# enucleated cell
# ['VERB', 'NOUN']
# Entity
# event
#
# environment
# ['NOUN']
# Entity
# event
#
# surrounding
# ['VERB']
# Entity
# event
#
# enzymatic reaction
# ['ADJ', 'NOUN']
# Event
# entity
#
# enzyme complement
# ['NOUN', 'NOUN']
# Entity
# event
#
# epidemic
# ['NOUN']
# Event
# entity
#
# epidemiology
# ['NOUN']
# Event
# entity
#
# epigenesis
# ['NOUN']
# Entity
# event
#
# epigenetic inheritance
# ['ADJ', 'NOUN']
# Event
# entity
#
# equilibrium
# ['NOUN']
# Event
# entity
#
# equilibrize
# ['PROPN']
# Event
# entity
#
# essential chemical element for life
# ['ADJ', 'ADJ', 'NOUN', 'ADP', 'NOUN']
# Entity
# event
#
# ethology
# ['NOUN']
# Event
# entity
#
# ripening gas
# ['NOUN', 'NOUN']
# Entity
# event
#
# eukaryotic lagging strand
# ['ADJ', 'NOUN', 'NOUN']
# Entity
# event
#
# eukaryotic light reaction
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# eukaryotic light reaction with cyclic electron flow
# ['ADJ', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# eukaryotic light reaction with linear electron flow
# ['ADJ', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# vaporise
# ['PROPN']
# Event
# entity
#
# evolution
# ['NOUN']
# Event
# entity
#
# evolution of mitosis hypothesis
# ['NOUN', 'ADP', 'NOUN', 'NOUN']
# Entity
# event
#
# evolutionary developmental biology
# ['ADJ', 'ADJ', 'NOUN']
# Event
# entity
#
# evolutionary representation
# ['ADJ', 'NOUN']
# Entity
# event
#
# exaptation
# ['NOUN']
# Entity
# event
#
# exchange
# ['NOUN']
# Event
# entity
#
# excreted fluid
# ['VERB', 'NOUN']
# Entity
# event
#
# excretion
# ['NOUN']
# Event
# entity
#
# excretion of nitrogenous waste by animal
# ['NOUN', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# release
# ['NOUN']
# Event
# entity
#
# exergonic
# ['PROPN']
# Event
# entity
#
# favorable-reaction
# ['ADJ', 'PUNCT', 'NOUN']
# Event
# entity
#
# exergonic reaction
# ['ADJ', 'NOUN']
# Event
# entity
#
# spontaneous-reaction
# ['NOUN']
# Event
# entity
#
# coding-segment
# ['NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# expression vector
# ['NOUN', 'NOUN']
# Entity
# event
#
# extensive work by human
# ['ADJ', 'NOUN', 'ADP', 'ADJ']
# Event
# entity
#
# extinction
# ['NOUN']
# Event
# entity
#
# extinction vortex
# ['NOUN', 'NOUN']
# Event
# entity
#
# extracellular digestion
# ['ADJ', 'NOUN']
# Event
# entity
#
# cell missing f plasmid
# ['NOUN', 'ADJ', 'NOUN', 'NOUN']
# Entity
# event
#
# F1 generation
# ['NOUN', 'NOUN']
# Entity
# event
#
# f1 generation
# ['NOUN', 'NOUN']
# Entity
# event
#
# F2 generation
# ['NOUN', 'NOUN']
# Entity
# event
#
# f2 generation
# ['NOUN', 'NOUN']
# Entity
# event
#
# family as classification
# ['NOUN', 'ADP', 'NOUN']
# Entity
# event
#
# fasciated gene
# ['VERB', 'NOUN']
# Entity
# event
#
# fast block
# ['ADJ', 'NOUN']
# Event
# entity
#
# bowel-movement
# ['NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# negative-feedback
# ['ADJ', 'PUNCT', 'NOUN']
# Event
# entity
#
# feedback mechanism
# ['NOUN', 'NOUN']
# Event
# entity
#
# female calico cat expressing fur color
# ['ADJ', 'ADJ', 'NOUN', 'VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# cell involved in fermentation
# ['NOUN', 'ADJ', 'ADP', 'NOUN']
# Entity
# event
#
# fermenting cell
# ['NOUN', 'NOUN']
# Entity
# event
#
# syngamy
# ['PROPN']
# Event
# entity
#
# fertilization envelope
# ['NOUN', 'NOUN']
# Entity
# event
#
# fetal stage
# ['ADJ', 'NOUN']
# Event
# entity
#
# fetoscopy
# ['NOUN']
# Event
# entity
#
# fever
# ['NOUN']
# Event
# entity
#
# fight or flight response
# ['NOUN', 'CCONJ', 'NOUN', 'NOUN']
# Event
# entity
#
# filament
# ['NOUN']
# Entity
# event
#
# filament protein
# ['NOUN', 'NOUN']
# Entity
# event
#
# filter
# ['NOUN']
# Event
# entity
#
# principle of conservation of energy
# ['NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN']
# Entity
# event
#
# flaccid
# ['ADJ']
# Event
# entity
#
# flagellated cell
# ['VERB', 'NOUN']
# Entity
# event
#
# flight
# ['NOUN']
# Event
# entity
#
# float
# ['NOUN']
# Event
# entity
#
# flood
# ['NOUN']
# Event
# entity
#
# Florida scrub jay
# ['PROPN', 'VERB', 'PROPN']
# Entity
# event
#
# florida scrub jay
# ['PROPN', 'VERB', 'PROPN']
# Entity
# event
#
# flow
# ['NOUN']
# Event
# entity
#
# flower filament
# ['NOUN', 'NOUN']
# Entity
# event
#
# flowering control plant
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# plant-with-flowering-control
# ['NOUN', 'PUNCT', 'ADP', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# fluorescence
# ['NOUN']
# Event
# entity
#
# stain
# ['NOUN']
# Event
# entity
#
# loop
# ['NOUN']
# Event
# entity
#
# bend
# ['NOUN']
# Event
# entity
#
# fold
# ['NOUN']
# Event
# entity
#
# folded protein
# ['VERB', 'NOUN']
# Entity
# event
#
# proliferative-phase
# ['ADJ', 'PUNCT', 'NOUN']
# Event
# entity
#
# follicular phase
# ['ADJ', 'NOUN']
# Event
# entity
#
# forensic detection of similarities and differences in DNA samples
# ['ADJ', 'NOUN', 'ADP', 'NOUN', 'CCONJ', 'NOUN', 'ADP', 'NOUN', 'NOUN']
# Event
# entity
#
# rflp in forensics
# ['NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# forensic detection of similarities and differences in dna samples
# ['ADJ', 'NOUN', 'ADP', 'NOUN', 'CCONJ', 'NOUN', 'ADP', 'NOUN', 'NOUN']
# Event
# entity
#
# forensic science
# ['ADJ', 'NOUN']
# Event
# entity
#
# forensics
# ['NOUN']
# Event
# entity
#
# forward reaction
# ['ADJ', 'NOUN']
# Event
# entity
#
# founder effect
# ['NOUN', 'NOUN']
# Event
# entity
#
# franklin x-ray crystallography
# ['PROPN', 'PROPN', 'PUNCT', 'PROPN', 'NOUN']
# Event
# entity
#
# freeze-fracture-technique
# ['ADJ']
# Event
# entity
#
# freeze-fracture
# ['NOUN', 'PUNCT', 'NOUN']
# Event
# entity
#
# freeze
# ['NOUN']
# Event
# entity
#
# frequency dependent selection
# ['NOUN', 'ADJ', 'NOUN']
# Event
# entity
#
# frozen cell
# ['VERB', 'NOUN']
# Entity
# event
#
# fruit fly maternal gene
# ['NOUN', 'VERB', 'ADJ', 'NOUN']
# Entity
# event
#
# fruit fly reproduction
# ['NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# fruiting body
# ['NOUN', 'NOUN']
# Entity
# event
#
# fuse
# ['NOUN']
# Event
# entity
#
# G-protein coupled receptor
# ['NOUN', 'VERB', 'NOUN']
# Entity
# event
#
# g protein linked receptor protein
# ['NOUN', 'NOUN', 'VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# g protein linked receptor
# ['NOUN', 'NOUN', 'VERB', 'NOUN']
# Entity
# event
#
# g protein coupled receptor
# ['NOUN', 'NOUN', 'VERB', 'NOUN']
# Entity
# event
#
# G0-phase
# ['NOUN', 'PUNCT', 'NOUN']
# Event
# entity
#
# g0 phase
# ['ADJ', 'NOUN']
# Event
# entity
#
# restriction point
# ['NOUN', 'NOUN']
# Event
# entity
#
# G1-checkpoint
# ['PROPN']
# Event
# entity
#
# g1 checkpoint
# ['PROPN', 'NOUN']
# Event
# entity
#
# G1-checkpoint in animal cell
# ['PROPN', 'PUNCT', 'NOUN', 'ADP', 'NOUN', 'NOUN']
# Event
# entity
#
# g1 checkpoint in animal cell
# ['ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN']
# Event
# entity
#
# first gap
# ['ADJ', 'NOUN']
# Event
# entity
#
# initial-interphase
# ['ADJ', 'PUNCT', 'NOUN']
# Event
# entity
#
# initial interphase
# ['ADJ', 'NOUN']
# Event
# entity
#
# G1-phase
# ['NOUN', 'PUNCT', 'NOUN']
# Event
# entity
#
# g1 phase
# ['NOUN', 'NUM', 'NOUN']
# Event
# entity
#
# G2-checkpoint
# ['PROPN']
# Event
# entity
#
# g2 checkpoint
# ['PROPN', 'NOUN']
# Event
# entity
#
# late-interphase
# ['ADJ', 'PUNCT', 'NOUN']
# Event
# entity
#
# late interphase
# ['ADJ', 'NOUN']
# Event
# entity
#
# G2-phase
# ['NOUN', 'PUNCT', 'NOUN']
# Event
# entity
#
# second gap
# ['ADJ', 'NOUN']
# Event
# entity
#
# g2 phase
# ['NOUN', 'NUM', 'NOUN']
# Event
# entity
#
# game theory
# ['NOUN', 'NOUN']
# Event
# entity
#
# gamete production
# ['ADJ', 'NOUN']
# Event
# entity
#
# gap in segmentation
# ['NOUN', 'ADP', 'NOUN']
# Entity
# event
#
# communicating junction
# ['VERB', 'NOUN']
# Entity
# event
#
# gas exchange
# ['NOUN', 'NOUN']
# Event
# entity
#
# gated Channel
# ['VERB', 'NOUN']
# Entity
# event
#
# gated channel
# ['VERB', 'NOUN']
# Entity
# event
#
# gated ion channel
# ['VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# gene allele relationship
# ['NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# polymerase-chain-reaction
# ['ADJ']
# Event
# entity
#
# pcr
# ['NOUN']
# Event
# entity
#
# gene flow
# ['NOUN', 'NOUN']
# Event
# entity
#
# gene interactions
# ['NOUN', 'NOUN']
# Event
# entity
#
# gene loss
# ['NOUN', 'NOUN']
# Event
# entity
#
# genetic-control
# ['ADJ']
# Event
# entity
#
# gene therapy
# ['NOUN', 'NOUN']
# Event
# entity
#
# generation
# ['NOUN']
# Entity
# event
#
# genetic-information
# ['NOUN']
# Entity
# event
#
# genetic drift
# ['ADJ', 'NOUN']
# Event
# entity
#
# genetically engineer
# ['ADV', 'NOUN']
# Event
# entity
#
# genetic representation
# ['ADJ', 'NOUN']
# Entity
# event
#
# genetic diversity
# ['ADJ', 'NOUN']
# Event
# entity
#
# genetic-diversity
# ['ADJ', 'PUNCT', 'NOUN']
# Event
# entity
#
# genetically modified organism
# ['ADV', 'VERB', 'NOUN']
# Entity
# event
#
# genetics
# ['NOUN']
# Event
# entity
#
# genomic representation
# ['ADJ', 'NOUN']
# Entity
# event
#
# genomics
# ['NOUN']
# Event
# entity
#
# offspring phenotype
# ['NOUN', 'NOUN']
# Entity
# event
#
# genotype of offspring
# ['NOUN', 'ADP', 'NOUN']
# Entity
# event
#
# geologic uplift
# ['ADJ', 'NOUN']
# Event
# entity
#
# geological time period
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# geology
# ['NOUN']
# Event
# entity
#
# global ecology
# ['ADJ', 'NOUN']
# Event
# entity
#
# heat
# ['NOUN']
# Event
# entity
#
# glucose storage by animals
# ['NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# store
# ['NOUN']
# Event
# entity
#
# glycogen breakdown
# ['NOUN', 'NOUN']
# Event
# entity
#
# glycogen breakdown in vertebrates
# ['NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# glycogen storage by vertebrate
# ['NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# glycolytic pathway
# ['ADJ', 'NOUN']
# Event
# entity
#
# jawed vertebrates
# ['VERB', 'NOUN']
# Entity
# event
#
# gonadotropin-releasing hormone
# ['NOUN', 'PUNCT', 'VERB', 'NOUN']
# Entity
# event
#
# gonadotropin releasing hormone
# ['NOUN', 'VERB', 'NOUN']
# Entity
# event
#
# graded potential
# ['VERB', 'NOUN']
# Entity
# event
#
# gradualism theory
# ['NOUN', 'NOUN']
# Entity
# event
#
# gram stain
# ['NOUN', 'NOUN']
# Event
# entity
#
# graphical representation
# ['ADJ', 'NOUN']
# Entity
# event
#
# gravitropism
# ['PROPN']
# Event
# entity
#
# greenhouse effect
# ['NOUN', 'NOUN']
# Event
# entity
#
# grind
# ['NOUN']
# Event
# entity
#
# gross primary production
# ['ADJ', 'ADJ', 'NOUN']
# Event
# entity
#
# growth factor release
# ['NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# habitat selection
# ['NOUN', 'NOUN']
# Event
# entity
#
# hardy weinberg equilibrium
# ['PROPN', 'NOUN', 'NOUN']
# Event
# entity
#
# heart attack
# ['NOUN', 'NOUN']
# Event
# entity
#
# heart beat
# ['NOUN', 'NOUN']
# Event
# entity
#
# heart murmur
# ['NOUN', 'NOUN']
# Event
# entity
#
# heat transfer
# ['NOUN', 'NOUN']
# Event
# entity
#
# Henrietta lacks
# ['PROPN', 'VERB']
# Entity
# event
#
# henrietta lacks
# ['PROPN', 'VERB']
# Entity
# event
#
# herbivory
# ['NOUN']
# Event
# entity
#
# hermaphroditism
# ['NOUN']
# Event
# entity
#
# heterochrony
# ['NOUN']
# Event
# entity
#
# heteromorphic
# ['ADJ']
# Event
# entity
#
# heterozygote advantage
# ['NOUN', 'NOUN']
# Event
# entity
#
# heterozygous-advantage
# ['ADJ']
# Event
# entity
#
# holoblastic cleavage
# ['ADJ', 'NOUN']
# Event
# entity
#
# homeobox containing gene
# ['NOUN', 'VERB', 'NOUN']
# Entity
# event
#
# homeodomain containing protein
# ['NOUN', 'VERB', 'NOUN']
# Entity
# event
#
# homeostatic response
# ['ADJ', 'NOUN']
# Event
# entity
#
# homo heidelbergensis
# ['NOUN', 'NOUN']
# Entity
# event
#
# homogenize
# ['PROPN']
# Event
# entity
#
# homologize
# ['PROPN']
# Event
# entity
#
# homology
# ['NOUN']
# Event
# entity
#
# homozygous dominant cross
# ['ADJ', 'ADJ', 'NOUN']
# Event
# entity
#
# homozygous recessive cross
# ['ADJ', 'ADJ', 'NOUN']
# Event
# entity
#
# lateral-gene-transfer
# ['ADJ']
# Event
# entity
#
# lgt
# ['PROPN']
# Event
# entity
#
# hgt
# ['PROPN']
# Event
# entity
#
# horizontal gene transfer
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# host range
# ['NOUN', 'NOUN']
# Event
# entity
#
# human behavior
# ['ADJ', 'NOUN']
# Event
# entity
#
# human dentition
# ['ADJ', 'NOUN']
# Entity
# event
#
# human evolution
# ['ADJ', 'NOUN']
# Event
# entity
#
# human genome project
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# human nutritional requirement
# ['ADJ', 'ADJ', 'NOUN']
# Entity
# event
#
# humoral immune response
# ['ADJ', 'ADJ', 'NOUN']
# Event
# entity
#
# hybrid breakdown
# ['ADJ', 'NOUN']
# Event
# entity
#
# hydrated ion
# ['VERB', 'NOUN', 'PROPN']
# Entity
# event
#
# hydrated molecule
# ['VERB', 'NOUN']
# Entity
# event
#
# hydrate
# ['NOUN']
# Event
# entity
#
# hydration shell
# ['NOUN', 'NOUN']
# Entity
# event
#
# solvation shell
# ['NOUN', 'NOUN']
# Entity
# event
#
# hydroelectric system
# ['ADJ', 'NOUN']
# Event
# entity
#
# hydrogenated margarine
# ['VERB', 'NOUN']
# Entity
# event
#
# hydrogenated peanut butter
# ['VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# hydrogenated vegetable oil
# ['VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# hydrolize
# ['PROPN']
# Event
# entity
#
# hydroponic
# ['NOUN']
# Event
# entity
#
# hydroponic-agriculture
# ['ADJ']
# Event
# entity
#
# hydroponic culture
# ['ADJ', 'NOUN']
# Event
# entity
#
# cancer causing ras protein
# ['NOUN', 'VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# hypersensitivity response
# ['NOUN', 'NOUN']
# Event
# entity
#
# hypertonic
# ['ADJ']
# Event
# entity
#
# hypothesis
# ['NOUN']
# Entity
# event
#
# hypotonic
# ['PROPN']
# Event
# entity
#
# i-filament
# ['PROPN']
# Entity
# event
#
# I band filament
# ['PRON', 'VERB', 'NOUN']
# Entity
# event
#
# i band filament
# ['PRON', 'VERB', 'NOUN']
# Entity
# event
#
# I-minus
# ['PRON', 'VERB']
# Entity
# event
#
# i minus
# ['PRON', 'VERB']
# Entity
# event
#
# group-ia-element
# ['ADJ']
# Entity
# event
#
# group-1-element
# ['PROPN']
# Entity
# event
#
# IA alkali metal element
# ['PROPN', 'NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# ia alkali metal element
# ['NOUN', 'NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# group-iia-element
# ['ADJ']
# Entity
# event
#
# IIA alkaline earth metal element
# ['NOUN', 'ADJ', 'NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# group-2-element
# ['ADJ']
# Entity
# event
#
# iia alkaline earth metal element
# ['NOUN', 'ADJ', 'NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# IIIA element
# ['NOUN', 'NOUN']
# Entity
# event
#
# iiia element
# ['NOUN', 'NOUN']
# Entity
# event
#
# IP3 gated calcium ion channel
# ['NOUN', 'VERB', 'NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# ip3 gated calcium ion channel
# ['NOUN', 'VERB', 'NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# IVA element
# ['PROPN', 'NOUN']
# Entity
# event
#
# iva element
# ['PROPN', 'NOUN']
# Entity
# event
#
# floating ice
# ['VERB', 'NOUN']
# Entity
# event
#
# floating water
# ['VERB', 'NOUN']
# Entity
# event
#
# frozen water
# ['VERB', 'NOUN']
# Entity
# event
#
# if then logic
# ['SCONJ', 'ADV', 'NOUN']
# Event
# entity
#
# immune response
# ['ADJ', 'NOUN']
# Event
# entity
#
# implant
# ['NOUN']
# Event
# entity
#
# imprint
# ['NOUN']
# Event
# entity
#
# improperly methylated DNA
# ['ADV', 'VERB', 'NOUN']
# Entity
# event
#
# improperly methylated dna
# ['ADV', 'VERB', 'NOUN']
# Entity
# event
#
# In situ
# ['ADP', 'NOUN']
# Event
# entity
#
# in situ
# ['ADP', 'NOUN']
# Event
# entity
#
# In vitro
# ['ADP', 'NOUN']
# Event
# entity
#
# in vitro
# ['ADP', 'NOUN']
# Event
# entity
#
# inborn error of metabolism
# ['ADJ', 'NOUN', 'ADP', 'NOUN']
# Entity
# event
#
# incomplete dominance
# ['ADJ', 'NOUN']
# Event
# entity
#
# increase
# ['NOUN']
# Event
# entity
#
# indeterminate cleavage
# ['ADJ', 'NOUN']
# Event
# entity
#
# indeterminate growth
# ['ADJ', 'NOUN']
# Event
# entity
#
# individualistic hypothesis
# ['ADJ', 'NOUN']
# Entity
# event
#
# induction
# ['NOUN']
# Event
# entity
#
# infected cell
# ['VERB', 'NOUN']
# Entity
# event
#
# infection
# ['NOUN']
# Event
# entity
#
# inflammatory response
# ['ADJ', 'NOUN']
# Event
# entity
#
# influence
# ['NOUN']
# Event
# entity
#
# information
# ['NOUN']
# Entity
# event
#
# ingestion
# ['NOUN']
# Event
# entity
#
# heredity
# ['NOUN']
# Event
# entity
#
# inheritance
# ['NOUN']
# Event
# entity
#
# inheritance of extranuclear genes
# ['NOUN', 'ADP', 'ADJ', 'NOUN']
# Event
# entity
#
# initiation factor
# ['NOUN', 'NOUN']
# Entity
# event
#
# innate behavior
# ['ADJ', 'NOUN']
# Event
# entity
#
# instinctive-behavior
# ['ADJ', 'PUNCT', 'NOUN']
# Event
# entity
#
# instinct
# ['NOUN']
# Event
# entity
#
# inquiry
# ['NOUN']
# Event
# entity
#
# insertion
# ['NOUN']
# Event
# entity
#
# integument
# ['NOUN']
# Entity
# event
#
# interaction of light with matter
# ['NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# interactive hypothesis
# ['ADJ', 'NOUN']
# Entity
# event
#
# intermediate filament
# ['ADJ', 'NOUN']
# Entity
# event
#
# interphase i
# ['NOUN', 'X']
# Event
# entity
#
# interphase
# ['NOUN']
# Event
# entity
#
# intersexual selection
# ['ADJ', 'NOUN']
# Event
# entity
#
# interspecific interaction
# ['ADJ', 'NOUN']
# Event
# entity
#
# interspersed repetitive DNA
# ['VERB', 'ADJ', 'NOUN']
# Entity
# event
#
# interspersed repetitive dna
# ['VERB', 'ADJ', 'NOUN']
# Entity
# event
#
# intracellular digestion
# ['ADJ', 'NOUN']
# Event
# entity
#
# intracytoplasmic sperm injection
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# intrasexual selection
# ['ADJ', 'NOUN']
# Event
# entity
#
# iud
# ['NOUN']
# Event
# entity
#
# intrauterine device
# ['ADJ', 'NOUN']
# Event
# entity
#
# introduced species
# ['VERB', 'NOUN']
# Entity
# event
#
# intervening-sequence
# ['VERB', 'PUNCT', 'NOUN']
# Entity
# event
#
# non-coding-segment
# ['ADJ', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# invaginate
# ['PROPN']
# Event
# entity
#
# invert
# ['NOUN']
# Event
# entity
#
# involution
# ['NOUN']
# Event
# entity
#
# irreparable DNA damage
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# damage irreparably
# ['NOUN', 'ADV']
# Event
# entity
#
# irreparable dna damage
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# isolated chlorophyll solution
# ['VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# isolated system
# ['VERB', 'NOUN']
# Entity
# event
#
# isomorphic
# ['ADJ']
# Event
# entity
#
# isotonic
# ['ADJ']
# Event
# entity
#
# iteroparity
# ['NOUN']
# Event
# entity
#
# juvenile stage
# ['ADJ', 'NOUN']
# Event
# entity
#
# density-dependent selection
# ['NOUN', 'PUNCT', 'ADJ', 'NOUN']
# Event
# entity
#
# K-selection
# ['PROPN']
# Event
# entity
#
# k selection
# ['PROPN', 'NOUN']
# Event
# entity
#
# karyogamy
# ['PROPN']
# Event
# entity
#
# kin selection
# ['NOUN', 'NOUN']
# Event
# entity
#
# knee jerk reflex
# ['NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# long-interspersed-nuclear-element
# ['NOUN']
# Entity
# event
#
# luteinizing hormone
# ['NOUN', 'NOUN']
# Entity
# event
#
# luteinizing-hormone
# ['NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# labor
# ['NOUN']
# Event
# entity
#
# labor and delivery
# ['NOUN', 'CCONJ', 'NOUN']
# Event
# entity
#
# lagging strand
# ['VERB', 'NOUN']
# Entity
# event
#
# landscape ecology
# ['NOUN', 'NOUN']
# Event
# entity
#
# hatch
# ['PROPN']
# Event
# entity
#
# larval stage
# ['ADJ', 'NOUN']
# Event
# entity
#
# lateral line system
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# law of independent assortment
# ['NOUN', 'ADP', 'ADJ', 'NOUN']
# Entity
# event
#
# law of segregation
# ['NOUN', 'ADP', 'NOUN']
# Entity
# event
#
# lead atom
# ['VERB', 'NOUN']
# Entity
# event
#
# leader-segment
# ['NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# leader segment
# ['NOUN', 'NOUN']
# Entity
# event
#
# leading strand
# ['VERB', 'NOUN']
# Entity
# event
#
# lichen
# ['NOUN']
# Event
# entity
#
# life activity
# ['NOUN', 'NOUN']
# Event
# entity
#
# biological activity
# ['ADJ', 'NOUN']
# Event
# entity
#
# life history
# ['NOUN', 'NOUN']
# Event
# entity
#
# ligament
# ['NOUN']
# Entity
# event
#
# ligand gated calcium channel
# ['NOUN', 'VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# ligand-gated ion-channel
# ['NOUN', 'PUNCT', 'VERB', 'NOUN']
# Entity
# event
#
# ligand gated ion channel
# ['NOUN', 'VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# visible_radiation
# ['NOUN']
# Entity
# event
#
# light-harvesting complex
# ['NOUN', 'PUNCT', 'NOUN', 'NOUN']
# Entity
# event
#
# light harvesting complex in the chloroplast
# ['NOUN', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN']
# Entity
# event
#
# light harvesting complex
# ['ADJ', 'NOUN', 'NOUN']
# Entity
# event
#
# optical-microscopy
# ['ADJ']
# Event
# entity
#
# light microscopy
# ['ADJ', 'NOUN']
# Event
# entity
#
# light reaction
# ['ADJ', 'NOUN']
# Event
# entity
#
# light reflection
# ['ADJ', 'NOUN']
# Event
# entity
#
# transmittance
# ['NOUN']
# Event
# entity
#
# limiting nutrient
# ['VERB', 'NOUN']
# Entity
# event
#
# linear electron flow
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# lining
# ['NOUN']
# Entity
# event
#
# linked genes
# ['VERB', 'NOUN']
# Entity
# event
#
# living_thing
# ['NOUN']
# Entity
# event
#
# animate thing
# ['VERB', 'NOUN']
# Entity
# event
#
# animate_thing
# ['NOUN']
# Entity
# event
#
# living entity
# ['NOUN', 'NOUN']
# Entity
# event
#
# load
# ['NOUN']
# Event
# entity
#
# locomotion of eukaryotic cell by flagellum
# ['NOUN', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# locomotion of eukaryotic cell by motile cilium
# ['NOUN', 'ADP', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN']
# Event
# entity
#
# log
# ['NOUN']
# Event
# entity
#
# long term memory
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# ltp
# ['PROPN']
# Event
# entity
#
# looped domains
# ['VERB', 'NOUN']
# Entity
# event
#
# crown of ciliated tentacles
# ['NOUN', 'ADP', 'VERB', 'NOUN']
# Entity
# event
#
# loss of energy by electron
# ['NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# luteal phase
# ['ADJ', 'NOUN']
# Event
# entity
#
# lyme-borreliosis
# ['NOUN']
# Entity
# event
#
# break
# ['NOUN']
# Event
# entity
#
# mitotic-phase
# ['ADJ', 'PUNCT', 'NOUN']
# Event
# entity
#
# mitotic phase
# ['ADJ', 'NOUN']
# Event
# entity
#
# M-phase
# ['NUM', 'PUNCT', 'NOUN']
# Event
# entity
#
# m-phase
# ['NUM', 'PUNCT', 'NOUN']
# Event
# entity
#
# m phase
# ['NUM', 'NOUN']
# Event
# entity
#
# M-phase checkpoint
# ['NUM', 'PUNCT', 'NOUN', 'NOUN']
# Event
# entity
#
# m phase checkpoint
# ['NUM', 'NOUN', 'NOUN']
# Event
# entity
#
# mitogen-activated protein kinase
# ['NOUN', 'PUNCT', 'VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# maturation-promoting-factor
# ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# m phase promoting factor
# ['NUM', 'NOUN', 'VERB', 'NOUN']
# Entity
# event
#
# macroclimate
# ['PROPN']
# Event
# entity
#
# macroevolution
# ['NOUN']
# Event
# entity
#
# magnetic reversal
# ['ADJ', 'NOUN']
# Event
# entity
#
# geomagnetic-reversal
# ['ADJ']
# Event
# entity
#
# maintenance of pH in lysosome
# ['NOUN', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# lysosomal ph maintenance
# ['NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# ph maintenance in lysosome
# ['NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# maintenance of ph
# ['NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# maintenance of lysosomal ph
# ['NOUN', 'ADP', 'ADJ', 'NOUN']
# Event
# entity
#
# maintenance of ph in lysosome
# ['NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# major Depression
# ['ADJ', 'NOUN']
# Entity
# event
#
# major depression
# ['ADJ', 'NOUN']
# Entity
# event
#
# malignant tumor growth
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# mass extinction
# ['ADJ', 'NOUN']
# Event
# entity
#
# maternal effect
# ['ADJ', 'NOUN']
# Event
# entity
#
# mating factor
# ['NOUN', 'NOUN']
# Entity
# event
#
# mating factor A
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# mating factor a
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# mating factor alpha
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# mating type A
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# mating type a
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# mating type alpha
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# measure
# ['NOUN']
# Event
# entity
#
# mechanical digestion
# ['ADJ', 'NOUN']
# Event
# entity
#
# mechanical work
# ['ADJ', 'NOUN']
# Event
# entity
#
# medical procedure
# ['ADJ', 'NOUN']
# Event
# entity
#
# medicine
# ['NOUN']
# Event
# entity
#
# meiosis-I
# ['PROPN']
# Event
# entity
#
# meiosis-i
# ['PROPN']
# Event
# entity
#
# meiosis-II
# ['PROPN']
# Event
# entity
#
# meiotic event
# ['ADJ', 'NOUN']
# Event
# entity
#
# melanocyte stimulating hormone
# ['NOUN', 'VERB', 'NOUN']
# Entity
# event
#
# memory
# ['NOUN']
# Event
# entity
#
# mendelian genetics
# ['NOUN', 'NOUN']
# Event
# entity
#
# mendelism
# ['PROPN']
# Entity
# event
#
# menopause
# ['NOUN']
# Event
# entity
#
# period
# ['NOUN']
# Event
# entity
#
# menses
# ['NOUN']
# Event
# entity
#
# menstrual flow
# ['NOUN', 'NOUN']
# Event
# entity
#
# meroblastic cleavage
# ['ADJ', 'NOUN']
# Event
# entity
#
# metabolic disequilibrium
# ['NOUN', 'NOUN']
# Event
# entity
#
# metabolic pathway
# ['NOUN', 'NOUN']
# Event
# entity
#
# metaphase
# ['NOUN']
# Event
# entity
#
# metaphase-I
# ['PROPN', 'PUNCT', 'PRON']
# Event
# entity
#
# metaphase i
# ['NOUN', 'NUM']
# Event
# entity
#
# metaphase-II
# ['NOUN', 'PROPN']
# Event
# entity
#
# metaphase ii
# ['NOUN', 'NUM']
# Event
# entity
#
# metapopulation
# ['NOUN']
# Entity
# event
#
# met
# ['VERB']
# Entity
# event
#
# methylated compound
# ['VERB', 'NOUN']
# Entity
# event
#
# methylated DNA
# ['VERB', 'NOUN']
# Entity
# event
#
# methylated dna
# ['VERB', 'NOUN']
# Entity
# event
#
# enzyme of methylation
# ['NOUN', 'ADP', 'NOUN']
# Entity
# event
#
# methylation enzyme
# ['NOUN', 'NOUN']
# Entity
# event
#
# microclimate
# ['NOUN']
# Event
# entity
#
# microevolution
# ['NOUN']
# Event
# entity
#
# actin filament
# ['NOUN', 'NOUN']
# Entity
# event
#
# actin microfilament
# ['NOUN', 'NOUN']
# Entity
# event
#
# microfilament
# ['NOUN']
# Entity
# event
#
# actin-microfilament
# ['NOUN']
# Entity
# event
#
# microscopy
# ['NOUN']
# Event
# entity
#
# microtubule increase in length
# ['NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# microtubule contraction
# ['NOUN', 'NOUN']
# Event
# entity
#
# microtubule shorten
# ['NOUN', 'NOUN']
# Event
# entity
#
# mimicry
# ['NOUN']
# Event
# entity
#
# minimum viable population
# ['ADJ', 'ADJ', 'NOUN']
# Entity
# event
#
# minipill
# ['PROPN']
# Event
# entity
#
# misfolded protein
# ['VERB', 'NOUN']
# Entity
# event
#
# mismatch repair
# ['NOUN', 'NOUN']
# Event
# entity
#
# mismatched nucleotide
# ['VERB', 'NOUN']
# Entity
# event
#
# misplaced methyl group
# ['VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# mitotic event
# ['ADJ', 'NOUN']
# Event
# entity
#
# mitotic stage
# ['ADJ', 'NOUN']
# ...
# ['NOUN', 'ADP', 'ADJ', 'NOUN']
# Event
# entity
#
# secreting cell
# ['VERB', 'NOUN']
# Entity
# event
#
# secretory phase
# ['ADJ', 'NOUN']
# Event
# entity
#
# seedling
# ['NOUN']
# Entity
# event
#
# segment polarity gene
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# segmentation gene
# ['NOUN', 'NOUN']
# Entity
# event
#
# segmented embryo
# ['VERB', 'NOUN']
# Entity
# event
#
# segmented worm
# ['VERB', 'NOUN']
# Entity
# event
#
# sort
# ['NOUN']
# Event
# entity
#
# selection force
# ['NOUN', 'NOUN']
# Event
# entity
#
# self awareness
# ['PRON', 'NOUN']
# Event
# entity
#
# self-prune
# ['PRON', 'PUNCT', 'NOUN']
# Event
# entity
#
# big bang reproduction
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# semelparity
# ['NOUN']
# Event
# entity
#
# watson-&-crick-model
# ['PROPN', 'PUNCT', 'PROPN', 'PROPN', 'NOUN']
# Event
# entity
#
# semiconservative-model
# ['NOUN']
# Event
# entity
#
# watson-and-crick-model
# ['PROPN', 'PUNCT', 'CCONJ', 'PUNCT', 'PROPN', 'PUNCT', 'NOUN']
# Event
# entity
#
# semi-conservative-model
# ['ADJ']
# Event
# entity
#
# watson-crick-model
# ['PROPN', 'PUNCT', 'ADJ', 'NOUN']
# Event
# entity
#
# senescence
# ['NOUN']
# Event
# entity
#
# sensitive period
# ['ADJ', 'NOUN']
# Event
# entity
#
# sensory division
# ['ADJ', 'NOUN']
# Entity
# event
#
# sensory transduction
# ['ADJ', 'NOUN']
# Event
# entity
#
# separate
# ['ADJ']
# Event
# entity
#
# septic shock
# ['ADJ', 'NOUN']
# Event
# entity
#
# sequencing machine
# ['NOUN', 'NOUN']
# Entity
# event
#
# sex-linked gene
# ['NOUN', 'PUNCT', 'VERB', 'NOUN']
# Entity
# event
#
# sex linked gene
# ['NOUN', 'VERB', 'NOUN']
# Entity
# event
#
# sex-linked human genetic disorder
# ['NOUN', 'PUNCT', 'VERB', 'ADJ', 'ADJ', 'NOUN']
# Entity
# event
#
# sex-linked
# ['NOUN', 'PUNCT', 'VERB']
# Entity
# event
#
# sex linked human genetic disorder
# ['NOUN', 'VERB', 'ADJ', 'ADJ', 'NOUN']
# Entity
# event
#
# sex linked hemophilia gene
# ['NOUN', 'VERB', 'ADJ', 'NOUN']
# Entity
# event
#
# sexual dimorphism
# ['ADJ', 'NOUN']
# Event
# entity
#
# sexual intercourse
# ['ADJ', 'NOUN']
# Event
# entity
#
# sexual reproduction
# ['ADJ', 'NOUN']
# Event
# entity
#
# sexual selection
# ['ADJ', 'NOUN']
# Event
# entity
#
# cell showing shape-change
# ['NOUN', 'VERB', 'NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# shape changing cell
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# shear
# ['NOUN']
# Event
# entity
#
# shelled egg
# ['VERB', 'NOUN']
# Entity
# event
#
# shewanella oneidensis
# ['ADJ', 'ADJ']
# Entity
# event
#
# shiver
# ['NOUN']
# Event
# entity
#
# shoot
# ['VERB']
# Entity
# event
#
# shoot apical meristem
# ['VERB', 'ADJ', 'NOUN']
# Entity
# event
#
# shoot system
# ['VERB', 'NOUN']
# Entity
# event
#
# short term memory
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# sieve-tube element
# ['NOUN', 'PUNCT', 'NOUN', 'NOUN']
# Entity
# event
#
# sugar conducting cell
# ['NOUN', 'VERB', 'NOUN']
# Entity
# event
#
# sieve tube element
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# sight
# ['NOUN']
# Event
# entity
#
# signaling
# ['NOUN']
# Entity
# event
#
# signal transduction
# ['NOUN', 'NOUN']
# Event
# entity
#
# transduction
# ['NOUN']
# Event
# entity
#
# signal detection
# ['NOUN', 'NOUN']
# Event
# entity
#
# signal-recognition particle
# ['NOUN', 'PUNCT', 'NOUN', 'NOUN']
# Entity
# event
#
# signal recognition particle
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# signal transduction with Ca2 plus
# ['NOUN', 'NOUN', 'ADP', 'NOUN', 'CCONJ']
# Event
# entity
#
# signal transduction with ca2 plus
# ['NOUN', 'NOUN', 'ADP', 'NOUN', 'CCONJ']
# Event
# entity
#
# signal transduction with calmodulin
# ['NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# signal transduction with IP3
# ['NOUN', 'NOUN', 'ADP', 'PROPN']
# Event
# entity
#
# signal transduction with ip3
# ['NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# signal transduction with receptor bound to structural protein
# ['NOUN', 'NOUN', 'ADP', 'NOUN', 'ADJ', 'ADP', 'ADJ', 'NOUN']
# Event
# entity
#
# signal transduction with second messenger
# ['NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN']
# Event
# entity
#
# signal transduction with testosterone
# ['NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# repeated-sequence-dna
# ['VERB', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# single circulation
# ['ADJ', 'NOUN']
# Entity
# event
#
# single strand binding protein
# ['ADJ', 'NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# sleep
# ['NOUN']
# Event
# entity
#
# slight decrease of water temperature
# ['ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN']
# Event
# entity
#
# decrease
# ['NOUN']
# Event
# entity
#
# slow block
# ['ADJ', 'NOUN']
# Event
# entity
#
# small interfering RNA
# ['ADJ', 'NOUN', 'NOUN']
# Entity
# event
#
# small interfering rna
# ['ADJ', 'NOUN', 'NOUN']
# Entity
# event
#
# snowball Earth hypothesis
# ['NOUN', 'PROPN', 'NOUN']
# Entity
# event
#
# snowball earth hypothesis
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# social behavior
# ['ADJ', 'NOUN']
# Event
# entity
#
# sociobiology
# ['NOUN']
# Event
# entity
#
# sodium-gated-ion-channel
# ['NOUN', 'PUNCT', 'VERB', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# sodium gated ion-channel
# ['NOUN', 'VERB', 'NOUN']
# Entity
# event
#
# soil depletion
# ['NOUN', 'NOUN']
# Event
# entity
#
# soil to xylem pathway
# ['NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# solution containing labeled phage
# ['NOUN', 'VERB', 'VERB', 'NOUN']
# Entity
# event
#
# soredium
# ['ADJ']
# Event
# entity
#
# specialised organ
# ['VERB', 'NOUN']
# Entity
# event
#
# species interactions
# ['NOUN', 'NOUN']
# Event
# entity
#
# specimen stained with fluorescent substance
# ['NOUN', 'VERB', 'ADP', 'ADJ', 'NOUN']
# Entity
# event
#
# spectrophotometry
# ['NOUN']
# Event
# entity
#
# speechify
# ['PROPN']
# Event
# entity
#
# speech
# ['NOUN']
# Event
# entity
#
# spiral cleavage
# ['ADJ', 'NOUN']
# Event
# entity
#
# split gene
# ['VERB', 'NOUN']
# Entity
# event
#
# spontaneous change
# ['ADJ', 'NOUN']
# Event
# entity
#
# stage of protein folding
# ['NOUN', 'ADP', 'NOUN', 'NOUN']
# Entity
# event
#
# stained band
# ['VERB', 'NOUN']
# Entity
# event
#
# standing crop
# ['VERB', 'NOUN']
# Entity
# event
#
# starch storage by plant
# ['NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# start signal
# ['VERB', 'NOUN']
# Entity
# event
#
# initiation-codon
# ['NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# starving cell
# ['VERB', 'NOUN']
# Entity
# event
#
# sticky end fragment
# ['ADJ', 'NOUN', 'NOUN']
# Entity
# event
#
# stop signal
# ['VERB', 'NOUN']
# Entity
# event
#
# stop codon
# ['VERB', 'NOUN']
# Entity
# event
#
# storage polysaccharide breakdown
# ['NOUN', 'ADJ', 'NOUN']
# Event
# entity
#
# stratified squamous epithelium
# ['VERB', 'ADJ', 'NOUN']
# Entity
# event
#
# stress
# ['NOUN']
# Event
# entity
#
# striated muscle
# ['VERB', 'NOUN']
# Entity
# event
#
# study
# ['NOUN']
# Event
# entity
#
# study of membrane by electron microscopy
# ['NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', 'NOUN']
# Event
# entity
#
# water storing plant
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# sucking louse
# ['VERB', 'NOUN']
# Entity
# event
#
# sucrose transport from leaf
# ['NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# sulfate reducing bacterium
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# suspension
# ['NOUN']
# Entity
# event
#
# suspension feeder
# ['NOUN', 'NOUN']
# Entity
# event
#
# sustainable agriculture
# ['ADJ', 'NOUN']
# Event
# entity
#
# swim bladder
# ['VERB', 'NOUN']
# Entity
# event
#
# symmetrical distribution
# ['ADJ', 'NOUN']
# Event
# entity
#
# sympathetic division
# ['ADJ', 'NOUN']
# Entity
# event
#
# symplastic transport
# ['ADJ', 'NOUN']
# Event
# entity
#
# synthesis-of-cellular-membrane
# ['ADJ']
# Event
# entity
#
# synthesis-of-polynucleotide
# ['ADV']
# Event
# entity
#
# systematics
# ['NOUN']
# Event
# entity
#
# systems biology
# ['NOUN', 'NOUN']
# Event
# entity
#
# systole
# ['NOUN']
# Event
# entity
#
# transfer ribo-nucleic acid
# ['VERB', 'ADJ', 'NOUN']
# Entity
# event
#
# transfer ribonucleic acid
# ['VERB', 'ADJ', 'NOUN']
# Entity
# event
#
# tandemly repeated DNA
# ['ADV', 'VERB', 'NOUN']
# Entity
# event
#
# tandemly repeated dna
# ['ADV', 'VERB', 'NOUN']
# Entity
# event
#
# target destination
# ['NOUN', 'NOUN']
# Entity
# event
#
# taxis
# ['NOUN']
# Event
# entity
#
# taxonomy
# ['NOUN']
# Event
# entity
#
# gm2 gangliosidosis
# ['ADJ', 'NOUN']
# Entity
# event
#
# technique
# ['NOUN']
# Event
# entity
#
# telophase
# ['PROPN']
# Event
# entity
#
# telophase-I
# ['PROPN', 'PUNCT', 'PRON']
# Event
# entity
#
# telophase i
# ['INTJ', 'X']
# Event
# entity
#
# telophase-II
# ['PROPN', 'PUNCT', 'NUM']
# Event
# entity
#
# telophase ii
# ['PROPN', 'NUM']
# Event
# entity
#
# land dwelling organism
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# territoriality
# ['NOUN']
# Event
# entity
#
# third stage of protein folding
# ['ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN']
# Entity
# event
#
# testcross
# ['PROPN']
# Event
# entity
#
# test cross
# ['NOUN', 'NOUN']
# Event
# entity
#
# testosterone secretion in males
# ['NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# somatic cell nuclear transfer
# ['ADJ', 'NOUN', 'ADJ', 'NOUN']
# Event
# entity
#
# thermal energy increase in organism
# ['ADJ', 'NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# thermal motion
# ['ADJ', 'NOUN']
# Event
# entity
#
# thermocycler
# ['NOUN']
# Entity
# event
#
# thermal-cycler
# ['ADJ']
# Entity
# event
#
# thermalcycler
# ['NOUN']
# Entity
# event
#
# thermodynamics
# ['NOUN']
# Event
# entity
#
# thick filament
# ['ADJ', 'NOUN']
# Entity
# event
#
# thigmotropism
# ['NOUN']
# Event
# entity
#
# thin filament
# ['ADJ', 'NOUN']
# Entity
# event
#
# threatened species
# ['VERB', 'NOUN']
# Entity
# event
#
# time span
# ['NOUN', 'NOUN']
# Event
# entity
#
# tissue repair
# ['NOUN', 'NOUN']
# Event
# entity
#
# tomato fasciated gene
# ['NOUN', 'VERB', 'NOUN']
# Entity
# event
#
# tonicity
# ['NOUN']
# Event
# entity
#
# torpor
# ['NOUN']
# Event
# entity
#
# touch
# ['NOUN']
# Event
# entity
#
# trace chemical entity
# ['VERB', 'ADJ', 'NOUN']
# Entity
# event
#
# trace element
# ['NOUN', 'NOUN']
# Entity
# event
#
# trade
# ['NOUN']
# Event
# entity
#
# trailer segment
# ['NOUN', 'NOUN']
# Entity
# event
#
# evolutionary adaptation
# ['ADJ', 'NOUN']
# Entity
# event
#
# transcribed terminator
# ['VERB', 'NOUN']
# Entity
# event
#
# general transcription factor
# ['ADJ', 'NOUN', 'NOUN']
# Entity
# event
#
# transcription factor
# ['NOUN', 'NOUN']
# Entity
# event
#
# sequence-specific dna binding factor
# ['NOUN', 'PUNCT', 'ADJ', 'NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# transcription factor gene
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# transcription initiation complex
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# transcription unit
# ['NOUN', 'NOUN']
# Entity
# event
#
# transduce
# ['PROPN']
# Event
# entity
#
# transduction gene transfer
# ['NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# transfer of malate to bundle sheath cell
# ['NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# transformed cell
# ['VERB', 'NOUN']
# Entity
# event
#
# transformed bacterial cell
# ['VERB', 'ADJ', 'NOUN']
# Entity
# event
#
# transgenic organism for clotting factor manufacture
# ['ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# transition state
# ['NOUN', 'NOUN']
# Entity
# event
#
# transition state intermediate
# ['VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# translation assembly
# ['NOUN', 'NOUN']
# Entity
# event
#
# translation initiation complex
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# translation-initiation-complex
# ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# transmembrane transport
# ['ADJ', 'NOUN']
# Event
# entity
#
# transmission electron microscope
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# transmitting cell
# ['VERB', 'NOUN']
# Entity
# event
#
# transpirational pull
# ['ADJ', 'NOUN']
# Event
# entity
#
# transplant rejection
# ['ADJ', 'NOUN']
# Event
# entity
#
# transplanted species
# ['VERB', 'NOUN']
# Entity
# event
#
# transport of cholesterol in blood
# ['NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# transport of pyruvate from cytosol to mitochondrion
# ['NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# transport work
# ['NOUN', 'NOUN']
# Event
# entity
#
# transposable-genetic-element
# ['ADJ']
# Entity
# event
#
# mobile-segment
# ['NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# jumping-gene
# ['NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# jumping gene
# ['VERB', 'NOUN']
# Entity
# event
#
# mobile-segment-of-dna
# ['ADJ', 'PUNCT', 'NOUN', 'PUNCT', 'ADP', 'PUNCT', 'NOUN']
# Entity
# event
#
# mobile-genetic-element
# ['ADJ']
# Entity
# event
#
# triple response
# ['NOUN', 'NOUN']
# Event
# entity
#
# tropism
# ['NOUN']
# Event
# entity
#
# true-breeding
# ['ADJ', 'PUNCT', 'NOUN']
# Entity
# event
#
# true breeding
# ['ADJ', 'NOUN']
# Entity
# event
#
# tubectomy
# ['NOUN']
# Event
# entity
#
# tuberculosis
# ['NOUN']
# Entity
# event
#
# consumption
# ['NOUN']
# Entity
# event
#
# tumor growth
# ['NOUN', 'NOUN']
# Event
# entity
#
# virus associated with cancer
# ['NOUN', 'VERB', 'ADP', 'NOUN']
# Entity
# event
#
# turgid
# ['ADJ']
# Event
# entity
#
# turnover
# ['NOUN']
# Event
# entity
#
# twin study
# ['NOUN', 'NOUN']
# Event
# entity
#
# twist
# ['NOUN']
# Event
# entity
#
# two cell stage
# ['NUM', 'NOUN', 'NOUN']
# Event
# entity
#
# ubiquitin conjugating enzyme
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# uncoupling protein
# ['NOUN', 'NOUN']
# Entity
# event
#
# undifferentiated cell
# ['VERB', 'NOUN']
# Entity
# event
#
# undifferentiated embryonic cell
# ['VERB', 'ADJ', 'NOUN']
# Entity
# event
#
# unfolded protein
# ['VERB', 'NOUN']
# Entity
# event
#
# uniformitarianism
# ['NOUN']
# Event
# entity
#
# unlinked gene
# ['VERB', 'NOUN']
# Entity
# event
#
# uptake of calcium ion by chloroplast
# ['NOUN', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# uptake of calcium ion by endoplasmic reticulum
# ['NOUN', 'ADP', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN']
# Event
# entity
#
# uptake of calcium ion by mitochondria
# ['NOUN', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# cholesterol uptake
# ['NOUN', 'NOUN']
# Event
# entity
#
# uptake of cholesterol by human cell
# ['NOUN', 'ADP', 'NOUN', 'ADP', 'ADJ', 'NOUN']
# Event
# entity
#
# uptake of hydrogen ion by base
# ['NOUN', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# VA element
# ['PROPN', 'NOUN']
# Entity
# event
#
# va element
# ['PROPN', 'NOUN']
# Entity
# event
#
# VIA chalcogen element
# ['ADP', 'NOUN', 'NOUN']
# Entity
# event
#
# via chalcogen element
# ['ADP', 'NOUN', 'NOUN']
# Entity
# event
#
# viia halogen element
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# medical weapon used to fight viral infections
# ['ADJ', 'NOUN', 'VERB', 'PART', 'VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# innoculation
# ['NOUN']
# Entity
# event
#
# medical weapon used to fight virus
# ['ADJ', 'NOUN', 'VERB', 'PART', 'VERB', 'NOUN']
# Entity
# event
#
# van der waals interaction
# ['PROPN', 'PROPN', 'VERB', 'NOUN']
# Entity
# event
#
# van der waals force
# ['PROPN', 'PROPN', 'VERB', 'NOUN']
# Entity
# event
#
# vasectomy
# ['NOUN']
# Event
# entity
#
# vasocongestion
# ['ADJ']
# Event
# entity
#
# vasoconstriction
# ['NOUN']
# Event
# entity
#
# blood vessel constriction
# ['NOUN', 'NOUN', 'NOUN']
# Event
# entity
#
# vegetation
# ['NOUN']
# Entity
# event
#
# vegetative reproduction
# ['ADJ', 'NOUN']
# Event
# entity
#
# flow of air
# ['NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# vertical gene transfer
# ['ADJ', 'NOUN', 'NOUN']
# Event
# entity
#
# vessel element
# ['NOUN', 'NOUN']
# Entity
# event
#
# cholera causing bacteria
# ['NOUN', 'VERB', 'NOUN']
# Entity
# event
#
# cholera causing agent
# ['NOUN', 'VERB', 'NOUN']
# Entity
# event
#
# viral infection
# ['ADJ', 'NOUN']
# Event
# entity
#
# viral spread
# ['NOUN', 'NOUN']
# Event
# entity
#
# viral reproduction
# ['ADJ', 'NOUN']
# Event
# entity
#
# virus spread
# ['NOUN', 'NOUN']
# Event
# entity
#
# virus reproduction
# ['NOUN', 'NOUN']
# Event
# entity
#
# VirusInfection
# ['PROPN']
# Event
# entity
#
# virusinfection
# ['NOUN']
# Event
# entity
#
# visual pigment
# ['ADJ', 'NOUN']
# Entity
# event
#
# viviparous
# ['NOUN']
# Event
# entity
#
# voltage-gated ion-channel
# ['NOUN', 'PUNCT', 'VERB', 'NOUN']
# Entity
# event
#
# voltage gated ion channel
# ['NOUN', 'VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# walled cell
# ['VERB', 'NOUN']
# Entity
# event
#
# walled cell inside hypertonic solution
# ['VERB', 'NOUN', 'ADP', 'ADJ', 'NOUN']
# Entity
# event
#
# walled cell inside hypotonic solution
# ['VERB', 'NOUN', 'ADP', 'ADJ', 'NOUN']
# Entity
# event
#
# walled cell inside isotonic solution
# ['VERB', 'NOUN', 'ADP', 'ADJ', 'NOUN']
# Entity
# event
#
# walled protist cell
# ['VERB', 'NOUN', 'NOUN']
# Entity
# event
#
# walther flemming
# ['PROPN', 'PROPN']
# Entity
# event
#
# waste product
# ['VERB', 'NOUN']
# Entity
# event
#
# waste
# ['VERB']
# Entity
# event
#
# water conducting cell
# ['NOUN', 'VERB', 'NOUN']
# Entity
# event
#
# water transport in plant
# ['NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# wilt
# ['PROPN']
# Event
# entity
#
# wind
# ['NOUN']
# Event
# entity
#
# breeze
# ['NOUN']
# Event
# entity
#
# wing
# ['NOUN']
# Entity
# event
#
# wobble hypothesis
# ['NOUN', 'NOUN']
# Entity
# event
#
# work
# ['NOUN']
# Event
# entity
#
# wound repair
# ['NOUN', 'NOUN']
# Event
# entity
#
# wound repair in liver
# ['NOUN', 'NOUN', 'ADP', 'NOUN']
# Event
# entity
#
# X-ray crystallography
# ['PROPN', 'PROPN', 'NOUN']
# Event
# entity
#
# x ray crystallography
# ['PROPN', 'PROPN', 'NOUN']
# Event
# entity
#
# Y-linked inheritance
# ['ADJ', 'NOUN']
# Event
# entity
#
# yeast mating factor
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# yeast transcription factor gene
# ['NOUN', 'NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# yeasted bread
# ['VERB', 'NOUN']
# Entity
# event
#
# z-filament
# ['NOUN', 'PUNCT', 'NOUN']
# Entity
# event
#
# Z line filament
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# z line filament
# ['NOUN', 'NOUN', 'NOUN']
# Entity
# event
#
# zebrafish developmental genetics
# ['NOUN', 'ADJ', 'NOUN']
# Event
# entity
#
# zone of polarizing activity
# ['NOUN', 'ADP', 'VERB', 'NOUN']
# Entity
# event
#
# zoned reserve
# ['VERB', 'NOUN']
# Entity
# event
#
# fertilized-egg
# ['VERB', 'PUNCT', 'NOUN']
# Entity
# event

# %%
print(len(correct))
print(len(errors))
print(len(correct) / (len(correct) + len(errors)))
# Out:
# 7587
# 1580
# 0.8276426311770481
