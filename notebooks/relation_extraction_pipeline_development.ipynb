# %% [markdown]
# # RE Data Pipeline Development
#
# 1. Extract Relation Triples
#   1. Take existing lexicon of all nominalizations/synonyms for each base noun/verb concept. Condense these into unique lemmatized versions. (cache for re-use)
#   2. Take all taxonomy, process, and structure relations & lemmatize arguments for relations (cache for re-use)
#   3. Create dictionary mapping relation type (meronym, etc.) -> relation (has-part, etc.) -> dictionary with entity/event pairs as keys
#   4. Find way to extract no-relation terms
# 2. Tag Sentences w/ Relations
#   1. Take all extracted biology sentences and spacy process (cache for re-use)
#   2. For each relation, check each sentence for existence of term pair. If exists, add sentence with <e1> and <e2> tags denoting location of terms to appropriate list in dictionary.
#
# Result will be json file corresponding to dictionary mapping relation type (meronym, etc.) -> relation (has-part, etc.) -> entity/event pairs as keys -> list of sentences expressing such a relation

# %%
import pandas as pd
import json
from io import StringIO
import spacy
from collections import defaultdict

import stanfordnlp
from spacy_stanfordnlp import StanfordNLPLanguage
snlp = stanfordnlp.Pipeline(lang="en")
nlp = StanfordNLPLanguage(snlp)

import warnings
warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2

# fix for importing utils
import os
import sys
module_path = os.path.abspath(os.path.join('../utils'))
if module_path not in sys.path:
    sys.path.append(module_path)
from utils import write_spacy_docs, read_spacy_docs, tag_bioes
from data_processing import get_closest_match

data_dir = "../data/relation_extraction"
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_tagger.pt', 'pretrain_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_lemmatizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_parser.pt', 'pretrain_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Done loading processors!
# ---
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 1. Extract Relation Triples
#
# First we condense all equivalent lexicon representations for a concept and spacy pre-process these lexical forms

# %%
def process_lexicon(lexicon_file):
    """ Takes in a lexicon file consisting of concept text representation pairs and turns this into a list
    of Spacy processed terms and a lexicon csv mapping KB concepts to lists of text representations and their lemma forms.
    
    """
    
    with open(lexicon_file, "r") as f:
        lexicon = f.read()
    
    # get rid of extra column and read in as dataframe
    lexicon = lexicon.replace(' | "n"', '').replace('"', '')
    lexicon = pd.read_csv(StringIO(lexicon), sep="\s*\|\s*", header=None, names=["concept", "relation", "text"])

    # create mapping from kb concept to unique text representations
    lexicon = lexicon[~lexicon.text.str.contains("Concept-Word-Frame")]
    lexicon = lexicon.groupby("concept")["text"].apply(lambda x: list(set(x))).reset_index()

    # spacy process terms to get lemmas
    spacy_terms = []
    lemmas = []
    for concept in lexicon.concept:
        terms = list(lexicon.loc[lexicon.concept == concept, "text"])[0]
        spacy_terms_tmp = [nlp(term) for term in terms]
        lemma_terms = list([" ".join([tok.lemma_ for tok in t]) for t in spacy_terms_tmp])
        spacy_terms += spacy_terms_tmp
        lemmas.append(lemma_terms)

    lexicon["lemmas"] = lemmas
    return spacy_terms, lexicon

terms, lexicon = process_lexicon(f"{data_dir}/raw_data/kb_lexicon_nouns.txt")
write_spacy_docs(terms, f"{data_dir}/processed_data/kb_terms_spacy")
lexicon.to_csv(f"{data_dir}/processed_data/lexicon.csv", index=False)

# %%
lexicon
# Out:
#                       concept                                       text  \
# 0     1,3-Bisphosphoglycerate            [PGAP, 1,3-bisphosphoglycerate]
# 1                 3-Prime-End                      [3'-end, 3 prime end]
# 2                 5-Prime-End      [5'-end, 5 prime end, five-prime-end]
# 3          5-Prime-Nucleotide  [5' base, 5'-nucleotide, five prime base]
# 4                   A-Antigen                [A antigen, carbohydrate-a]
# ...                       ...                                        ...
# 2727            Zoned-Reserve                            [zoned reserve]
# 2728                 Zoospore                                 [zoospore]
# 2729               Zygomycete                   [zygomycota, zygomycete]
# 2730           Zygosporangium                           [zygosporangium]
# 2731                   Zygote                   [zygote, fertilized-egg]
#
#                                             lemmas
# 0                  [pgap, 1,3-bisphosphoglycerate]
# 1                          [3 '- end, 3 prime end]
# 2      [5 '- end, 5 prime end, five - prime - end]
# 3     [5 ' base, 5 '- nucleotide, five prime base]
# 4                      [a antigen, carbohydrate-a]
# ...                                            ...
# 2727                                [zone reserve]
# 2728                                    [zoospore]
# 2729                      [zygomycota, zygomycete]
# 2730                              [zygosporangium]
# 2731                     [zygote, fertilize - egg]
#
# [2732 rows x 3 columns]

# %% [markdown]
# Next we extract all relations accounting for lexicon variability

# %%
import itertools
import re
import string

def extract_lemmas(lexicon, concept, instance):
    """ For a given concept, text representation in a relation this function 
    extracts all lemma representations of that concept and the associated text representations.
    """
    
    # pull out equivalent lemma, text representations from lexicon
    if concept in lexicon.concept:
        instance_texts = lexicon.at[lexicon.concept == concept, "text"]
        instance_lemmas = lexicon.at[lexicon.concept == concept, "lemma"]
    else:
        instance_texts = []
        instance_lemmas = []
        
    # add particular text from relation if not present
    if instance not in instance_texts:
        instance_texts.append(instance)
        instance_lemmas.append(" ".join([tok.lemma_ for tok in nlp(instance)]))
        
    # create a dictionary mapping all lemma forms to corresponding text forms for this concept
    instance_pairs = {}
    for lemma, text in zip(instance_lemmas, instance_texts):
        if lemma in instance_pairs:
            instance_pairs[lemma].append(text)
        else:
            instance_pairs[lemma] = [text]
            
    return instance_pairs

def parse_relations(file, relation_type, lexicon, relations_db, include_relations=None):
    """ Parses all relations from a text file containing relations and adds them to
    the relations database.
    
    1. Parse each relation into concepts, relations, and text representation
    2. Extract all unique lemma representations and associated text representations for each entity/event pair
    3. Add each unique relation pair to the relations database
    
    """
    with open(file) as f:
        data = f.readlines()
    
    for i, r in enumerate(data):
    
        if i % 100 == 0:
            print(i)
    
        if relation_type == "taxonomy":
            c1, e1, relation, c2, e2 = [tok.strip() for tok in r.split("|")]
        elif relation_type == "structure":
            _, _, c1, e1, relation, c2, e2 = [tok.strip() for tok in r.split("|")]

            c1 = c1.strip("_").replace("_ABOX_", "").rstrip(string.digits)
            c2 = c2.strip("_").replace("_ABOX_", "").rstrip(string.digits)
        
        if include_relations and relation not in include_relations:
            continue
    
        if relation not in relations_db:
            relations_db[relation] = {}
        
        e1_pairs = extract_lemmas(lexicon, c1, e1)
        e2_pairs = extract_lemmas(lexicon, c2, e2)
        
        for pair in itertools.product(e1_pairs.keys(), e2_pairs.keys()):
            relations_db[relation][" -> ".join(pair)] = {"sentences": [], 
                                                         "e1_representations": e1_pairs[pair[0]], 
                                                         "e2_representations": e2_pairs[pair[1]]}
    
    return relations_db
    
meronym_relations = ["has-part", "has-region", "element", "possesses", "material"]
spatial_relations = ["is-at", "is-inside", "is-outside", "abuts", "between"]
taxonomy_relations = ["subclass-of", "instance-of"]
include_relations = meronym_relations + spatial_relations + taxonomy_relations

relations_db = {"no-relation": {}}
for relation_type in ["taxonomy", "structure"]:
    file = f"{data_dir}/raw_data/{relation_type}_relations.txt"
    relations_db = parse_relations(file, relation_type, lexicon, relations_db, include_relations)
    
with open(f"{data_dir}/processed_data/relations_db_intermediate.json", "w") as f:
    json.dump(relations_db, f, indent=4)
relations_db
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000
# 21100
# 21200
# 21300
# 21400
# 21500
# 21600
# 21700
# 21800
# 21900
# 22000
# 22100
# 22200
# 22300
# 22400
# 22500
# 22600
# 22700
# 22800
# 22900
# 23000
# 23100
# 23200
# 23300
# 23400
# 23500
# 23600
# 23700
# 23800
# 23900
# 24000
# 24100
# 24200
# 24300
# 24400
# 24500
# 24600
# 24700
# 24800
# 24900
# 25000
# 25100
# 25200
# 25300
# 25400
# 25500
# 25600
# 25700
# 25800
# 25900
# 26000
# 26100
# 26200
# 26300
# 26400
# 26500
# 26600
# 26700
# 26800
# 26900
# 27000
# 27100
# 27200
# 27300
# 27400
# 27500
# 27600
# 27700
# 27800
# 27900
# 28000
# 28100
# 28200
# 28300
# 28400
# 28500
# 28600
# 28700
# 28800
# 28900
# 29000
# 29100
# 29200
# 29300
# 29400
# 29500
# 29600
# 29700
# 29800
# 29900
# 30000
# 30100
# 30200
# 30300
# 30400
# 30500
# 30600
# 30700
# 30800
# 30900
# 31000
# 31100
# 31200
# 31300
# 31400
# 31500
# 31600
# 31700
# 31800
# 31900
# 32000
# 32100
# 32200
# 32300
# 32400
# 32500
# 32600
# 32700
# 32800
# 32900
# 33000
# 33100
# 33200
# 33300
# 33400
# 33500
# 33600
# 33700
# 33800
# 33900
# 34000
# 34100
# 34200
# 34300
# 34400
# 34500
# 34600
# 34700
# 34800
# 34900
# 35000
# 35100
# 35200
# 35300
# 35400
# 35500
# 35600
# 35700
# 35800
# 35900
# 36000
# 36100
# 36200
# 36300
# 36400
# 36500
# 36600
# 36700
# 36800
# 36900
# 37000
# 37100
# 37200
# 37300
# 37400
# 37500
# 37600
# 37700
# 37800
# 37900
# 38000
# 38100
# 38200
# 38300
# 38400
# 38500
# 38600
# 38700
# 38800
# 38900
# 39000
# 39100
# 39200
# 39300
# 39400
# 39500
# 39600
# 39700
# 39800
# 39900
# 40000
# 40100
# 40200
# 40300
# 40400
# 40500
# 40600
# 40700
# 40800
# 40900
# 41000
# 41100
# 41200
# 41300
# 41400
# 41500
# 41600
# 41700
# 41800
# 41900
# 42000
# 42100
# 42200
# 42300
# 42400
# 42500
# 42600
# 42700
# 42800
# 42900
# 43000
# 43100
# 43200
# 43300
# 43400
# 43500
# 43600
# 43700
# 43800
# 43900
# 44000
# 44100
# 44200
# 44300
# 44400
# {'no-relation': {},
#  'subclass-of': {'chemical -> substance': {'sentences': [],
#    'e1_representations': ['chemical'],
#    'e2_representations': ['substance']},
#   'chemical -> object': {'sentences': [],
#    'e1_representations': ['chemical'],
#    'e2_representations': ['object']},
#   'role -> thing': {'sentences': [],
#    'e1_representations': ['role'],
#    'e2_representations': ['thing']},
#   'mixture -> substance': {'sentences': [],
#    'e1_representations': ['mixture'],
#    'e2_representations': ['substance']},
#   'aggregate -> object': {'sentences': [],
#    'e1_representations': ['aggregate'],
#    'e2_representations': ['object']},
#   'region -> object': {'sentences': [],
#    'e1_representations': ['region'],
#    'e2_representations': ['object']},
#   'community -> aggregate': {'sentences': [],
#    'e1_representations': ['community'],
#    'e2_representations': ['aggregate']},
#   'animate thing -> object': {'sentences': [],
#    'e1_representations': ['animate thing'],
#    'e2_representations': ['object']},
#   'animate thing -> organic entity': {'sentences': [],
#    'e1_representations': ['animate thing'],
#    'e2_representations': ['organic entity']},
#   'information -> conceptual entity': {'sentences': [],
#    'e1_representations': ['information'],
#    'e2_representations': ['conceptual entity']},
#   'conceptual entity -> intangible entity': {'sentences': [],
#    'e1_representations': ['conceptual entity'],
#    'e2_representations': ['intangible entity']},
#   'non metal atom -> atom': {'sentences': [],
#    'e1_representations': ['non metal atom'],
#    'e2_representations': ['atom']},
#   'metal atom -> atom': {'sentences': [],
#    'e1_representations': ['metal atom'],
#    'e2_representations': ['atom']},
#   'metalloid atom -> atom': {'sentences': [],
#    'e1_representations': ['metalloid atom'],
#    'e2_representations': ['atom']},
#   'VIIA -> chemical element': {'sentences': [],
#    'e1_representations': ['VIIA'],
#    'e2_representations': ['chemical element']},
#   'acid compound -> compound': {'sentences': [],
#    'e1_representations': ['acid compound'],
#    'e2_representations': ['compound']},
#   'pgap -> phosphorylate intermediate': {'sentences': [],
#    'e1_representations': ['PGAP'],
#    'e2_representations': ['phosphorylated intermediate']},
#   '3 - prime carbon -> carbon atom': {'sentences': [],
#    'e1_representations': ['3-prime carbon'],
#    'e2_representations': ['carbon atom']},
#   '3 prime end -> nucleic acid region': {'sentences': [],
#    'e1_representations': ['3 prime end'],
#    'e2_representations': ['nucleic acid region']},
#   '3 - prime region -> nucleic acid region': {'sentences': [],
#    'e1_representations': ['3-prime region'],
#    'e2_representations': ['nucleic acid region']},
#   '5 - prime carbon -> carbon atom': {'sentences': [],
#    'e1_representations': ['5-prime carbon'],
#    'e2_representations': ['carbon atom']},
#   '5 prime end -> nucleic acid region': {'sentences': [],
#    'e1_representations': ['5 prime end'],
#    'e2_representations': ['nucleic acid region']},
#   '5 - prime nucleotide -> nucleotide': {'sentences': [],
#    'e1_representations': ['5-prime nucleotide'],
#    'e2_representations': ['nucleotide']},
#   '5 - prime region -> nucleic acid region': {'sentences': [],
#    'e1_representations': ['5-prime region'],
#    'e2_representations': ['nucleic acid region']},
#   'a antigen -> blood carbohydrate': {'sentences': [],
#    'e1_representations': ['A antigen'],
#    'e2_representations': ['blood carbohydrate']},
#   'a band -> biological region': {'sentences': [],
#    'e1_representations': ['A band'],
#    'e2_representations': ['biological region']},
#   'A - site -> ribosome region': {'sentences': [],
#    'e1_representations': ['A-Site'],
#    'e2_representations': ['ribosome region']},
#   'abdome -> segment of body': {'sentences': [],
#    'e1_representations': ['abdomen'],
#    'e2_representations': ['segment of body']},
#   'abdominal cavity -> animal space': {'sentences': [],
#    'e1_representations': ['abdominal cavity'],
#    'e2_representations': ['animal space']},
#   'abiotic factor -> ecological role': {'sentences': [],
#    'e1_representations': ['abiotic factor'],
#    'e2_representations': ['ecological role']},
#   'abnormal clone embryo -> embryo': {'sentences': [],
#    'e1_representations': ['abnormal cloned embryo'],
#    'e2_representations': ['embryo']},
#   'abnormal clone embryo -> clone': {'sentences': [],
#    'e1_representations': ['abnormal cloned embryo'],
#    'e2_representations': ['clone']},
#   'abnormal -> role': {'sentences': [],
#    'e1_representations': ['abnormal'],
#    'e2_representations': ['role']},
#   'abo blood group -> gene with multiple alleles': {'sentences': [],
#    'e1_representations': ['ABO blood group'],
#    'e2_representations': ['gene with multiple alleles']},
#   'abomasum -> digestive organ': {'sentences': [],
#    'e1_representations': ['abomasum'],
#    'e2_representations': ['digestive organ']},
#   'abortion -> medical procedure': {'sentences': [],
#    'e1_representations': ['abortion'],
#    'e2_representations': ['medical procedure']},
#   'abrade -> make contact': {'sentences': [],
#    'e1_representations': ['abrade'],
#    'e2_representations': ['make contact']},
#   'abscisic acid -> plant hormone': {'sentences': [],
#    'e1_representations': ['abscisic acid'],
#    'e2_representations': ['plant hormone']},
#   'absolute dating -> radiometric dating': {'sentences': [],
#    'e1_representations': ['absolute dating'],
#    'e2_representations': ['radiometric dating']},
#   'absorption in small intestine -> digestive process': {'sentences': [],
#    'e1_representations': ['absorption in small intestine'],
#    'e2_representations': ['digestive process']},
#   'absorption of energy by electron -> take in': {'sentences': [],
#    'e1_representations': ['absorption of energy by electron'],
#    'e2_representations': ['take In']},
#   'absorption of fat in small intestine -> digestive process': {'sentences': [],
#    'e1_representations': ['absorption of fats in small intestine'],
#    'e2_representations': ['digestive process']},
#   'absorption spectrum -> graphical representation': {'sentences': [],
#    'e1_representations': ['absorption spectrum'],
#    'e2_representations': ['graphical representation']},
#   'absorptive process -> animal process': {'sentences': [],
#    'e1_representations': ['absorptive process'],
#    'e2_representations': ['animal process']},
#   'abyssal zone -> aquatic zone': {'sentences': [],
#    'e1_representations': ['abyssal zone'],
#    'e2_representations': ['aquatic zone']},
#   'acacia tree -> eudicot': {'sentences': [],
#    'e1_representations': ['acacia tree'],
#    'e2_representations': ['eudicot']},
#   'acanthodian -> early vertebrate': {'sentences': [],
#    'e1_representations': ['acanthodian'],
#    'e2_representations': ['early vertebrate']},
#   'acanthodian -> extinct vertebrate': {'sentences': [],
#    'e1_representations': ['acanthodian'],
#    'e2_representations': ['extinct vertebrate']},
#   'accessory fruit -> fruit': {'sentences': [],
#    'e1_representations': ['accessory fruit'],
#    'e2_representations': ['fruit']},
#   'accessory pigment -> antenna pigment': {'sentences': [],
#    'e1_representations': ['accessory pigment'],
#    'e2_representations': ['antenna pigment']},
#   'acclimatization -> homeostatic response': {'sentences': [],
#    'e1_representations': ['acclimatization'],
#    'e2_representations': ['homeostatic response']},
#   'acetaldehyde substance -> substance': {'sentences': [],
#    'e1_representations': ['acetaldehyde substance'],
#    'e2_representations': ['substance']},
#   'acetaldehyde -> aldehyde': {'sentences': [],
#    'e1_representations': ['acetaldehyde'],
#    'e2_representations': ['aldehyde']},
#   'acetate -> ester': {'sentences': [],
#    'e1_representations': ['acetate'],
#    'e2_representations': ['ester']},
#   'acetic acid -> carboxylic acid': {'sentences': [],
#    'e1_representations': ['acetic acid'],
#    'e2_representations': ['carboxylic acid']},
#   'acetone -> ketone': {'sentences': [],
#    'e1_representations': ['acetone'],
#    'e2_representations': ['ketone']},
#   'acetyl coa -> ester': {'sentences': [],
#    'e1_representations': ['acetyl CoA'],
#    'e2_representations': ['ester']},
#   'acetyl group -> functional group': {'sentences': [],
#    'e1_representations': ['acetyl group'],
#    'e2_representations': ['functional group']},
#   'acetylcholine -> neurotransmitter': {'sentences': [],
#    'e1_representations': ['acetylcholine'],
#    'e2_representations': ['neurotransmitter']},
#   'acetylcholinesterase -> hydrolase': {'sentences': [],
#    'e1_representations': ['acetylcholinesterase'],
#    'e2_representations': ['Hydrolase']},
#   'achondroplasia -> human genetic disorder': {'sentences': [],
#    'e1_representations': ['achondroplasia'],
#    'e2_representations': ['human genetic disorder']},
#   'acid chyme -> organic entity': {'sentences': [],
#    'e1_representations': ['acid chyme'],
#    'e2_representations': ['organic entity']},
#   'acid chyme -> heterogeneous mixture': {'sentences': [],
#    'e1_representations': ['acid chyme'],
#    'e2_representations': ['heterogeneous mixture']},
#   'acid dissociation reaction -> reversible reaction': {'sentences': [],
#    'e1_representations': ['acid dissociation reaction'],
#    'e2_representations': ['reversible reaction']},
#   'acid dissociation reaction -> chemical dissociation reaction': {'sentences': [],
#    'e1_representations': ['acid dissociation reaction'],
#    'e2_representations': ['chemical dissociation reaction']},
#   'acid precipitation -> precipitation': {'sentences': [],
#    'e1_representations': ['acid precipitation'],
#    'e2_representations': ['precipitation']},
#   'acid precipitation -> human drive disturbance': {'sentences': [],
#    'e1_representations': ['acid precipitation'],
#    'e2_representations': ['human driven disturbance']},
#   'acid reflux -> animal process': {'sentences': [],
#    'e1_representations': ['acid reflux'],
#    'e2_representations': ['animal process']},
#   'acid -> chemical': {'sentences': [],
#    'e1_representations': ['acid'],
#    'e2_representations': ['chemical']},
#   'acidic amino acid -> electrically charge amino acid': {'sentences': [],
#    'e1_representations': ['acidic amino acid'],
#    'e2_representations': ['electrically charged amino acid']},
#   'acidic solution of weak acid -> acidic solution': {'sentences': [],
#    'e1_representations': ['acidic solution of weak acid'],
#    'e2_representations': ['acidic solution']},
#   'acidic solution -> aqueous solution': {'sentences': [],
#    'e1_representations': ['acidic solution'],
#    'e2_representations': ['aqueous solution']},
#   'acoela -> animal': {'sentences': [],
#    'e1_representations': ['acoela'],
#    'e2_representations': ['animal']},
#   'acrosomal reaction -> animal fertilization': {'sentences': [],
#    'e1_representations': ['acrosomal reaction'],
#    'e2_representations': ['animal fertilization']},
#   'acrosome -> vesicle': {'sentences': [],
#    'e1_representations': ['acrosome'],
#    'e2_representations': ['vesicle']},
#   'actin -> globular protein': {'sentences': [],
#    'e1_representations': ['actin'],
#    'e2_representations': ['globular protein']},
#   'actinium atom -> metal atom': {'sentences': [],
#    'e1_representations': ['actinium atom'],
#    'e2_representations': ['metal atom']},
#   'actinopod -> amoeba': {'sentences': [],
#    'e1_representations': ['actinopod'],
#    'e2_representations': ['amoeba']},
#   'actinopterygii -> ray - fin fish': {'sentences': [],
#    'e1_representations': ['Actinopterygii'],
#    'e2_representations': ['ray-finned fish']},
#   'action potential -> change in membrane potential': {'sentences': [],
#    'e1_representations': ['action potential'],
#    'e2_representations': ['change in membrane potential']},
#   'action spectrum -> graphical representation': {'sentences': [],
#    'e1_representations': ['action spectrum'],
#    'e2_representations': ['graphical representation']},
#   'activation energy -> energy': {'sentences': [],
#    'e1_representations': ['activation energy'],
#    'e2_representations': ['energy']},
#   'activation of atp synthase -> cellular process': {'sentences': [],
#    'e1_representations': ['activation of ATP synthase'],
#    'e2_representations': ['cellular process']},
#   'activation of cyclin dependent kinase -> activate': {'sentences': [],
#    'e1_representations': ['activation of cyclin dependent kinase'],
#    'e2_representations': ['activate']},
#   'activator -> transcription factor': {'sentences': [],
#    'e1_representations': ['activator'],
#    'e2_representations': ['transcription factor']},
#   'active movement of ion -> active transport': {'sentences': [],
#    'e1_representations': ['active movement of ions'],
#    'e2_representations': ['active transport']},
#   'active period -> activity': {'sentences': [],
#    'e1_representations': ['active period'],
#    'e2_representations': ['activity']},
#   'active repressor -> repressor': {'sentences': [],
#    'e1_representations': ['active repressor'],
#    'e2_representations': ['repressor']},
#   'active site -> cavity': {'sentences': [],
#    'e1_representations': ['active site'],
#    'e2_representations': ['cavity']},
#   'active site -> functional region': {'sentences': [],
#    'e1_representations': ['active site'],
#    'e2_representations': ['functional region']},
#   'active transport by proton pump -> active movement of ion': {'sentences': [],
#    'e1_representations': ['active transport by proton pump'],
#    'e2_representations': ['active movement of ions']},
#   'active transport by proton pump -> active transport use atp': {'sentences': [],
#    'e1_representations': ['active transport by proton pump'],
#    'e2_representations': ['active transport using ATP']},
#   'active transport by sodium potassium pump -> transport work': {'sentences': [],
#    'e1_representations': ['active transport by sodium potassium pump'],
#    'e2_representations': ['transport work']},
#   'active transport use atp -> active transport': {'sentences': [],
#    'e1_representations': ['active transport using ATP'],
#    'e2_representations': ['active transport']},
#   'active transport -> transport work': {'sentences': [],
#    'e1_representations': ['active transport'],
#    'e2_representations': ['transport work']},
#   'active transport -> endergonic process': {'sentences': [],
#    'e1_representations': ['active transport'],
#    'e2_representations': ['endergonic process']},
#   'active transport -> subcellular movement': {'sentences': [],
#    'e1_representations': ['active transport'],
#    'e2_representations': ['subcellular movement']},
#   'adaptation for heat conservation -> thermoregulatory adaptation': {'sentences': [],
#    'e1_representations': ['adaptation for heat conservation'],
#    'e2_representations': ['thermoregulatory adaptation']},
#   'adaptation for heat loss -> thermoregulatory adaptation': {'sentences': [],
#    'e1_representations': ['adaptation for heat loss'],
#    'e2_representations': ['thermoregulatory adaptation']},
#   'adaptation for heat production -> thermoregulatory adaptation': {'sentences': [],
#    'e1_representations': ['adaptation for heat production'],
#    'e2_representations': ['thermoregulatory adaptation']},
#   'adaptation -> evolutionary process': {'sentences': [],
#    'e1_representations': ['adaptation'],
#    'e2_representations': ['evolutionary process']},
#   'adaptive immunity -> immune response': {'sentences': [],
#    'e1_representations': ['adaptive immunity'],
#    'e2_representations': ['immune response']},
#   'adaptive management -> bioremediation': {'sentences': [],
#    'e1_representations': ['adaptive management'],
#    'e2_representations': ['bioremediation']},
#   'adaptive radiation -> evolutionary process': {'sentences': [],
#    'e1_representations': ['adaptive radiation'],
#    'e2_representations': ['evolutionary process']},
#   'adenine at dna strand opposite to dna strand -> adenine at dna strand': {'sentences': [],
#    'e1_representations': ['adenine at DNA strand opposite to DNA strand'],
#    'e2_representations': ['adenine at DNA strand']},
#   'adenine at dna strand opposite to RNA strand -> adenine at dna strand': {'sentences': [],
#    'e1_representations': ['adenine at DNA strand opposite to RNA strand'],
#    'e2_representations': ['adenine at DNA strand']},
#   'adenine at dna strand -> adenine': {'sentences': [],
#    'e1_representations': ['adenine at DNA strand'],
#    'e2_representations': ['adenine']},
#   'adenine at dna strand -> nitrogenous basis present in dna': {'sentences': [],
#    'e1_representations': ['adenine at DNA strand'],
#    'e2_representations': ['nitrogenous bases present in DNA']},
#   'adenine at RNA strand opposite to dna strand -> adenine at RNA strand': {'sentences': [],
#    'e1_representations': ['adenine at RNA strand opposite to DNA strand'],
#    'e2_representations': ['adenine at RNA strand']},
#   'adenine at RNA strand opposite to RNA strand -> adenine at RNA strand': {'sentences': [],
#    'e1_representations': ['adenine at RNA strand opposite to RNA strand'],
#    'e2_representations': ['adenine at RNA strand']},
#   'adenine at RNA strand -> adenine': {'sentences': [],
#    'e1_representations': ['adenine at RNA strand'],
#    'e2_representations': ['adenine']},
#   'adenine at RNA strand -> nitrogenous basis present in RNA': {'sentences': [],
#    'e1_representations': ['adenine at RNA strand'],
#    'e2_representations': ['nitrogenous bases present in RNA']},
#   'adenine -> purine': {'sentences': [],
#    'e1_representations': ['adenine'],
#    'e2_representations': ['purine']},
#   'adenosine -> nucleoside': {'sentences': [],
#    'e1_representations': ['adenosine'],
#    'e2_representations': ['nucleoside']},
#   'adenovirus -> dna virus': {'sentences': [],
#    'e1_representations': ['adenovirus'],
#    'e2_representations': ['DNA virus']},
#   'adenovirus -> tumor virus': {'sentences': [],
#    'e1_representations': ['adenovirus'],
#    'e2_representations': ['tumor virus']},
#   'adenovirus -> animal virus': {'sentences': [],
#    'e1_representations': ['adenovirus'],
#    'e2_representations': ['animal virus']},
#   'adenylyl cyclase -> membrane protein': {'sentences': [],
#    'e1_representations': ['adenylyl cyclase'],
#    'e2_representations': ['membrane protein']},
#   'adenylyl cyclase -> lyase': {'sentences': [],
#    'e1_representations': ['adenylyl cyclase'],
#    'e2_representations': ['lyase']},
#   'adipose cell -> animal cell': {'sentences': [],
#    'e1_representations': ['adipose cell'],
#    'e2_representations': ['animal cell']},
#   'adipose tissue -> connective tissue': {'sentences': [],
#    'e1_representations': ['adipose tissue'],
#    'e2_representations': ['connective tissue']},
#   'adp -> ribonucleoside diphosphate': {'sentences': [],
#    'e1_representations': ['ADP'],
#    'e2_representations': ['ribonucleoside diphosphate']},
#   'adrenal cortex -> organ region': {'sentences': [],
#    'e1_representations': ['adrenal cortex'],
#    'e2_representations': ['organ region']},
#   'adrenal gland -> endocrine gland': {'sentences': [],
#    'e1_representations': ['adrenal gland'],
#    'e2_representations': ['endocrine gland']},
#   'adrenal medulla -> organ region': {'sentences': [],
#    'e1_representations': ['adrenal medulla'],
#    'e2_representations': ['organ region']},
#   'adrenocorticotropic hormone -> peptide hormone': {'sentences': [],
#    'e1_representations': ['adrenocorticotropic hormone'],
#    'e2_representations': ['peptide hormone']},
#   'adult cell -> animal cell': {'sentences': [],
#    'e1_representations': ['adult cell'],
#    'e2_representations': ['animal cell']},
#   'adult human -> human': {'sentences': [],
#    'e1_representations': ['adult human'],
#    'e2_representations': ['human']},
#   'adult stem cell -> stem cell': {'sentences': [],
#    'e1_representations': ['adult stem cell'],
#    'e2_representations': ['stem cell']},
#   'adult stem cell -> adult cell': {'sentences': [],
#    'e1_representations': ['adult stem cell'],
#    'e2_representations': ['adult cell']},
#   'adult -> life stage': {'sentences': [],
#    'e1_representations': ['adult'],
#    'e2_representations': ['life stage']},
#   'adulthood -> developmental stage': {'sentences': [],
#    'e1_representations': ['adulthood'],
#    'e2_representations': ['developmental stage']},
#   'adventitious root -> root': {'sentences': [],
#    'e1_representations': ['adventitious root'],
#    'e2_representations': ['root']},
#   'aerobe -> ecological role': {'sentences': [],
#    'e1_representations': ['aerobe'],
#    'e2_representations': ['ecological role']},
#   'aerobic condition -> condition': {'sentences': [],
#    'e1_representations': ['aerobic condition'],
#    'e2_representations': ['condition']},
#   'aerobic metabolism -> metabolism': {'sentences': [],
#    'e1_representations': ['aerobic metabolism'],
#    'e2_representations': ['metabolism']},
#   'afferent arteriole -> arteriole': {'sentences': [],
#    'e1_representations': ['afferent arteriole'],
#    'e2_representations': ['arteriole']},
#   'aflatoxin -> organic entity': {'sentences': [],
#    'e1_representations': ['aflatoxin'],
#    'e2_representations': ['organic entity']},
#   'aflatoxin -> organic molecule': {'sentences': [],
#    'e1_representations': ['aflatoxin'],
#    'e2_representations': ['organic molecule']},
#   'african sleeping sickness -> protozoan disease': {'sentences': [],
#    'e1_representations': ['African sleeping sickness'],
#    'e2_representations': ['protozoan disease']},
#   'agar medium -> culture medium': {'sentences': [],
#    'e1_representations': ['agar medium'],
#    'e2_representations': ['culture medium']},
#   'agar -> organic entity': {'sentences': [],
#    'e1_representations': ['agar'],
#    'e2_representations': ['organic entity']},
#   'agar -> semisolid substance': {'sentences': [],
#    'e1_representations': ['agar'],
#    'e2_representations': ['semisolid substance']},
#   'age - structure diagram -> population representation': {'sentences': [],
#    'e1_representations': ['age-structure diagram'],
#    'e2_representations': ['population representation']},
#   'age structure -> population ecology': {'sentences': [],
#    'e1_representations': ['age structure'],
#    'e2_representations': ['population ecology']},
#   'agglutination -> biological process': {'sentences': [],
#    'e1_representations': ['agglutination'],
#    'e2_representations': ['biological process']},
#   'aggregate fruit -> fruit': {'sentences': [],
#    'e1_representations': ['aggregate fruit'],
#    'e2_representations': ['fruit']},
#   'agonistic behavior -> social behavior': {'sentences': [],
#    'e1_representations': ['agonistic behavior'],
#    'e2_representations': ['social behavior']},
#   'agricultural process -> ecological process': {'sentences': [],
#    'e1_representations': ['agricultural process'],
#    'e2_representations': ['ecological process']},
#   'agricultural product -> useful product': {'sentences': [],
#    'e1_representations': ['agricultural product'],
#    'e2_representations': ['useful product']},
#   'Agrobacterium tumefacien -> gram - negative bacterium': {'sentences': [],
#    'e1_representations': ['Agrobacterium tumefaciens'],
#    'e2_representations': ['gram-negative bacterium']},
#   'aids -> viral disease': {'sentences': [],
#    'e1_representations': ['AIDS'],
#    'e2_representations': ['viral disease']},
#   'air space -> space': {'sentences': [],
#    'e1_representations': ['air space'],
#    'e2_representations': ['space']},
#   'air water interface -> region': {'sentences': [],
#    'e1_representations': ['air water interface'],
#    'e2_representations': ['region']},
#   'airconditioner -> device': {'sentences': [],
#    'e1_representations': ['airconditioner'],
#    'e2_representations': ['device']},
#   'alanine -> hydrophobic amino acid': {'sentences': [],
#    'e1_representations': ['alanine'],
#    'e2_representations': ['hydrophobic amino acid']},
#   'albumin -> organic entity': {'sentences': [],
#    'e1_representations': ['albumin'],
#    'e2_representations': ['organic entity']},
#   'albumin -> semisolid substance': {'sentences': [],
#    'e1_representations': ['albumin'],
#    'e2_representations': ['semisolid substance']},
#   'albuterol isomer -> drug': {'sentences': [],
#    'e1_representations': ['albuterol isomer'],
#    'e2_representations': ['drug']},
#   'albuterol isomer -> isomer': {'sentences': [],
#    'e1_representations': ['albuterol isomer'],
#    'e2_representations': ['isomer']},
#   'albuterol -> molecule': {'sentences': [],
#    'e1_representations': ['albuterol'],
#    'e2_representations': ['molecule']},
#   'albuterol -> drug': {'sentences': [],
#    'e1_representations': ['albuterol'],
#    'e2_representations': ['drug']},
#   'alcohol dehydrogenase -> dehydrogenase': {'sentences': [],
#    'e1_representations': ['alcohol dehydrogenase'],
#    'e2_representations': ['dehydrogenase']},
#   'alcohol fermentation by bacteria -> alcohol fermentation': {'sentences': [],
#    'e1_representations': ['alcohol fermentation by bacteria'],
#    'e2_representations': ['alcohol fermentation']},
#   'alcohol fermentation by yeast -> alcohol fermentation': {'sentences': [],
#    'e1_representations': ['alcohol fermentation by yeast'],
#    'e2_representations': ['alcohol fermentation']},
#   'alcohol fermentation -> fermentation': {'sentences': [],
#    'e1_representations': ['alcohol fermentation'],
#    'e2_representations': ['fermentation']},
#   'alcohol hormone -> alcohol': {'sentences': [],
#    'e1_representations': ['alcohol hormone'],
#    'e2_representations': ['alcohol']},
#   'alcohol -> organic molecule': {'sentences': [],
#    'e1_representations': ['alcohol'],
#    'e2_representations': ['organic molecule']},
#   'alcoholic beverage -> liquid': {'sentences': [],
#    'e1_representations': ['alcoholic beverage'],
#    'e2_representations': ['liquid']},
#   'aldehyde -> organic molecule': {'sentences': [],
#    'e1_representations': ['aldehyde'],
#    'e2_representations': ['organic molecule']},
#   'aldolase -> lyase': {'sentences': [],
#    'e1_representations': ['aldolase'],
#    'e2_representations': ['lyase']},
#   'aldose -> aldehyde': {'sentences': [],
#    'e1_representations': ['aldose'],
#    'e2_representations': ['aldehyde']},
#   'aldose -> monosaccharide': {'sentences': [],
#    'e1_representations': ['aldose'],
#    'e2_representations': ['monosaccharide']},
#   'aldosterone -> steroid hormone': {'sentences': [],
#    'e1_representations': ['aldosterone'],
#    'e2_representations': ['steroid hormone']},
#   'alga bloom -> growth': {'sentences': [],
#    'e1_representations': ['algae bloom'],
#    'e2_representations': ['growth']},
#   'alga -> Streptophyta': {'sentences': [],
#    'e1_representations': ['algae'],
#    'e2_representations': ['Streptophyta']},
#   'algal cell wall -> cell wall': {'sentences': [],
#    'e1_representations': ['algal cell wall'],
#    'e2_representations': ['cell wall']},
#   'algal cell -> eukaryotic cell': {'sentences': [],
#    'e1_representations': ['algal cell'],
#    'e2_representations': ['eukaryotic cell']},
#   'algal cell -> wall cell': {'sentences': [],
#    'e1_representations': ['algal cell'],
#    'e2_representations': ['walled cell']},
#   'alimentary canal -> digestive tract': {'sentences': [],
#    'e1_representations': ['alimentary canal'],
#    'e2_representations': ['digestive tract']},
#   'alimentary canal -> canal': {'sentences': [],
#    'e1_representations': ['alimentary canal'],
#    'e2_representations': ['canal']},
#   'alkaptonuria -> inborn error of metabolism': {'sentences': [],
#    'e1_representations': ['alkaptonuria'],
#    'e2_representations': ['inborn error of metabolism']},
#   'allantois -> extraembryonic membrane': {'sentences': [],
#    'e1_representations': ['allantois'],
#    'e2_representations': ['extraembryonic membrane']},
#   'allee effect -> condition': {'sentences': [],
#    'e1_representations': ['allee effect'],
#    'e2_representations': ['condition']},
#   'allele I -> blood allele': {'sentences': [],
#    'e1_representations': ['allele I'],
#    'e2_representations': ['blood allele']},
#   'allele -> gene': {'sentences': [],
#    'e1_representations': ['allele'],
#    'e2_representations': ['gene']},
#   'allergy -> immune response': {'sentences': [],
#    'e1_representations': ['allergy'],
#    'e2_representations': ['immune response']},
#   'allolactose -> lactose': {'sentences': [],
#    'e1_representations': ['allolactose'],
#    'e2_representations': ['lactose']},
#   'allopatric speciation -> speciation': {'sentences': [],
#    'e1_representations': ['allopatric speciation'],
#    'e2_representations': ['speciation']},
#   'allopolyploid -> polyploidy': {'sentences': [],
#    'e1_representations': ['allopolyploid'],
#    'e2_representations': ['polyploidy']},
#   'allosteric enzyme -> protein enzyme': {'sentences': [],
#    'e1_representations': ['allosteric enzyme'],
#    'e2_representations': ['protein enzyme']},
#   'allosteric protein -> protein': {'sentences': [],
#    'e1_representations': ['allosteric protein'],
#    'e2_representations': ['protein']},
#   'allosteric regulation -> regulation': {'sentences': [],
#    'e1_representations': ['allosteric regulation'],
#    'e2_representations': ['regulation']},
#   'allosteric site -> receptor site': {'sentences': [],
#    'e1_representations': ['allosteric site'],
#    'e2_representations': ['receptor site']},
#   'alpha 1 , 4 linkage -> glycosidic linkage': {'sentences': [],
#    'e1_representations': ['alpha 1,4 linkage'],
#    'e2_representations': ['glycosidic linkage']},
#   'alpha 1 , 6 linkage -> glycosidic linkage': {'sentences': [],
#    'e1_representations': ['alpha 1,6 linkage'],
#    'e2_representations': ['glycosidic linkage']},
#   'alpha cell islet of Langerhans -> pancrea cell': {'sentences': [],
#    'e1_representations': ['alpha cell islet of Langerhans'],
#    'e2_representations': ['pancreas cell']},
#   'alpha globin ancestral gene -> globin ancestral gene': {'sentences': [],
#    'e1_representations': ['alpha globin ancestral gene'],
#    'e2_representations': ['globin ancestral gene']},
#   'alpha globin gene -> immunoglobulin gene': {'sentences': [],
#    'e1_representations': ['alpha globin gene'],
#    'e2_representations': ['immunoglobulin gene']},
#   'alpha globin -> globin': {'sentences': [],
#    'e1_representations': ['alpha globin'],
#    'e2_representations': ['globins']},
#   'alpha glucose -> glucose isomer': {'sentences': [],
#    'e1_representations': ['alpha glucose'],
#    'e2_representations': ['glucose isomer']},
#   'alpha helix -> secondary structure': {'sentences': [],
#    'e1_representations': ['alpha helix'],
#    'e2_representations': ['secondary structure']},
#   'alpha keratin -> keratin': {'sentences': [],
#    'e1_representations': ['alpha keratin'],
#    'e2_representations': ['keratin']},
#   'alpha ketoglutarate -> ester': {'sentences': [],
#    'e1_representations': ['alpha ketoglutarate'],
#    'e2_representations': ['ester']},
#   'alpha tubulin -> polypeptide': {'sentences': [],
#    'e1_representations': ['alpha tubulin'],
#    'e2_representations': ['polypeptide']},
#   'alter genome -> change sequence': {'sentences': [],
#    'e1_representations': ['alter genome'],
#    'e2_representations': ['change sequence']},
#   'alter -> action': {'sentences': [],
#    'e1_representations': ['alter'],
#    'e2_representations': ['action']},
#   'alteration of mRNA end -> biochemical change': {'sentences': [],
#    'e1_representations': ['alteration of mRNA ends'],
#    'e2_representations': ['biochemical change']},
#   'alternate generation organ -> plant organ': {'sentences': [],
#    'e1_representations': ['alternating generation organ'],
#    'e2_representations': ['plant organ']},
#   'alternation of generation -> life cycle process': {'sentences': [],
#    'e1_representations': ['alternation of generations'],
#    'e2_representations': ['life cycle process']},
#   'alternative RNA splicing -> RNA splicing': {'sentences': [],
#    'e1_representations': ['alternative RNA splicing'],
#    'e2_representations': ['RNA splicing']},
#   'altruism -> social behavior': {'sentences': [],
#    'e1_representations': ['altruism'],
#    'e2_representations': ['social behavior']},
#   'Alu element -> transposon': {'sentences': [],
#    'e1_representations': ['Alu element'],
#    'e2_representations': ['transposon']},
#   'aluminum atom -> metal atom': {'sentences': [],
#    'e1_representations': ['aluminum atom'],
#    'e2_representations': ['metal atom']},
#   'alveolate -> unicellular organism': {'sentences': [],
#    'e1_representations': ['alveolate'],
#    'e2_representations': ['unicellular organism']},
#   'alveolate -> protist cell': {'sentences': [],
#    'e1_representations': ['alveolate'],
#    'e2_representations': ['protist cell']},
#   'alveolus -> simple squamous epithelium': {'sentences': [],
#    'e1_representations': ['alveolus'],
#    'e2_representations': ['simple squamous epithelium']},
#   'alzheimer disease process -> disease process': {'sentences': [],
#    'e1_representations': ['alzheimers disease process'],
#    'e2_representations': ['disease process']},
#   'alzheimer disease -> mental or brain disorder': {'sentences': [],
#    'e1_representations': ['alzheimers disease'],
#    'e2_representations': ['mental or brain disorder']},
#   'amacrine cell -> sensory neuron': {'sentences': [],
#    'e1_representations': ['amacrine cell'],
#    'e2_representations': ['sensory neuron']},
#   'american gin -> eudicot': {'sentences': [],
#    'e1_representations': ['American ginseng'],
#    'e2_representations': ['eudicot']},
#   'americium atom -> metal atom': {'sentences': [],
#    'e1_representations': ['americium atom'],
#    'e2_representations': ['metal atom']},
#   'amine -> base compound': {'sentences': [],
#    'e1_representations': ['amine'],
#    'e2_representations': ['base compound']},
#   'amine -> nitrogenous compound': {'sentences': [],
#    'e1_representations': ['amine'],
#    'e2_representations': ['nitrogenous compound']},
#   'amino acid hormone -> hormone': {'sentences': [],
#    'e1_representations': ['amino acid hormone'],
#    'e2_representations': ['hormone']},
#   'amino acid hormone -> amino acid': {'sentences': [],
#    'e1_representations': ['amino acid hormone'],
#    'e2_representations': ['amino acid']},
#   'amino acid neurotransmitter -> neurotransmitter': {'sentences': [],
#    'e1_representations': ['amino acid neurotransmitter'],
#    'e2_representations': ['neurotransmitter']},
#   'amino acid neurotransmitter -> amino acid': {'sentences': [],
#    'e1_representations': ['amino acid neurotransmitter'],
#    'e2_representations': ['amino acid']},
#   'amino acid sequence -> sequence': {'sentences': [],
#    'e1_representations': ['amino acid sequence'],
#    'e2_representations': ['sequence']},
#   'amino acid -> organic entity': {'sentences': [],
#    'e1_representations': ['amino acid'],
#    'e2_representations': ['organic entity']},
#   'amino acid -> organic molecule': {'sentences': [],
#    'e1_representations': ['amino acid'],
#    'e2_representations': ['organic molecule']},
#   'amino end of a protein -> molecular region': {'sentences': [],
#    'e1_representations': ['amino end of a protein'],
#    'e2_representations': ['molecular region']},
#   'amino end of a protein -> end': {'sentences': [],
#    'e1_representations': ['amino end of a protein'],
#    'e2_representations': ['end']},
#   'amino group -> functional group': {'sentences': [],
#    'e1_representations': ['amino group'],
#    'e2_representations': ['functional group']},
#   'amino peptidase -> protease': {'sentences': [],
#    'e1_representations': ['amino peptidase'],
#    'e2_representations': ['protease']},
#   'aminoacyl - tRNA synthetase -> ligase': {'sentences': [],
#    'e1_representations': ['aminoacyl-tRNA synthetase'],
#    'e2_representations': ['ligase']},
#   'aminoacyl - tRNA -> TRNA': {'sentences': [],
#    'e1_representations': ['aminoacyl-tRNA'],
#    'e2_representations': ['TRNA']},
#   'ammonia gas -> weak base': {'sentences': [],
#    'e1_representations': ['ammonia gas'],
#    'e2_representations': ['weak base']},
#   'ammonia -> covalent compound': {'sentences': [],
#    'e1_representations': ['ammonia'],
#    'e2_representations': ['covalent compound']},
#   'ammonia -> inorganic molecule': {'sentences': [],
#    'e1_representations': ['ammonia'],
#    'e2_representations': ['inorganic molecule']},
#   'ammonification -> decomposition': {'sentences': [],
#    'e1_representations': ['ammonification'],
#    'e2_representations': ['decomposition']},
#   'ammonifying bacterium -> bacterium': {'sentences': [],
#    'e1_representations': ['ammonifying bacterium'],
#    'e2_representations': ['bacterium']},
#   'ammonite -> early invertebrate': {'sentences': [],
#    'e1_representations': ['ammonite'],
#    'e2_representations': ['early invertebrate']},
#   'ammonite -> extinct invertebrate': {'sentences': [],
#    'e1_representations': ['ammonite'],
#    'e2_representations': ['extinct invertebrate']},
#   'amniocentesis -> fetal testing': {'sentences': [],
#    'e1_representations': ['amniocentesis'],
#    'e2_representations': ['fetal testing']},
#   'amnion -> extraembryonic membrane': {'sentences': [],
#    'e1_representations': ['amnion'],
#    'e2_representations': ['extraembryonic membrane']},
#   'amniote -> tetrapod': {'sentences': [],
#    'e1_representations': ['amniote'],
#    'e2_representations': ['tetrapod']},
#   'amniotic egg -> shell egg': {'sentences': [],
#    'e1_representations': ['amniotic egg'],
#    'e2_representations': ['shelled egg']},
#   'amniotic fluid -> extra cellular fluid': {'sentences': [],
#    'e1_representations': ['amniotic fluid'],
#    'e2_representations': ['extra cellular fluid']},
#   'amoeba -> unicellular organism': {'sentences': [],
#    'e1_representations': ['amoeba'],
#    'e2_representations': ['unicellular organism']},
#   'amoeba -> protist cell': {'sentences': [],
#    'e1_representations': ['amoeba'],
#    'e2_representations': ['protist cell']},
#   'amoeba -> protist': {'sentences': [],
#    'e1_representations': ['amoeba'],
#    'e2_representations': ['protist']},
#   'amoebocyte -> animal development cell': {'sentences': [],
#    'e1_representations': ['amoebocyte'],
#    'e2_representations': ['animal development cell']},
#   'amp -> nucleoside monophosphate': {'sentences': [],
#    'e1_representations': ['AMP'],
#    'e2_representations': ['nucleoside monophosphate']},
#   'amphibian -> ectotherm': {'sentences': [],
#    'e1_representations': ['amphibian'],
#    'e2_representations': ['ectotherm']},
#   'amphibian -> tetrapod': {'sentences': [],
#    'e1_representations': ['amphibian'],
#    'e2_representations': ['tetrapod']},
#   'amphipathic molecule -> molecule': {'sentences': [],
#    'e1_representations': ['amphipathic molecule'],
#    'e2_representations': ['molecule']},
#   'ampicillin -> antibiotic': {'sentences': [],
#    'e1_representations': ['ampicillin'],
#    'e2_representations': ['antibiotic']},
#   'amplification -> nerve related intercellular process': {'sentences': [],
#    'e1_representations': ['amplification'],
#    'e2_representations': ['nerve related intercellular process']},
#   'amygdala -> cerebrum': {'sentences': [],
#    'e1_representations': ['amygdala'],
#    'e2_representations': ['cerebrum']},
#   'amylase -> digestive enzyme': {'sentences': [],
#    'e1_representations': ['amylase'],
#    'e2_representations': ['digestive enzyme']},
#   'amylopectin -> starch': {'sentences': [],
#    'e1_representations': ['amylopectin'],
#    'e2_representations': ['starch']},
#   'amyloplast -> plastid': {'sentences': [],
#    'e1_representations': ['amyloplast'],
#    'e2_representations': ['plastid']},
#   'amylose -> starch': {'sentences': [],
#    'e1_representations': ['amylose'],
#    'e2_representations': ['starch']},
#   'anabolic pathway -> endergonic reaction': {'sentences': [],
#    'e1_representations': ['anabolic pathway'],
#    'e2_representations': ['endergonic reaction']},
#   'anabolic pathway -> metabolic pathway': {'sentences': [],
#    'e1_representations': ['anabolic pathway'],
#    'e2_representations': ['metabolic pathway']},
#   'anabolism -> endergonic process': {'sentences': [],
#    'e1_representations': ['anabolism'],
#    'e2_representations': ['endergonic process']},
#   'anabolism -> metabolism': {'sentences': [],
#    'e1_representations': ['anabolism'],
#    'e2_representations': ['metabolism']},
#   'anaerobe -> ecological role': {'sentences': [],
#    'e1_representations': ['anaerobe'],
#    'e2_representations': ['ecological role']},
#   'anaerobic condition -> condition': {'sentences': [],
#    'e1_representations': ['anaerobic condition'],
#    'e2_representations': ['condition']},
#   'anaerobic metabolism -> metabolism': {'sentences': [],
#    'e1_representations': ['anaerobic metabolism'],
#    'e2_representations': ['metabolism']},
#   'anaerobic respiration -> catabolism': {'sentences': [],
#    'e1_representations': ['anaerobic respiration'],
#    'e2_representations': ['catabolism']},
#   'anagenesis -> speciation': {'sentences': [],
#    'e1_representations': ['anagenesis'],
#    'e2_representations': ['speciation']},
#   'anaphase - I -> meiotic event': {'sentences': [],
#    'e1_representations': ['anaphase-I'],
#    'e2_representations': ['meiotic event']},
#   'anaphase - ii -> meiotic event': {'sentences': [],
#    'e1_representations': ['anaphase-II'],
#    'e2_representations': ['meiotic event']},
#   'anaphase - promote complex -> protein complex': {'sentences': [],
#    'e1_representations': ['anaphase-promoting complex'],
#    'e2_representations': ['protein complex']},
#   'anaphase -> mitotic stage': {'sentences': [],
#    'e1_representations': ['anaphase'],
#    'e2_representations': ['mitotic stage']},
#   'anaphylactic shock -> immune disorder': {'sentences': [],
#    'e1_representations': ['anaphylactic shock'],
#    'e2_representations': ['immune disorders']},
#   'anapsid -> early vertebrate': {'sentences': [],
#    'e1_representations': ['anapsid'],
#    'e2_representations': ['early vertebrate']},
#   'anapsid -> extinct vertebrate': {'sentences': [],
#    'e1_representations': ['anapsid'],
#    'e2_representations': ['extinct vertebrate']},
#   'anatomical appendage -> anatomical structure': {'sentences': [],
#    'e1_representations': ['anatomical appendage'],
#    'e2_representations': ['anatomical structure']},
#   'anatomical region -> organismal region': {'sentences': [],
#    'e1_representations': ['anatomical region'],
#    'e2_representations': ['organismal region']},
#   'anatomical space -> space': {'sentences': [],
#    'e1_representations': ['anatomical space'],
#    'e2_representations': ['space']},
#   'anatomical space -> organismal region': {'sentences': [],
#    'e1_representations': ['anatomical space'],
#    'e2_representations': ['organismal region']},
#   'anatomical structure -> animate thing': {'sentences': [],
#    'e1_representations': ['anatomical structure'],
#    'e2_representations': ['animate thing']},
#   'anatomist -> biologist': {'sentences': [],
#    'e1_representations': ['anatomist'],
#    'e2_representations': ['biologist']},
#   'anatomy -> morphology': {'sentences': [],
#    'e1_representations': ['anatomy'],
#    'e2_representations': ['morphology']},
#   'ancestral gene -> gene': {'sentences': [],
#    'e1_representations': ['ancestral gene'],
#    'e2_representations': ['gene']},
#   'anchor cell destruction experiment -> experiment': {'sentences': [],
#    'e1_representations': ['anchor cell destruction experiment'],
#    'e2_representations': ['experiment']},
#   'anchor cell -> reproductive cell': {'sentences': [],
#    'e1_representations': ['anchor cell'],
#    'e2_representations': ['reproductive cell']},
#   'anchor cell -> animal cell': {'sentences': [],
#    'e1_representations': ['anchor cell'],
#    'e2_representations': ['animal cell']},
#   'anchor -> support': {'sentences': [],
#    'e1_representations': ['anchor'],
#    'e2_representations': ['support']},
#   'anchorage dependence -> cellular process': {'sentences': [],
#    'e1_representations': ['Anchorage dependence'],
#    'e2_representations': ['cellular process']},
#   'anchor of organelle -> anchor': {'sentences': [],
#    'e1_representations': ['anchoring of organelles'],
#    'e2_representations': ['anchor']},
#   'androgen -> sex hormone': {'sentences': [],
#    'e1_representations': ['androgen'],
#    'e2_representations': ['sex hormone']},
#   'anesthesia -> medical procedure': {'sentences': [],
#    'e1_representations': ['anesthesia'],
#    'e2_representations': ['medical procedure']},
#   'aneuploidy -> chromosomal disorder cell': {'sentences': [],
#    'e1_representations': ['aneuploidy'],
#    'e2_representations': ['chromosomal disorder cell']},
#   'Angelman syndrome -> human genetic disorder': {'sentences': [],
#    'e1_representations': ['Angelman syndrome'],
#    'e2_representations': ['human genetic disorder']},
#   'angiopserm plant development -> plant development': {'sentences': [],
#    'e1_representations': ['angiopserm plant development'],
#    'e2_representations': ['plant development']},
#   'angiosperm -> seed - plant': {'sentences': [],
#    'e1_representations': ['angiosperm'],
#    'e2_representations': ['seed-plant']},
#   'anhydrobiosis -> condition': {'sentences': [],
#    'e1_representations': ['anhydrobiosis'],
#    'e2_representations': ['condition']},
#   'animal appendage -> anatomical appendage': {'sentences': [],
#    'e1_representations': ['animal appendage'],
#    'e2_representations': ['anatomical appendage']},
#   'animal base on constancy of body temperature -> animal': {'sentences': [],
#    'e1_representations': ['animal based on constancy of body temperature'],
#    'e2_representations': ['animal']},
#   'animal -> animal': {'sentences': [],
#    'e1_representations': ['animal'],
#    'e2_representations': ['animal']},
#   'animal cell centrosome -> centrosome': {'sentences': [],
#    'e1_representations': ['animal cell centrosome'],
#    'e2_representations': ['centrosome']},
#   'animal cell division -> cell division': {'sentences': [],
# ...
#    'e1_representations': ['hydrophilic face'],
#    'e2_representations': ['mitochondrial membrane']},
#   'plant cell - wall -> cell-membrane': {'sentences': [],
#    'e1_representations': ['plant cell-wall'],
#    'e2_representations': ['cell-membrane']},
#   'sugar phosphate backbone -> dna double helix': {'sentences': [],
#    'e1_representations': ['sugar phosphate backbone'],
#    'e2_representations': ['DNA double helix']},
#   'whorl -> whorl': {'sentences': [],
#    'e1_representations': ['whorl'],
#    'e2_representations': ['whorl']},
#   'carbohydrate side chain -> chloroplast membrane': {'sentences': [],
#    'e1_representations': ['carbohydrate side chain'],
#    'e2_representations': ['chloroplast membrane']},
#   'object -> lysosome': {'sentences': [],
#    'e1_representations': ['object'],
#    'e2_representations': ['lysosome']},
#   'inner membrane -> mitochondrial matrix': {'sentences': [],
#    'e1_representations': ['inner membrane'],
#    'e2_representations': ['mitochondrial matrix']},
#   'extra cellular matrix -> sperm cell': {'sentences': [],
#    'e1_representations': ['extra cellular matrix'],
#    'e2_representations': ['sperm cell']},
#   'hypertonic solution -> bacterial cell inside hypertonic solution': {'sentences': [],
#    'e1_representations': ['hypertonic solution'],
#    'e2_representations': ['bacterial cell inside hypertonic solution']},
#   'ectoderm -> endoderm': {'sentences': [],
#    'e1_representations': ['ectoderm'],
#    'e2_representations': ['endoderm']},
#   'object -> nucleus': {'sentences': [],
#    'e1_representations': ['object'],
#    'e2_representations': ['nucleus']},
#   'shell of egg -> blastula': {'sentences': [],
#    'e1_representations': ['shell of egg'],
#    'e2_representations': ['blastula']},
#   'extra cellular matrix -> plant cell inside isotonic solution': {'sentences': [],
#    'e1_representations': ['extra cellular matrix'],
#    'e2_representations': ['plant cell inside isotonic solution']},
#   'extra cellular matrix -> cell without cell - wall inside hypotonic solution': {'sentences': [],
#    'e1_representations': ['extra cellular matrix'],
#    'e2_representations': ['cell without cell-wall inside hypotonic solution']},
#   'object -> chlorophyll B': {'sentences': [],
#    'e1_representations': ['object'],
#    'e2_representations': ['chlorophyll B']},
#   'embryonic cell -> object': {'sentences': [],
#    'e1_representations': ['embryonic cell'],
#    'e2_representations': ['object']},
#   'extra cellular matrix -> animal cell': {'sentences': [],
#    'e1_representations': ['extra cellular matrix'],
#    'e2_representations': ['animal cell']},
#   'fiber -> eukaryotic cell': {'sentences': [],
#    'e1_representations': ['fiber'],
#    'e2_representations': ['eukaryotic cell']},
#   'extra cellular matrix -> wall cell inside hypertonic solution': {'sentences': [],
#    'e1_representations': ['extra cellular matrix'],
#    'e2_representations': ['walled cell inside hypertonic solution']},
#   'object -> mitochondrion': {'sentences': [],
#    'e1_representations': ['object'],
#    'e2_representations': ['mitochondrion']},
#   'extracellular side -> plant cell inside isotonic solution': {'sentences': [],
#    'e1_representations': ['extracellular side'],
#    'e2_representations': ['plant cell inside isotonic solution']},
#   'extra cellular matrix -> turgid cell': {'sentences': [],
#    'e1_representations': ['extra cellular matrix'],
#    'e2_representations': ['turgid cell']},
#   'region -> molecule': {'sentences': [],
#    'e1_representations': ['region'],
#    'e2_representations': ['molecule']},
#   'hydrophilic face -> chloroplast membrane': {'sentences': [],
#    'e1_representations': ['hydrophilic face'],
#    'e2_representations': ['chloroplast membrane']},
#   'shell -> larva': {'sentences': [],
#    'e1_representations': ['shell'],
#    'e2_representations': ['larva']},
#   'interstitial fluid -> cell': {'sentences': [],
#    'e1_representations': ['interstitial fluid'],
#    'e2_representations': ['cell']},
#   'choanocyte -> amoebocyte': {'sentences': [],
#    'e1_representations': ['choanocyte'],
#    'e2_representations': ['amoebocyte']},
#   'cytoplasm -> ribosome': {'sentences': [],
#    'e1_representations': ['cytoplasm'],
#    'e2_representations': ['ribosome']},
#   'hypotonic solution -> turgid cell': {'sentences': [],
#    'e1_representations': ['hypotonic solution'],
#    'e2_representations': ['turgid cell']},
#   'extracellular side -> eukaryotic cell': {'sentences': [],
#    'e1_representations': ['extracellular side'],
#    'e2_representations': ['eukaryotic cell']},
#   'object -> seed': {'sentences': [],
#    'e1_representations': ['object'],
#    'e2_representations': ['seedling']},
#   'extra cellular fluid -> animal cell': {'sentences': [],
#    'e1_representations': ['extra cellular fluid'],
#    'e2_representations': ['animal cell']},
#   'shell of egg -> zygote': {'sentences': [],
#    'e1_representations': ['shell of egg'],
#    'e2_representations': ['zygote']},
#   'cell wall -> cell-membrane': {'sentences': [],
#    'e1_representations': ['cell wall'],
#    'e2_representations': ['cell-membrane']},
#   'carbohydrate side chain -> animal plasma membrane': {'sentences': [],
#    'e1_representations': ['carbohydrate side chain'],
#    'e2_representations': ['animal plasma membrane']},
#   'soil -> root': {'sentences': [],
#    'e1_representations': ['soil'],
#    'e2_representations': ['root']},
#   'soil -> cell-membrane': {'sentences': [],
#    'e1_representations': ['soil'],
#    'e2_representations': ['cell-membrane']},
#   'deep body of water -> plankton': {'sentences': [],
#    'e1_representations': ['deep body of water'],
#    'e2_representations': ['plankton']},
#   'solution -> chief cell': {'sentences': [],
#    'e1_representations': ['solution'],
#    'e2_representations': ['chief cell']},
#   'pupal case -> pupa': {'sentences': [],
#    'e1_representations': ['pupal case'],
#    'e2_representations': ['pupa']},
#   'hydrophilic face -> hypertonic solution': {'sentences': [],
#    'e1_representations': ['hydrophilic face'],
#    'e2_representations': ['hypertonic solution']},
#   'mesophyll cell -> sieve - tube element': {'sentences': [],
#    'e1_representations': ['mesophyll cell'],
#    'e2_representations': ['sieve-tube element']},
#   'extra cellular matrix -> cell': {'sentences': [],
#    'e1_representations': ['extra cellular matrix'],
#    'e2_representations': ['cell']},
#   'aqueous solution -> cell-membrane': {'sentences': [],
#    'e1_representations': ['aqueous solution'],
#    'e2_representations': ['cell-membrane']},
#   'hydrophilic face , which be outside face -> membrane': {'sentences': [],
#    'e1_representations': ['hydrophilic face, which is outside face'],
#    'e2_representations': ['membrane']},
#   'object -> Platyhelminthes': {'sentences': [],
#    'e1_representations': ['object'],
#    'e2_representations': ['Platyhelminthes']},
#   'object -> sunlight': {'sentences': [],
#    'e1_representations': ['object'],
#    'e2_representations': ['sunlight']},
#   'environment -> kudzu': {'sentences': [],
#    'e1_representations': ['environment'],
#    'e2_representations': ['kudzu']},
#   'membrane protein -> phospholipid bilayer': {'sentences': [],
#    'e1_representations': ['membrane protein'],
#    'e2_representations': ['phospholipid bilayer']},
#   'extra cellular matrix -> cell without cell - wall inside hypertonic solution': {'sentences': [],
#    'e1_representations': ['extra cellular matrix'],
#    'e2_representations': ['cell without cell-wall inside hypertonic solution']},
#   'object -> acoela': {'sentences': [],
#    'e1_representations': ['object'],
#    'e2_representations': ['acoela']},
#   'extra cellular matrix -> bacterial cell inside hypertonic solution': {'sentences': [],
#    'e1_representations': ['extra cellular matrix'],
#    'e2_representations': ['bacterial cell inside hypertonic solution']},
#   'epidermal cell -> plant organ': {'sentences': [],
#    'e1_representations': ['epidermal cell'],
#    'e2_representations': ['plant organ']},
#   'polypeptide -> algal cell': {'sentences': [],
#    'e1_representations': ['polypeptide'],
#    'e2_representations': ['algal cell']},
#   'environment -> C4 plant': {'sentences': [],
#    'e1_representations': ['environment'],
#    'e2_representations': ['C4 plant']},
#   'environment -> leucosolenia': {'sentences': [],
#    'e1_representations': ['environment'],
#    'e2_representations': ['leucosolenia']},
#   'shell of egg -> larva': {'sentences': [],
#    'e1_representations': ['shell of egg'],
#    'e2_representations': ['larva']},
#   'object -> organism': {'sentences': [],
#    'e1_representations': ['object'],
#    'e2_representations': ['organism']},
#   'environment -> bean plant': {'sentences': [],
#    'e1_representations': ['environment'],
#    'e2_representations': ['bean plant']},
#   'object -> rotor': {'sentences': [],
#    'e1_representations': ['object'],
#    'e2_representations': ['rotor']},
#   'environment -> sunlight': {'sentences': [],
#    'e1_representations': ['environment'],
#    'e2_representations': ['sunlight']},
#   'hypotonic solution -> wall cell inside hypotonic solution': {'sentences': [],
#    'e1_representations': ['hypotonic solution'],
#    'e2_representations': ['walled cell inside hypotonic solution']},
#   'object -> biologist': {'sentences': [],
#    'e1_representations': ['object'],
#    'e2_representations': ['biologist']},
#   'environment -> Paramecium': {'sentences': [],
#    'e1_representations': ['environment'],
#    'e2_representations': ['Paramecium']},
#   'hydrophilic face -> thylakoid membrane': {'sentences': [],
#    'e1_representations': ['hydrophilic face'],
#    'e2_representations': ['thylakoid membrane']},
#   'object -> pancrea cell': {'sentences': [],
#    'e1_representations': ['object'],
#    'e2_representations': ['pancreas cell']},
#   'extra cellular fluid -> pancrea cell': {'sentences': [],
#    'e1_representations': ['extra cellular fluid'],
#    'e2_representations': ['pancreas cell']},
#   'extra cellular fluid -> cell': {'sentences': [],
#    'e1_representations': ['extra cellular fluid'],
#    'e2_representations': ['cell']},
#   'hydrophilic face -> cytosol': {'sentences': [],
#    'e1_representations': ['hydrophilic face'],
#    'e2_representations': ['cytosol']},
#   'peripheral protein -> phospholipid bilayer': {'sentences': [],
#    'e1_representations': ['peripheral protein'],
#    'e2_representations': ['phospholipid bilayer']},
#   'anus -> colon': {'sentences': [],
#    'e1_representations': ['anus'],
#    'e2_representations': ['colon']},
#   'carbohydrate side chain -> er membrane': {'sentences': [],
#    'e1_representations': ['carbohydrate side chain'],
#    'e2_representations': ['ER membrane']},
#   'object -> plant organ': {'sentences': [],
#    'e1_representations': ['object'],
#    'e2_representations': ['plant organ']},
#   'atmosphere -> colon': {'sentences': [],
#    'e1_representations': ['atmosphere'],
#    'e2_representations': ['colon']},
#   'egg -> shell of egg': {'sentences': [],
#    'e1_representations': ['egg'],
#    'e2_representations': ['shell of egg']},
#   'extra cellular matrix -> cell without cell - wall inside isotonic solution': {'sentences': [],
#    'e1_representations': ['extra cellular matrix'],
#    'e2_representations': ['cell without cell-wall inside isotonic solution']},
#   'extra cellular matrix -> plant cell': {'sentences': [],
#    'e1_representations': ['extra cellular matrix'],
#    'e2_representations': ['plant cell']},
#   'gastrovascular cavity -> gastrodermal cell': {'sentences': [],
#    'e1_representations': ['gastrovascular cavity'],
#    'e2_representations': ['gastrodermal cell']},
#   'hypotonic solution -> animal cell inside hypotonic solution': {'sentences': [],
#    'e1_representations': ['hypotonic solution'],
#    'e2_representations': ['animal cell inside hypotonic solution']},
#   'extra cellular matrix -> delta formin yeast': {'sentences': [],
#    'e1_representations': ['extra cellular matrix'],
#    'e2_representations': ['delta formin yeast']},
#   'endoderm -> archenteron': {'sentences': [],
#    'e1_representations': ['endoderm'],
#    'e2_representations': ['archenteron']},
#   'atmosphere -> peroxisome': {'sentences': [],
#    'e1_representations': ['atmosphere'],
#    'e2_representations': ['peroxisome']},
#   'environment -> corn': {'sentences': [],
#    'e1_representations': ['environment'],
#    'e2_representations': ['corn']},
#   'biological region -> organism': {'sentences': [],
#    'e1_representations': ['biological region'],
#    'e2_representations': ['organism']},
#   'plasma -> cell': {'sentences': [],
#    'e1_representations': ['plasma'],
#    'e2_representations': ['cell']},
#   'blood -> animal cell': {'sentences': [],
#    'e1_representations': ['blood'],
#    'e2_representations': ['animal cell']},
#   'carbohydrate side chain -> mitochondrial membrane': {'sentences': [],
#    'e1_representations': ['carbohydrate side chain'],
#    'e2_representations': ['mitochondrial membrane']},
#   'sunlight -> deep body of water': {'sentences': [],
#    'e1_representations': ['sunlight'],
#    'e2_representations': ['deep body of water']},
#   'negatively charge region -> er membrane': {'sentences': [],
#    'e1_representations': ['negatively charged region'],
#    'e2_representations': ['ER membrane']},
#   'extra cellular matrix -> ovarian cell': {'sentences': [],
#    'e1_representations': ['extra cellular matrix'],
#    'e2_representations': ['ovarian cell']},
#   'object -> tropical sea': {'sentences': [],
#    'e1_representations': ['object'],
#    'e2_representations': ['tropical sea']},
#   'sun -> deep body of water': {'sentences': [],
#    'e1_representations': ['sun'],
#    'e2_representations': ['deep body of water']},
#   'animal plasma membrane -> cytoplasm': {'sentences': [],
#    'e1_representations': ['animal plasma membrane'],
#    'e2_representations': ['cytoplasm']},
#   'extracellular side -> amoeba': {'sentences': [],
#    'e1_representations': ['extracellular side'],
#    'e2_representations': ['amoeba']},
#   'hydration shell -> molecule': {'sentences': [],
#    'e1_representations': ['hydration shell'],
#    'e2_representations': ['molecule']},
#   'object -> flatworm': {'sentences': [],
#    'e1_representations': ['object'],
#    'e2_representations': ['flatworm']},
#   'extracellular side -> mesophyll cell': {'sentences': [],
#    'e1_representations': ['extracellular side'],
#    'e2_representations': ['mesophyll cell']},
#   'object -> membrane , which be mitochondrion': {'sentences': [],
#    'e1_representations': ['object'],
#    'e2_representations': ['membrane, which is mitochondrion']},
#   'extra cellular matrix -> secondary spermatocyte': {'sentences': [],
#    'e1_representations': ['extra cellular matrix'],
#    'e2_representations': ['secondary spermatocyte']},
#   'hypotonic solution -> cell without cell - wall inside hypotonic solution': {'sentences': [],
#    'e1_representations': ['hypotonic solution'],
#    'e2_representations': ['cell without cell-wall inside hypotonic solution']},
#   'inner membrane -> stroma': {'sentences': [],
#    'e1_representations': ['inner membrane'],
#    'e2_representations': ['stroma']},
#   'environment -> grass': {'sentences': [],
#    'e1_representations': ['environment'],
#    'e2_representations': ['grass']},
#   'suspension -> amoebocyte': {'sentences': [],
#    'e1_representations': ['suspension'],
#    'e2_representations': ['amoebocyte']},
#   'object -> protist': {'sentences': [],
#    'e1_representations': ['object'],
#    'e2_representations': ['protist']},
#   'cytoplasm -> mitochondrion': {'sentences': [],
#    'e1_representations': ['cytoplasm'],
#    'e2_representations': ['mitochondrion']},
#   'extranuclear gene -> nucleus': {'sentences': [],
#    'e1_representations': ['extranuclear gene'],
#    'e2_representations': ['nucleus']},
#   'extracellular side -> wall cell inside isotonic solution': {'sentences': [],
#    'e1_representations': ['extracellular side'],
#    'e2_representations': ['walled cell inside isotonic solution']},
#   'extra cellular matrix -> mate type alpha': {'sentences': [],
#    'e1_representations': ['extra cellular matrix'],
#    'e2_representations': ['mating type alpha']},
#   'object -> arthropo': {'sentences': [],
#    'e1_representations': ['object'],
#    'e2_representations': ['arthropod']}}}

# %% [markdown]
# # 2. Tag Sentences w/ Relations
#
# First, we pre-process the sentences with spacy.

# %%
stax_bio_sentences = pd.read_csv(f"{data_dir}/raw_data/final_bio_parsed.csv")
exclude_sections = ["Preface", "Chapter Outline", "Index", "Chapter Outline", "Critical Thinking Questions", 
                    "Visual Connection Questions", "Key Terms", "Review Questions", 
                    "The Periodic Table of Elements", "Measurements and the Metric System"]
stax_bio_sentences = stax_bio_sentences[~(stax_bio_sentences.section_name.isin(exclude_sections))]
docs = [nlp(sent) for sent in stax_bio_sentences.sentence]
write_spacy_docs(docs, f"{data_dir}/processed_data/openstax_biology_sentences_spacy")

# %%
with open(f"{data_dir}/raw_data/life_bio_selected_sentences.txt", "r") as f:
    life_bio_sentences = f.readlines()
docs = [nlp(sent) for sent in life_bio_sentences]
write_spacy_docs(docs, f"{data_dir}/processed_data/life_biology_sentences_spacy")

# %%
indices = ((3, 4), (5, 6))
[i for ind in indices for i in ind]
# Out:
# [3, 4, 5, 6]

# %%
test = "7.1.1.16.6	Chapters 27 and 28 cover the green plants (D)."
re.sub("^(\d*\.*)+\s*", "", test)
# Out:
# 'Chapters 27 and 28 cover the green plants (D).'

# %% [markdown]
# Next, we tag sentences with relation pairs extracted earlier.

# %%
def add_relation(term1, term2, found_terms, tokenized_text, relation_type, relations_db):
    
    term_pair = " -> ".join((term1, term2))
    for relation in relations_db:
        if term_pair in relations_db[relation]: 
            
        relation_text = " ".join(tokenized_text)
        term_text = found_terms[term1]["text"][0]
        relation_text = relation_text.replace(term_text, f"<e1> {term_text} </e1>")
        term_text = found_terms[term2]["text"][0] 
        relation_text = relation_text.replace(term_text, f"<e2> {term_text} </e2>")
        relation_count += 1
        relations[relation][" | ".join((term1, term2))]["sentences"].append(relation_text)
    
def tag_relations(text, terms, relations_db, nlp=None):
    
    # default to Stanford NLP pipeline wrapped in Spacy
    if nlp is None:
        snlp = stanfordnlp.Pipeline(lang="en")
        nlp = StanfordNLPLanguage(snlp)
        
    # preprocess with spacy if needed
    if type(terms[0]) != spacy.tokens.doc.Doc:
        terms = [nlp(term) for term in terms]
    if type(text) != spacy.tokens.doc.Doc:
        text = nlp(text)

    normalized_text = [token.lemma_ for token in text]
    tokenized_text = [token.text for token in text]

    # storage variables

                    
    # extract relations
    for i in range(len(found_terms) - 1):
        for j in range(i + 1, len(found_terms)):
            terms = list(found_terms.keys())
            # sort alphabetically so no-relations will have same ordering across all texts 
            term1, term2 = sorted([terms[i], terms[j]])
            relation_count = 0
            for relation in relations:
                if " | ".join((term1, term2)) in relations[relation]: 
                    relation_text = " ".join(tokenized_text)
                    term_text = found_terms[term1]["text"][0]
                    relation_text = relation_text.replace(term_text, f"<e1> {term_text} </e1>")
                    term_text = found_terms[term2]["text"][0] 
                    relation_text = relation_text.replace(term_text, f"<e2> {term_text} </e2>")
                    relation_count += 1
                    relations[relation][" | ".join((term1, term2))]["sentences"].append(relation_text)
                elif " | ".join((term2, term1)) in relations[relation]: 
                    relation_text = " ".join(tokenized_text)
                    term_text = found_terms[term1]["text"][0]
                    relation_text = relation_text.replace(term_text, f"<e2> {term_text} </e2>")
                    term_text = found_terms[term2]["text"][0] 
                    relation_text = relation_text.replace(term_text, f"<e1> {term_text} </e1>")
                    relation_count += 1
                    relations[relation][" | ".join((term2, term1))]["sentences"].append(relation_text)
            if relation_count == 0:
                relation_text = " ".join(tokenized_text)
                term_text = found_terms[term1]["text"][0]
                relation_text = relation_text.replace(term_text, f"<e1> {term_text} </e1>")
                term_text = found_terms[term2]["text"][0] 
                relation_text = relation_text.replace(term_text, f"<e2> {term_text} </e2>")
                    
                if " | ".join((term1, term2)) not in relations["no-relation"]:
                    relations["no-relation"][" | ".join((term1, term2))] = {"sentences": [relation_text], "e1_representations": [], "e2_representations": []}
                else:
                    relations["no-relation"][" | ".join((term1, term2))]["sentences"].append(relation_text)
                
    
    return relations

terms = read_spacy_docs(f"{data_dir}/processed_data/kb_terms_spacy", nlp)
sentences1 = read_spacy_docs(f"{data_dir}/processed_data/openstax_biology_sentences_spacy", nlp)
sentences2 = read_spacy_docs(f"{data_dir}/processed_data/life_biology_sentences_spacy", nlp)
sentences = sentences1 + sentences2
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_tagger.pt', 'pretrain_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_lemmatizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_parser.pt', 'pretrain_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Done loading processors!
# ---
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_tagger.pt', 'pretrain_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_lemmatizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_parser.pt', 'pretrain_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Done loading processors!
# ---
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_tagger.pt', 'pretrain_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_lemmatizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt_parser.pt', 'pretrain_path': '/Users/mattboggess/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Done loading processors!
# ---

# %%
relations_db["no-relation"] = {}
for sentence in sentences:
    
    relations_db = locate_relations(sentence, terms, relations_db, nlp)

# %%
import json
with open(f"{data_dir}/processed_data/relations_db.json", "w") as f:
    json.dump(relations_db, f, indent=4)

# %% [markdown]
# # Explore Relations

# %%
with open(f"{data_dir}/processed_data/relations_db.json", "r") as f:
    db = json.load(f)

df = {"relation": [], "num_word_pairs": [], "word_pair": [], "num_sentences": []}

for rt in db:
    num_word_pairs = len(db[rt])
    for wp in db[rt]:
        df["relation"].append(rt)
        df["num_word_pairs"].append(num_word_pairs)
        df["word_pair"].append(wp)
        df["num_sentences"].append(len(db[rt][wp]["sentences"]))
df = pd.DataFrame(df)
df
# Out:
#            relation  num_word_pairs  \
# 0       no-relation           85446
# 1       no-relation           85446
# 2       no-relation           85446
# 3       no-relation           85446
# 4       no-relation           85446
# ...             ...             ...
# 100431   is-outside             166
# 100432   is-outside             166
# 100433   is-outside             166
# 100434   is-outside             166
# 100435   is-outside             166
#
#                                                 word_pair  num_sentences
# 0                                 light microscope -> end              1
# 1                                 end -> light microscope              1
# 2                                light microscope -> alga              1
# 3                                alga -> light microscope              1
# 4                                             end -> alga              2
# ...                                                   ...            ...
# 100431                         cytoplasm -> mitochondrion              2
# 100432                       extranuclear gene -> nucleus              0
# 100433  extracellular side -> wall cell inside isotoni...              0
# 100434           extra cellular matrix -> mate type alpha              0
# 100435                                 object -> arthropo              0
#
# [100436 rows x 4 columns]

# %%
df["zero"] = df["num_sentences"] == 0
df_avg = df.groupby(["relation", "zero"]).agg({"num_word_pairs": ["mean", "count"],
                                     "num_sentences": ["sum", "mean"]})
df_avg
# Out:
#                   num_word_pairs        num_sentences
#                             mean  count           sum       mean
# relation    zero
# abuts       False            110     18           146   8.111111
#             True             110     92             0   0.000000
# element     False            497     76           530   6.973684
#             True             497    421             0   0.000000
# has-part    False           4281    465          4714  10.137634
#             True            4281   3816             0   0.000000
# has-region  False           1561    117           861   7.358974
#             True            1561   1444             0   0.000000
# is-at       False            246     36           316   8.777778
#             True             246    210             0   0.000000
# is-inside   False            604     75           697   9.293333
#             True             604    529             0   0.000000
# is-outside  False            166     22           191   8.681818
#             True             166    144             0   0.000000
# no-relation False          85446  85446        252172   2.951244
# possesses   False            784     45           258   5.733333
#             True             784    739             0   0.000000
# subclass-of False           6741    468          1758   3.756410
#             True            6741   6273             0   0.000000

# %%
df.groupby(["relation", "zero"]).count()
# Out:
#                    num_word_pairs  word_pair  num_sentences
# relation    zero
# abuts       False              18         18             18
#             True               92         92             92
# element     False              76         76             76
#             True              421        421            421
# has-part    False             465        465            465
#             True             3816       3816           3816
# has-region  False             117        117            117
#             True             1444       1444           1444
# is-at       False              36         36             36
#             True              210        210            210
# is-inside   False              75         75             75
#             True              529        529            529
# is-outside  False              22         22             22
#             True              144        144            144
# no-relation False           85446      85446          85446
# possesses   False              45         45             45
#             True              739        739            739
# subclass-of False             468        468            468
#             True             6273       6273           6273

# %%
data = pd.read_csv(f"{data_dir}/raw_data/final_bio_parsed.csv")
data[(data.sentence.str.contains("nucleus") & (data.sentence.str.contains("cytosol")))].sentence.iat[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-264-fe6f7000a19c> in <module>
#       1 data = pd.read_csv(f"{data_dir}/raw_data/final_bio_parsed.csv")
# ----> 2 data[(data.sentence.str.contains("nucleus") & (data.sentence.str.contains("cytosol")))].sentence.iat[0]
#
# //anaconda3/envs/tokn/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2198
#    2199         key = self._convert_key(key)
# -> 2200         return self.obj._get_value(*key, takeable=self._takeable)
#    2201
#    2202     def __setitem__(self, key, value):
#
# //anaconda3/envs/tokn/lib/python3.7/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1399     def _get_value(self, label, takeable=False):
#    1400         if takeable is True:
# -> 1401             return com.maybe_box_datetimelike(self._values[label])
#    1402         return self.index.get_value(self._values, label)
#    1403
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# %%
STOP_WORDS
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}
