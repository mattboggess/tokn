# %% [markdown]
# # Relation Extraction EDA

# %%
import pandas as pd
import pickle
import json

from collections import defaultdict
import spacy

import stanfordnlp
from spacy_stanfordnlp import StanfordNLPLanguage
#stanfordnlp.download('en')
snlp = stanfordnlp.Pipeline(lang="en")
nlp = StanfordNLPLanguage(snlp)

import warnings
warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2

# fix for importing utils
import os
import sys
module_path = os.path.abspath(os.path.join('../utils'))
if module_path not in sys.path:
    sys.path.append(module_path)
from utils import tag_text, write_spacy_docs, read_spacy_docs

data_dir = '../data/relation_extraction'
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/home/mattboggess7/stanfordnlp_resources/en_ewt_models/en_ewt_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/home/mattboggess7/stanfordnlp_resources/en_ewt_models/en_ewt_tagger.pt', 'pretrain_path': '/home/mattboggess7/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/home/mattboggess7/stanfordnlp_resources/en_ewt_models/en_ewt_lemmatizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': '/home/mattboggess7/stanfordnlp_resources/en_ewt_models/en_ewt_parser.pt', 'pretrain_path': '/home/mattboggess7/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Done loading processors!
# ---

# %%
import re
term = "hela (HLA)"
re.match(".*\((.+)\).*", term).group(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-3350502cf014> in <module>
#       1 import re
#       2 term = "hela HLA"
# ----> 3 re.match(".*\((.+)\).*", term).group(1)
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
def process_term(key_term_text):
    term, _ = key_term_text.split(":")
    match = re.match(".*\((.+)\).*", term)
    if match:
        acronym = match.group(1)
        term = term.replace(f"({acronym})", "")
        return [term.strip(), acronym.strip()]
    
    return [term.strip()] 
term = "hela HLA): fhksh"
process_term(term)
# Out:
# ['hela HLA)']

# %%
import os
data_dir = "../data/relation_extraction/cwf"
files = os.listdir(data_dir)
for file in files:
    with open(f"{data_dir}/{file}", "r") as f:
        data = f.read()
        if 'part-of-speech ("n")' not in data:
            print(data)
# Out:
# (disable-classification)
# (_Concept-Word-Frame60100 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60100 now-has (word ("amass")))
# (_Concept-Word-Frame60100 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60100 now-has (synonym-for (|Collecting|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60011 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60011 now-has (word ("gear up")))
# (_Concept-Word-Frame60011 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60011 now-has (synonym-for (|Activate|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame52430 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame52430 now-has (word ("communicate a death signal")))
# (_Concept-Word-Frame52430 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame52430 now-has (grammatical-subject (agent)))
# (_Concept-Word-Frame52430 now-has (grammatical-object NIL))
# (_Concept-Word-Frame52430 now-has (preposition ((:pair instrument "using") (:pair object "with"))))
# (_Concept-Word-Frame52430 now-has (implied-participant NIL))
# (_Concept-Word-Frame52430 now-has (synonym-for (Cell-Communication-Leading-To-Apoptosis)))
# (_Concept-Word-Frame52430 now-has (primary-nominalization-for (Cell-Communication-Leading-To-Apoptosis)))
# (_Concept-Word-Frame52430 now-has (primary-verb-for (Cell-Communication-Leading-To-Apoptosis)))
# (_Concept-Word-Frame52430 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
#
# (_Concept-Word-Frame60373 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame60373 now-has (word ("reach")))
# (_Concept-Word-Frame60373 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60373 now-has (grammatical-subject (object)))
# (_Concept-Word-Frame60373 now-has (grammatical-object (destination)))
# (_Concept-Word-Frame60373 now-has (preposition NIL))
# (_Concept-Word-Frame60373 now-has (implied-participant NIL))
# (_Concept-Word-Frame60373 now-has (synonym-for (Go-To)))
# (_Concept-Word-Frame60373 now-has (primary-nominalization-for (Go-To)))
# (_Concept-Word-Frame60373 now-has (primary-verb-for (Go-To)))
# (_Concept-Word-Frame60373 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
#
# (_Concept-Word-Frame58249 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame58249 now-has (word ("conduct")))
# (_Concept-Word-Frame58249 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame58249 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame58249 now-has (grammatical-object NIL))
# (_Concept-Word-Frame58249 now-has (preposition NIL))
# (_Concept-Word-Frame58249 now-has (implied-participant NIL))
# (_Concept-Word-Frame58249 now-has (synonym-for (Saltatory-Conduction)))
# (_Concept-Word-Frame58249 now-has (primary-nominalization-for (Saltatory-Conduction)))
# (_Concept-Word-Frame58249 now-has (primary-verb-for (Saltatory-Conduction)))
# (_Concept-Word-Frame58249 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame60233 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60233 now-has (word ("come off")))
# (_Concept-Word-Frame60233 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60233 now-has (synonym-for (|Detach|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame60322 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame60322 now-has (word ("enter")))
# (_Concept-Word-Frame60322 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60322 now-has (grammatical-subject (object)))
# (_Concept-Word-Frame60322 now-has (grammatical-object NIL))
# (_Concept-Word-Frame60322 now-has (preposition NIL))
# (_Concept-Word-Frame60322 now-has (implied-participant (agent)))
# (_Concept-Word-Frame60322 now-has (synonym-for (Enter)))
# (_Concept-Word-Frame60322 now-has (primary-nominalization-for (Enter)))
# (_Concept-Word-Frame60322 now-has (primary-verb-for (Enter)))
# (_Concept-Word-Frame60322 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
#
# (_Concept-Word-Frame58218 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame58218 now-has (word ("signal")))
# (_Concept-Word-Frame58218 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame58218 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame58218 now-has (grammatical-object NIL))
# (_Concept-Word-Frame58218 now-has (preposition NIL))
# (_Concept-Word-Frame58218 now-has (implied-participant NIL))
# (_Concept-Word-Frame58218 now-has (synonym-for (Cell-Signaling-With-Nitric-Oxide)))
# (_Concept-Word-Frame58218 now-has (primary-nominalization-for (Cell-Signaling-With-Nitric-Oxide)))
# (_Concept-Word-Frame58218 now-has (primary-verb-for (Cell-Signaling-With-Nitric-Oxide)))
# (_Concept-Word-Frame58218 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
#
# (_Concept-Word-Frame61209 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame61209 now-has (word ("transfer")))
# (_Concept-Word-Frame61209 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61209 now-has (grammatical-subject (agent)))
# (_Concept-Word-Frame61209 now-has (grammatical-object (object)))
# (_Concept-Word-Frame61209 now-has (preposition NIL))
# (_Concept-Word-Frame61209 now-has (implied-participant NIL))
# (_Concept-Word-Frame61209 now-has (synonym-for NIL))
# (_Concept-Word-Frame61209 now-has (primary-nominalization-for NIL))
# (_Concept-Word-Frame61209 now-has (primary-verb-for NIL))
# (_Concept-Word-Frame61209 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame61198 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61198 now-has (word ("release")))
# (_Concept-Word-Frame61198 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61198 now-has (grammatical-subject (|agent|)))
# (_Concept-Word-Frame61198 now-has (grammatical-object (|object|)))
# (_Concept-Word-Frame61198 now-has (preposition ((:pair base "from"))))
# (_Concept-Word-Frame61198 now-has (synonym-for (|Release-Of-Calcium-Ion-By-Cell|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61349 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61349 now-has (word ("convert")))
# (_Concept-Word-Frame61349 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61349 now-has (grammatical-object (|raw-material|)))
# (_Concept-Word-Frame61349 now-has (preposition ((:pair result "to"))))
# (_Concept-Word-Frame61349 now-has (primary-verb-for (|Reverse-Reaction|)))
# (_Concept-Word-Frame61349 now-has (primary-nominalization-for (|Reverse-Reaction|)))
# (_Concept-Word-Frame61349 now-has (synonym-for (|Reverse-Reaction|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60025 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60025 now-has (word ("let in")))
# (_Concept-Word-Frame60025 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60025 now-has (synonym-for (|Admit|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60134 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60134 now-has (word ("convey")))
# (_Concept-Word-Frame60134 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60134 now-has (synonym-for (|Communicate|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame76420 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame76420 now-has (word ("cause disease")))
# (_Concept-Word-Frame76420 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame76420 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame76420 now-has (grammatical-object (agent)))
# (_Concept-Word-Frame76420 now-has (preposition ((:pair experiencer "in"))))
# (_Concept-Word-Frame76420 now-has (implied-participant NIL))
# (_Concept-Word-Frame76420 now-has (synonym-for (Cholera-Process)))
# (_Concept-Word-Frame76420 now-has (primary-nominalization-for (Cholera-Process)))
# (_Concept-Word-Frame76420 now-has (primary-verb-for (Cholera-Process)))
# (_Concept-Word-Frame76420 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame61258 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61258 now-has (word ("synthesize")))
# (_Concept-Word-Frame61258 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61258 now-has (grammatical-subject (|agent|)))
# (_Concept-Word-Frame61258 now-has (grammatical-object (|result|)))
# (_Concept-Word-Frame61258 now-has (preposition ((:pair raw-material "using"))))
# (_Concept-Word-Frame61258 now-has (primary-verb-for (|Synthesis-Of-Glucose-From-G3P|)))
# (_Concept-Word-Frame61258 now-has (primary-nominalization-for (|Synthesis-Of-Glucose-From-G3P|)))
# (_Concept-Word-Frame61258 now-has (synonym-for (|Synthesis-Of-Glucose-From-G3P|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61318 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61318 now-has (word ("differentiate")))
# (_Concept-Word-Frame61318 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61318 now-has (primary-verb-for (|Stem-Cell-Differentiation-In-Brain|)))
# (_Concept-Word-Frame61318 now-has (primary-nominalization-for (|Stem-Cell-Differentiation-In-Brain|)))
# (_Concept-Word-Frame61318 now-has (synonym-for (|Stem-Cell-Differentiation-In-Brain|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61089 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61089 now-has (word ("code")))
# (_Concept-Word-Frame61089 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61089 now-has (preposition ((:pair object "for"))))
# (_Concept-Word-Frame61089 now-has (primary-verb-for (|Coding-For-Amino-Acid|)))
# (_Concept-Word-Frame61089 now-has (primary-nominalization-for (|Coding-For-Amino-Acid|)))
# (_Concept-Word-Frame61089 now-has (synonym-for (|Coding-For-Amino-Acid|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60074 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60074 now-has (word ("go")))
# (_Concept-Word-Frame60074 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60074 now-has (synonym-for (|Break|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame52737 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame52737 now-has (word ("communicate")))
# (_Concept-Word-Frame52737 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame52737 now-has (grammatical-subject (agent)))
# (_Concept-Word-Frame52737 now-has (grammatical-object NIL))
# (_Concept-Word-Frame52737 now-has (preposition ((:pair object "with"))))
# (_Concept-Word-Frame52737 now-has (implied-participant NIL))
# (_Concept-Word-Frame52737 now-has (synonym-for (Cell-Communication-In-Plant)))
# (_Concept-Word-Frame52737 now-has (primary-nominalization-for (Cell-Communication-In-Plant)))
# (_Concept-Word-Frame52737 now-has (primary-verb-for (Cell-Communication-In-Plant)))
# (_Concept-Word-Frame52737 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
#
# (_Concept-Word-Frame60087 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame60087 now-has (word ("take")))
# (_Concept-Word-Frame60087 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60087 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame60087 now-has (grammatical-object NIL))
# (_Concept-Word-Frame60087 now-has (preposition NIL))
# (_Concept-Word-Frame60087 now-has (implied-participant NIL))
# (_Concept-Word-Frame60087 now-has (synonym-for (Carry)))
# (_Concept-Word-Frame60087 now-has (primary-nominalization-for NIL))
# (_Concept-Word-Frame60087 now-has (primary-verb-for NIL))
# (_Concept-Word-Frame60087 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
#
# (_Concept-Word-Frame60316 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame60316 now-has (word ("give out")))
# (_Concept-Word-Frame60316 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60316 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame60316 now-has (grammatical-object NIL))
# (_Concept-Word-Frame60316 now-has (preposition NIL))
# (_Concept-Word-Frame60316 now-has (implied-participant NIL))
# (_Concept-Word-Frame60316 now-has (synonym-for (Emit)))
# (_Concept-Word-Frame60316 now-has (primary-nominalization-for NIL))
# (_Concept-Word-Frame60316 now-has (primary-verb-for NIL))
# (_Concept-Word-Frame60316 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
#
# (_Concept-Word-Frame52766 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame52766 now-has (word ("hydrolyze")))
# (_Concept-Word-Frame52766 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame52766 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame52766 now-has (grammatical-object NIL))
# (_Concept-Word-Frame52766 now-has (preposition NIL))
# (_Concept-Word-Frame52766 now-has (implied-participant NIL))
# (_Concept-Word-Frame52766 now-has (synonym-for (Hydrolysis)))
# (_Concept-Word-Frame52766 now-has (primary-nominalization-for NIL))
# (_Concept-Word-Frame52766 now-has (primary-verb-for NIL))
# (_Concept-Word-Frame52766 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame60207 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60207 now-has (word ("delude")))
# (_Concept-Word-Frame60207 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60207 now-has (synonym-for (|Deceive|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60347 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60347 now-has (word ("state")))
# (_Concept-Word-Frame60347 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60347 now-has (synonym-for (|Express|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61625 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61625 now-has (word ("regulate")))
# (_Concept-Word-Frame61625 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61625 now-has (primary-verb-for (|Blood-Sugar-Regulation|)))
# (_Concept-Word-Frame61625 now-has (primary-nominalization-for (|Blood-Sugar-Regulation|)))
# (_Concept-Word-Frame61625 now-has (synonym-for (|Blood-Sugar-Regulation|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60549 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60549 now-has (word ("perceive")))
# (_Concept-Word-Frame60549 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60549 now-has (primary-verb-for (|Perceive|)))
# (_Concept-Word-Frame60549 now-has (primary-nominalization-for (|Perceive|)))
# (_Concept-Word-Frame60549 now-has (synonym-for (|Perceive|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60409 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60409 now-has (word ("better")))
# (_Concept-Word-Frame60409 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60409 now-has (synonym-for (|Improvement|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61765 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61765 now-has (word ("crossbreed")))
# (_Concept-Word-Frame61765 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61765 now-has (primary-verb-for (|Cross-breeding-event|)))
# (_Concept-Word-Frame61765 now-has (primary-nominalization-for (|Cross-breeding-event|)))
# (_Concept-Word-Frame61765 now-has (synonym-for (|Cross-breeding-event|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61674 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61674 now-has (word ("delete")))
# (_Concept-Word-Frame61674 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61674 now-has (primary-verb-for (|Deletion-Of-Chromosome-Fragment|)))
# (_Concept-Word-Frame61674 now-has (primary-nominalization-for (|Deletion-Of-Chromosome-Fragment|)))
# (_Concept-Word-Frame61674 now-has (synonym-for (|Deletion-Of-Chromosome-Fragment|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60518 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60518 now-has (word ("go")))
# (_Concept-Word-Frame60518 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60518 now-has (synonym-for (|Move|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60689 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60689 now-has (word ("fix")))
# (_Concept-Word-Frame60689 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60689 now-has (synonym-for (|Specify|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60458 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60458 now-has (word ("stow")))
# (_Concept-Word-Frame60458 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60458 now-has (synonym-for (|Load|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61734 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61734 now-has (word ("perform cellular respiration")))
# (_Concept-Word-Frame61734 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61734 now-has (primary-verb-for (|Cellular-Respiration-Of-Fat|)))
# (_Concept-Word-Frame61734 now-has (primary-nominalization-for (|Cellular-Respiration-Of-Fat|)))
# (_Concept-Word-Frame61734 now-has (synonym-for (|Cellular-Respiration-Of-Fat|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame58591 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame58591 now-has (word ("synaptic signaling between neurons leading to ion inflow")))
# (_Concept-Word-Frame58591 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame58591 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame58591 now-has (grammatical-object NIL))
# (_Concept-Word-Frame58591 now-has (preposition NIL))
# (_Concept-Word-Frame58591 now-has (implied-participant NIL))
# (_Concept-Word-Frame58591 now-has (synonym-for (Cell-Communication-Between-Neurons-Leading-to-Ion-Inflow)))
# (_Concept-Word-Frame58591 now-has (primary-nominalization-for NIL))
# (_Concept-Word-Frame58591 now-has (primary-verb-for NIL))
# (_Concept-Word-Frame58591 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame61687 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61687 now-has (word ("repair")))
# (_Concept-Word-Frame61687 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61687 now-has (primary-verb-for (|Nucleotide-Excision-Repair|)))
# (_Concept-Word-Frame61687 now-has (primary-nominalization-for (|Nucleotide-Excision-Repair|)))
# (_Concept-Word-Frame61687 now-has (synonym-for (|Nucleotide-Excision-Repair|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61516 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61516 now-has (word ("clone")))
# (_Concept-Word-Frame61516 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61516 now-has (primary-verb-for (|Cloning-Eukaryotic-Gene|)))
# (_Concept-Word-Frame61516 now-has (primary-nominalization-for (|Cloning-Eukaryotic-Gene|)))
# (_Concept-Word-Frame61516 now-has (synonym-for (|Cloning-Eukaryotic-Gene|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60979 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60979 now-has (word ("pilot")))
# (_Concept-Word-Frame60979 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60979 now-has (primary-verb-for (|Piloting|)))
# (_Concept-Word-Frame60979 now-has (primary-nominalization-for (|Piloting|)))
# (_Concept-Word-Frame60979 now-has (synonym-for (|Piloting|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame58843 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame58843 now-has (word ("convert")))
# (_Concept-Word-Frame58843 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame58843 now-has (grammatical-subject (agent)))
# (_Concept-Word-Frame58843 now-has (grammatical-object (raw-material)))
# (_Concept-Word-Frame58843 now-has (preposition ((:pair base "in") (:pair result "to"))))
# (_Concept-Word-Frame58843 now-has (implied-participant NIL))
# (_Concept-Word-Frame58843 now-has (synonym-for (Synthesis-Of-Glucose-6-Phosphate-From-Glycogen)))
# (_Concept-Word-Frame58843 now-has (primary-nominalization-for (Synthesis-Of-Glucose-6-Phosphate-From-Glycogen)))
# (_Concept-Word-Frame58843 now-has (primary-verb-for (Synthesis-Of-Glucose-6-Phosphate-From-Glycogen)))
# (_Concept-Word-Frame58843 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame60839 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60839 now-has (word ("deepen")))
# (_Concept-Word-Frame60839 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60839 now-has (primary-verb-for (|Deepen|)))
# (_Concept-Word-Frame60839 now-has (primary-nominalization-for (|Deepen|)))
# (_Concept-Word-Frame60839 now-has (synonym-for (|Deepen|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60928 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60928 now-has (word ("inquire")))
# (_Concept-Word-Frame60928 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60928 now-has (primary-verb-for (|In-Vitro|)))
# (_Concept-Word-Frame60928 now-has (primary-nominalization-for (|In-Vitro|)))
# (_Concept-Word-Frame60928 now-has (synonym-for (|In-Vitro|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61547 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61547 now-has (word ("splice")))
# (_Concept-Word-Frame61547 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61547 now-has (primary-verb-for (|Alternative-RNA-Splicing|)))
# (_Concept-Word-Frame61547 now-has (primary-nominalization-for (|Alternative-RNA-Splicing|)))
# (_Concept-Word-Frame61547 now-has (synonym-for (|Alternative-RNA-Splicing|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61796 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61796 now-has (word ("germinate")))
# (_Concept-Word-Frame61796 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61796 now-has (primary-verb-for (|Germination|)))
# (_Concept-Word-Frame61796 now-has (primary-nominalization-for (|Germination|)))
# (_Concept-Word-Frame61796 now-has (synonym-for (|Germination|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61407 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61407 now-has (word ("process")))
# (_Concept-Word-Frame61407 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61407 now-has (primary-verb-for (|Food-Processing-In-Ruminant|)))
# (_Concept-Word-Frame61407 now-has (primary-nominalization-for (|Food-Processing-In-Ruminant|)))
# (_Concept-Word-Frame61407 now-has (synonym-for (|Food-Processing-In-Ruminant|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame60868 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame60868 now-has (word ("vaporize")))
# (_Concept-Word-Frame60868 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60868 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame60868 now-has (grammatical-object NIL))
# (_Concept-Word-Frame60868 now-has (preposition NIL))
# (_Concept-Word-Frame60868 now-has (implied-participant NIL))
# (_Concept-Word-Frame60868 now-has (synonym-for (Evaporation)))
# (_Concept-Word-Frame60868 now-has (primary-nominalization-for NIL))
# (_Concept-Word-Frame60868 now-has (primary-verb-for NIL))
# (_Concept-Word-Frame60868 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame61803 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61803 now-has (word ("undergo the two cell stage")))
# (_Concept-Word-Frame61803 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61803 now-has (grammatical-subject (|object|)))
# (_Concept-Word-Frame61803 now-has (primary-verb-for (|Two-Cell-Stage|)))
# (_Concept-Word-Frame61803 now-has (primary-nominalization-for (|Two-Cell-Stage|)))
# (_Concept-Word-Frame61803 now-has (synonym-for (|Two-Cell-Stage|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame57668 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame57668 now-has (word ("release")))
# (_Concept-Word-Frame57668 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame57668 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame57668 now-has (grammatical-object (result)))
# (_Concept-Word-Frame57668 now-has (preposition ((:pair base "in") (:pair site "from") (:pair agent "by"))))
# (_Concept-Word-Frame57668 now-has (implied-participant NIL))
# (_Concept-Word-Frame57668 now-has (synonym-for (Exergonic-Process)))
# (_Concept-Word-Frame57668 now-has (primary-nominalization-for (Exergonic-Process)))
# (_Concept-Word-Frame57668 now-has (primary-verb-for (Exergonic-Process)))
# (_Concept-Word-Frame57668 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame61700 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61700 now-has (word ("take part in an anabolic pathway")))
# (_Concept-Word-Frame61700 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61700 now-has (primary-verb-for (|Anabolic-Pathway|)))
# (_Concept-Word-Frame61700 now-has (primary-nominalization-for (|Anabolic-Pathway|)))
# (_Concept-Word-Frame61700 now-has (synonym-for (|Anabolic-Pathway|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61640 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61640 now-has (word ("intercellularly join")))
# (_Concept-Word-Frame61640 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61640 now-has (preposition ((:pair base "with"))))
# (_Concept-Word-Frame61640 now-has (primary-verb-for (|Intercellular-Joining|)))
# (_Concept-Word-Frame61640 now-has (primary-nominalization-for (|Intercellular-Joining|)))
# (_Concept-Word-Frame61640 now-has (synonym-for (|Intercellular-Joining|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61751 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61751 now-has (word ("translocate")))
# (_Concept-Word-Frame61751 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61751 now-has (primary-verb-for (|Chromosomal-Translocation|)))
# (_Concept-Word-Frame61751 now-has (primary-nominalization-for (|Chromosomal-Translocation|)))
# (_Concept-Word-Frame61751 now-has (synonym-for (|Chromosomal-Translocation|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame56555 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame56555 now-has (word ("endocrine signaling")))
# (_Concept-Word-Frame56555 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame56555 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame56555 now-has (grammatical-object NIL))
# (_Concept-Word-Frame56555 now-has (preposition NIL))
# (_Concept-Word-Frame56555 now-has (implied-participant NIL))
# (_Concept-Word-Frame56555 now-has (synonym-for (Cell-Communication-With-Endocrine-Hormone)))
# (_Concept-Word-Frame56555 now-has (primary-nominalization-for NIL))
# (_Concept-Word-Frame56555 now-has (primary-verb-for NIL))
# (_Concept-Word-Frame56555 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame61611 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61611 now-has (word ("transport")))
# (_Concept-Word-Frame61611 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61611 now-has (primary-verb-for (|Cotransport|)))
# (_Concept-Word-Frame61611 now-has (primary-nominalization-for (|Cotransport|)))
# (_Concept-Word-Frame61611 now-has (synonym-for (|Cotransport|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61580 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61580 now-has (word ("undergo the oxygen cycle")))
# (_Concept-Word-Frame61580 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61580 now-has (grammatical-subject (|object|)))
# (_Concept-Word-Frame61580 now-has (primary-verb-for (|Oxygen-Cycle|)))
# (_Concept-Word-Frame61580 now-has (primary-nominalization-for (|Oxygen-Cycle|)))
# (_Concept-Word-Frame61580 now-has (synonym-for (|Oxygen-Cycle|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61433 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61433 now-has (word ("develop")))
# (_Concept-Word-Frame61433 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61433 now-has (grammatical-subject (|experiencer|)))
# (_Concept-Word-Frame61433 now-has (preposition ((:pair result "into"))))
# (_Concept-Word-Frame61433 now-has (primary-verb-for (|Organismal-Development|)))
# (_Concept-Word-Frame61433 now-has (primary-nominalization-for (|Organismal-Development|)))
# (_Concept-Word-Frame61433 now-has (synonym-for (|Organismal-Development|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame58665 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame58665 now-has (word ("convert")))
# (_Concept-Word-Frame58665 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame58665 now-has (grammatical-subject (agent)))
# (_Concept-Word-Frame58665 now-has (grammatical-object (raw-material)))
# (_Concept-Word-Frame58665 now-has (preposition ((:pair base "in") (:pair result "to"))))
# (_Concept-Word-Frame58665 now-has (implied-participant (object)))
# (_Concept-Word-Frame58665 now-has (synonym-for (Synthesis-Of-Glutamine-with-ATP)))
# (_Concept-Word-Frame58665 now-has (primary-nominalization-for (Synthesis-Of-Glutamine-with-ATP)))
# (_Concept-Word-Frame58665 now-has (primary-verb-for (Synthesis-Of-Glutamine-with-ATP)))
# (_Concept-Word-Frame58665 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
#
# (_Concept-Word-Frame79175 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame79175 now-has (word ("convert")))
# (_Concept-Word-Frame79175 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame79175 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame79175 now-has (grammatical-object (raw-material)))
# (_Concept-Word-Frame79175 now-has (preposition ((:pair result "to"))))
# (_Concept-Word-Frame79175 now-has (implied-participant NIL))
# (_Concept-Word-Frame79175 now-has (synonym-for (Prokaryotic-Oxidative-Phosphorylation)))
# (_Concept-Word-Frame79175 now-has (primary-nominalization-for (Prokaryotic-Oxidative-Phosphorylation)))
# (_Concept-Word-Frame79175 now-has (primary-verb-for (Prokaryotic-Oxidative-Phosphorylation)))
# (_Concept-Word-Frame79175 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame61573 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61573 now-has (word ("undergo the fungal life cycle")))
# (_Concept-Word-Frame61573 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61573 now-has (grammatical-subject (|object|)))
# (_Concept-Word-Frame61573 now-has (primary-verb-for (|Fungal-Life-Cycle|)))
# (_Concept-Word-Frame61573 now-has (primary-nominalization-for (|Fungal-Life-Cycle|)))
# (_Concept-Word-Frame61573 now-has (synonym-for (|Fungal-Life-Cycle|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61462 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61462 now-has (word ("signal")))
# (_Concept-Word-Frame61462 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61462 now-has (preposition ((:pair base "to") (:pair experiencer "in"))))
# (_Concept-Word-Frame61462 now-has (primary-verb-for (|Cell-Signaling-Using-Testosterone-Receptor|)))
# (_Concept-Word-Frame61462 now-has (primary-nominalization-for (|Cell-Signaling-Using-Testosterone-Receptor|)))
# (_Concept-Word-Frame61462 now-has (synonym-for (|Cell-Signaling-Using-Testosterone-Receptor|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame64247 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame64247 now-has (word ("move")))
# (_Concept-Word-Frame64247 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame64247 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame64247 now-has (grammatical-object (object)))
# (_Concept-Word-Frame64247 now-has (preposition ((:pair instrument "using"))))
# (_Concept-Word-Frame64247 now-has (implied-participant (agent)))
# (_Concept-Word-Frame64247 now-has (synonym-for (Locomotion-Of-Eukaryotic-Cell-By-Motile-Cilium)))
# (_Concept-Word-Frame64247 now-has (primary-nominalization-for (Locomotion-Of-Eukaryotic-Cell-By-Motile-Cilium)))
# (_Concept-Word-Frame64247 now-has (primary-verb-for (Locomotion-Of-Eukaryotic-Cell-By-Motile-Cilium)))
# (_Concept-Word-Frame64247 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame61522 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61522 now-has (word ("change")))
# (_Concept-Word-Frame61522 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61522 now-has (grammatical-subject (|agent|)))
# (_Concept-Word-Frame61522 now-has (grammatical-object (|object|)))
# (_Concept-Word-Frame61522 now-has (preposition ((:pair result "to"))))
# (_Concept-Word-Frame61522 now-has (primary-verb-for (|Change-Chromosome-Structure|)))
# (_Concept-Word-Frame61522 now-has (primary-nominalization-for (|Change-Chromosome-Structure|)))
# (_Concept-Word-Frame61522 now-has (synonym-for (|Change-Chromosome-Structure|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame59548 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame59548 now-has (word ("undergo cellular process")))
# (_Concept-Word-Frame59548 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame59548 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame59548 now-has (grammatical-object NIL))
# (_Concept-Word-Frame59548 now-has (preposition NIL))
# (_Concept-Word-Frame59548 now-has (implied-participant NIL))
# (_Concept-Word-Frame59548 now-has (synonym-for (Cellular-Process)))
# (_Concept-Word-Frame59548 now-has (primary-nominalization-for (Cellular-Process)))
# (_Concept-Word-Frame59548 now-has (primary-verb-for (Cellular-Process)))
# (_Concept-Word-Frame59548 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame61532 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61532 now-has (word ("mutate")))
# (_Concept-Word-Frame61532 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61532 now-has (primary-verb-for (|Mutation|)))
# (_Concept-Word-Frame61532 now-has (primary-nominalization-for (|Mutation|)))
# (_Concept-Word-Frame61532 now-has (synonym-for (|Mutation|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame61472 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame61472 now-has (word ("signal")))
# (_Concept-Word-Frame61472 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61472 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame61472 now-has (grammatical-object NIL))
# (_Concept-Word-Frame61472 now-has (preposition ((:pair experiencer "in") (:pair base "to"))))
# (_Concept-Word-Frame61472 now-has (implied-participant NIL))
# (_Concept-Word-Frame61472 now-has (synonym-for (Neural-Signaling)))
# (_Concept-Word-Frame61472 now-has (primary-nominalization-for NIL))
# (_Concept-Word-Frame61472 now-has (primary-verb-for NIL))
# (_Concept-Word-Frame61472 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
#
# (_Concept-Word-Frame51296 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame51296 now-has (word ("convert")))
# (_Concept-Word-Frame51296 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame51296 now-has (grammatical-subject (agent)))
# (_Concept-Word-Frame51296 now-has (grammatical-object (raw-material)))
# (_Concept-Word-Frame51296 now-has (preposition ((:pair result "to"))))
# (_Concept-Word-Frame51296 now-has (implied-participant NIL))
# (_Concept-Word-Frame51296 now-has (synonym-for (Shell-Calcification)))
# (_Concept-Word-Frame51296 now-has (primary-nominalization-for (Shell-Calcification)))
# (_Concept-Word-Frame51296 now-has (primary-verb-for (Shell-Calcification)))
# (_Concept-Word-Frame51296 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame61563 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61563 now-has (word ("undergo the ATP cycle")))
# (_Concept-Word-Frame61563 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61563 now-has (grammatical-subject (|object|)))
# (_Concept-Word-Frame61563 now-has (primary-verb-for (|ATP-Cycle|)))
# (_Concept-Word-Frame61563 now-has (primary-nominalization-for (|ATP-Cycle|)))
# (_Concept-Word-Frame61563 now-has (synonym-for (|ATP-Cycle|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61423 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61423 now-has (word ("repair")))
# (_Concept-Word-Frame61423 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61423 now-has (primary-verb-for (|DNA-Repair|)))
# (_Concept-Word-Frame61423 now-has (primary-nominalization-for (|DNA-Repair|)))
# (_Concept-Word-Frame61423 now-has (synonym-for (|DNA-Repair|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame54722 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame54722 now-has (word ("relay a signal")))
# (_Concept-Word-Frame54722 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame54722 now-has (grammatical-subject (base)))
# (_Concept-Word-Frame54722 now-has (grammatical-object NIL))
# (_Concept-Word-Frame54722 now-has (preposition NIL))
# (_Concept-Word-Frame54722 now-has (implied-participant NIL))
# (_Concept-Word-Frame54722 now-has (synonym-for (Signal-Transduction)))
# (_Concept-Word-Frame54722 now-has (primary-nominalization-for (Signal-Transduction)))
# (_Concept-Word-Frame54722 now-has (primary-verb-for (Signal-Transduction)))
# (_Concept-Word-Frame54722 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
#
# (_Concept-Word-Frame64346 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame64346 now-has (word ("tissue repair")))
# (_Concept-Word-Frame64346 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame64346 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame64346 now-has (grammatical-object (object)))
# (_Concept-Word-Frame64346 now-has (preposition NIL))
# (_Concept-Word-Frame64346 now-has (implied-participant NIL))
# (_Concept-Word-Frame64346 now-has (synonym-for (Wound-Repair)))
# (_Concept-Word-Frame64346 now-has (primary-nominalization-for NIL))
# (_Concept-Word-Frame64346 now-has (primary-verb-for NIL))
# (_Concept-Word-Frame64346 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame61590 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61590 now-has (word ("undergo the sulfur cycle")))
# (_Concept-Word-Frame61590 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61590 now-has (grammatical-subject (|object|)))
# (_Concept-Word-Frame61590 now-has (primary-verb-for (|Sulfur-Cycle|)))
# (_Concept-Word-Frame61590 now-has (primary-nominalization-for (|Sulfur-Cycle|)))
# (_Concept-Word-Frame61590 now-has (synonym-for (|Sulfur-Cycle|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61601 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61601 now-has (word ("control glycolysis")))
# (_Concept-Word-Frame61601 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61601 now-has (primary-verb-for (|Control-Of-Glycolysis|)))
# (_Concept-Word-Frame61601 now-has (synonym-for (|Control-Of-Glycolysis|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61741 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61741 now-has (word ("perform cellular work")))
# (_Concept-Word-Frame61741 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61741 now-has (primary-verb-for (|Cellular-Work-Involving-Phosphorylation|)))
# (_Concept-Word-Frame61741 now-has (primary-nominalization-for (|Cellular-Work-Involving-Phosphorylation|)))
# (_Concept-Word-Frame61741 now-has (synonym-for (|Cellular-Work-Involving-Phosphorylation|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame61650 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame61650 now-has (word ("undergo anaphase")))
# (_Concept-Word-Frame61650 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61650 now-has (grammatical-subject (base)))
# (_Concept-Word-Frame61650 now-has (grammatical-object NIL))
# (_Concept-Word-Frame61650 now-has (preposition NIL))
# (_Concept-Word-Frame61650 now-has (implied-participant (result)))
# (_Concept-Word-Frame61650 now-has (synonym-for (Anaphase)))
# (_Concept-Word-Frame61650 now-has (primary-nominalization-for (Anaphase)))
# (_Concept-Word-Frame61650 now-has (primary-verb-for (Anaphase)))
# (_Concept-Word-Frame61650 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
#
# (_Concept-Word-Frame58406 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame58406 now-has (word ("convert")))
# (_Concept-Word-Frame58406 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame58406 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame58406 now-has (grammatical-object (raw-material)))
# (_Concept-Word-Frame58406 now-has (preposition ((:pair base "in") (:pair result "to"))))
# (_Concept-Word-Frame58406 now-has (implied-participant NIL))
# (_Concept-Word-Frame58406 now-has (synonym-for (Substrate-Level-Phosphorylation)))
# (_Concept-Word-Frame58406 now-has (primary-nominalization-for (Substrate-Level-Phosphorylation)))
# (_Concept-Word-Frame58406 now-has (primary-verb-for (Substrate-Level-Phosphorylation)))
# (_Concept-Word-Frame58406 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame61813 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61813 now-has (word ("perform a Franklin X-ray diffraction experiment")))
# (_Concept-Word-Frame61813 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61813 now-has (primary-verb-for (|Franklin-X-ray-Diffraction-Experiment|)))
# (_Concept-Word-Frame61813 now-has (primary-nominalization-for (|Franklin-X-ray-Diffraction-Experiment|)))
# (_Concept-Word-Frame61813 now-has (synonym-for (|Franklin-X-ray-Diffraction-Experiment|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61710 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61710 now-has (word ("analyze bioenergetically")))
# (_Concept-Word-Frame61710 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61710 now-has (primary-verb-for (|Bioenergetics|)))
# (_Concept-Word-Frame61710 now-has (primary-nominalization-for (|Bioenergetics|)))
# (_Concept-Word-Frame61710 now-has (synonym-for (|Bioenergetics|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame65088 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame65088 now-has (word ("rotate")))
# (_Concept-Word-Frame65088 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame65088 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame65088 now-has (grammatical-object NIL))
# (_Concept-Word-Frame65088 now-has (preposition NIL))
# (_Concept-Word-Frame65088 now-has (implied-participant NIL))
# (_Concept-Word-Frame65088 now-has (synonym-for (Rotation-Of-Flagella-In-Prokaryote)))
# (_Concept-Word-Frame65088 now-has (primary-nominalization-for (Rotation-Of-Flagella-In-Prokaryote)))
# (_Concept-Word-Frame65088 now-has (primary-verb-for (Rotation-Of-Flagella-In-Prokaryote)))
# (_Concept-Word-Frame65088 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
#
# (_Concept-Word-Frame58894 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame58894 now-has (word ("convert")))
# (_Concept-Word-Frame58894 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame58894 now-has (grammatical-subject (agent)))
# (_Concept-Word-Frame58894 now-has (grammatical-object (raw-material)))
# (_Concept-Word-Frame58894 now-has (preposition ((:pair base "in") (:pair result "to"))))
# (_Concept-Word-Frame58894 now-has (implied-participant NIL))
# (_Concept-Word-Frame58894 now-has (synonym-for (Synthesis-Of-Glucose-From-Pyruvate)))
# (_Concept-Word-Frame58894 now-has (primary-nominalization-for (Synthesis-Of-Glucose-From-Pyruvate)))
# (_Concept-Word-Frame58894 now-has (primary-verb-for (Synthesis-Of-Glucose-From-Pyruvate)))
# (_Concept-Word-Frame58894 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
#
# (_Concept-Word-Frame54780 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame54780 now-has (word ("measure absorption")))
# (_Concept-Word-Frame54780 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame54780 now-has (grammatical-subject (agent)))
# (_Concept-Word-Frame54780 now-has (grammatical-object NIL))
# (_Concept-Word-Frame54780 now-has (preposition ((:pair result "resulting in") (:pair instrument "using") (:pair base "by") (:pair raw-material "of"))))
# (_Concept-Word-Frame54780 now-has (implied-participant NIL))
# (_Concept-Word-Frame54780 now-has (synonym-for (Spectrophotometry)))
# (_Concept-Word-Frame54780 now-has (primary-nominalization-for (Spectrophotometry)))
# (_Concept-Word-Frame54780 now-has (primary-verb-for (Spectrophotometry)))
# (_Concept-Word-Frame54780 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame60878 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60878 now-has (word ("evaporate")))
# (_Concept-Word-Frame60878 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60878 now-has (primary-verb-for (|Evaporative-Cooling-Of-Water|)))
# (_Concept-Word-Frame60878 now-has (primary-nominalization-for (|Evaporative-Cooling-Of-Water|)))
# (_Concept-Word-Frame60878 now-has (synonym-for (|Evaporative-Cooling-Of-Water|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61417 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61417 now-has (word ("fingerpring")))
# (_Concept-Word-Frame61417 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61417 now-has (primary-verb-for (|DNA-Fingerprinting|)))
# (_Concept-Word-Frame61417 now-has (primary-nominalization-for (|DNA-Fingerprinting|)))
# (_Concept-Word-Frame61417 now-has (synonym-for (|DNA-Fingerprinting|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61786 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61786 now-has (word ("respond")))
# (_Concept-Word-Frame61786 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61786 now-has (primary-verb-for (|Inflammatory-Response|)))
# (_Concept-Word-Frame61786 now-has (primary-nominalization-for (|Inflammatory-Response|)))
# (_Concept-Word-Frame61786 now-has (synonym-for (|Inflammatory-Response|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame58701 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame58701 now-has (word ("divide")))
# (_Concept-Word-Frame58701 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame58701 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame58701 now-has (grammatical-object NIL))
# (_Concept-Word-Frame58701 now-has (preposition NIL))
# (_Concept-Word-Frame58701 now-has (implied-participant NIL))
# (_Concept-Word-Frame58701 now-has (synonym-for (Cell-Division-In-Yeast)))
# (_Concept-Word-Frame58701 now-has (primary-nominalization-for (Cell-Division-In-Yeast)))
# (_Concept-Word-Frame58701 now-has (primary-verb-for (Cell-Division-In-Yeast)))
# (_Concept-Word-Frame58701 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
#
# (_Concept-Word-Frame61557 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame61557 now-has (word ("perform osmosis")))
# (_Concept-Word-Frame61557 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61557 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame61557 now-has (grammatical-object NIL))
# (_Concept-Word-Frame61557 now-has (preposition NIL))
# (_Concept-Word-Frame61557 now-has (implied-participant NIL))
# (_Concept-Word-Frame61557 now-has (synonym-for (Osmosis)))
# (_Concept-Word-Frame61557 now-has (primary-nominalization-for NIL))
# (_Concept-Word-Frame61557 now-has (primary-verb-for NIL))
# (_Concept-Word-Frame61557 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# ...
# (_Concept-Word-Frame61486 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61486 now-has (preposition ((:pair base "to") (:pair experiencer "in"))))
# (_Concept-Word-Frame61486 now-has (primary-verb-for (|Synaptic-Signaling|)))
# (_Concept-Word-Frame61486 now-has (primary-nominalization-for (|Synaptic-Signaling|)))
# (_Concept-Word-Frame61486 now-has (synonym-for (|Synaptic-Signaling|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61717 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61717 now-has (word ("perform biotechnology")))
# (_Concept-Word-Frame61717 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61717 now-has (primary-verb-for (|Biotechnology|)))
# (_Concept-Word-Frame61717 now-has (primary-nominalization-for (|Biotechnology|)))
# (_Concept-Word-Frame61717 now-has (synonym-for (|Biotechnology|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame61814 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame61814 now-has (word ("respond hypersensitively")))
# (_Concept-Word-Frame61814 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61814 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame61814 now-has (grammatical-object NIL))
# (_Concept-Word-Frame61814 now-has (preposition NIL))
# (_Concept-Word-Frame61814 now-has (implied-participant NIL))
# (_Concept-Word-Frame61814 now-has (synonym-for NIL))
# (_Concept-Word-Frame61814 now-has (primary-nominalization-for NIL))
# (_Concept-Word-Frame61814 now-has (primary-verb-for NIL))
# (_Concept-Word-Frame61814 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame61535 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61535 now-has (word ("mutate")))
# (_Concept-Word-Frame61535 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61535 now-has (primary-verb-for (|Frameshift-Mutation|)))
# (_Concept-Word-Frame61535 now-has (primary-nominalization-for (|Frameshift-Mutation|)))
# (_Concept-Word-Frame61535 now-has (synonym-for (|Frameshift-Mutation|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame60719 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame60719 now-has (word ("break up")))
# (_Concept-Word-Frame60719 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60719 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame60719 now-has (grammatical-object NIL))
# (_Concept-Word-Frame60719 now-has (preposition NIL))
# (_Concept-Word-Frame60719 now-has (implied-participant NIL))
# (_Concept-Word-Frame60719 now-has (synonym-for (Take-Apart)))
# (_Concept-Word-Frame60719 now-has (primary-nominalization-for NIL))
# (_Concept-Word-Frame60719 now-has (primary-verb-for NIL))
# (_Concept-Word-Frame60719 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame60608 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60608 now-has (word ("substitute")))
# (_Concept-Word-Frame60608 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60608 now-has (synonym-for (|Replace|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60599 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60599 now-has (word ("remove")))
# (_Concept-Word-Frame60599 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60599 now-has (grammatical-subject (|agent|)))
# (_Concept-Word-Frame60599 now-has (grammatical-object (|object|)))
# (_Concept-Word-Frame60599 now-has (preposition ((:pair base "from"))))
# (_Concept-Word-Frame60599 now-has (primary-verb-for (|Remove|)))
# (_Concept-Word-Frame60599 now-has (primary-nominalization-for (|Remove|)))
# (_Concept-Word-Frame60599 now-has (synonym-for (|Remove|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60748 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60748 now-has (word ("convey")))
# (_Concept-Word-Frame60748 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60748 now-has (synonym-for (|Transmit|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61424 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61424 now-has (word ("initiate replication")))
# (_Concept-Word-Frame61424 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61424 now-has (preposition ((:pair object "of"))))
# (_Concept-Word-Frame61424 now-has (primary-verb-for (|DNA-Replication-Initiation|)))
# (_Concept-Word-Frame61424 now-has (primary-nominalization-for (|DNA-Replication-Initiation|)))
# (_Concept-Word-Frame61424 now-has (synonym-for (|DNA-Replication-Initiation|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60397 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60397 now-has (word ("heat up")))
# (_Concept-Word-Frame60397 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60397 now-has (synonym-for (|Heat|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame60006 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame60006 now-has (word ("absorb")))
# (_Concept-Word-Frame60006 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60006 now-has (grammatical-subject (base)))
# (_Concept-Word-Frame60006 now-has (grammatical-object (object)))
# (_Concept-Word-Frame60006 now-has (preposition NIL))
# (_Concept-Word-Frame60006 now-has (implied-participant NIL))
# (_Concept-Word-Frame60006 now-has (synonym-for (Absorb)))
# (_Concept-Word-Frame60006 now-has (primary-nominalization-for (Absorb)))
# (_Concept-Word-Frame60006 now-has (primary-verb-for (Absorb)))
# (_Concept-Word-Frame60006 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
#
# (_Concept-Word-Frame52476 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame52476 now-has (word ("respond")))
# (_Concept-Word-Frame52476 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame52476 now-has (grammatical-subject (base)))
# (_Concept-Word-Frame52476 now-has (grammatical-object NIL))
# (_Concept-Word-Frame52476 now-has (preposition ((:pair agent "to"))))
# (_Concept-Word-Frame52476 now-has (implied-participant (instrument)))
# (_Concept-Word-Frame52476 now-has (synonym-for (Photoperiodism)))
# (_Concept-Word-Frame52476 now-has (primary-nominalization-for NIL))
# (_Concept-Word-Frame52476 now-has (primary-verb-for (Photoperiodism)))
# (_Concept-Word-Frame52476 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
#
# (_Concept-Word-Frame60117 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame60117 now-has (word ("assemble")))
# (_Concept-Word-Frame60117 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60117 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame60117 now-has (grammatical-object NIL))
# (_Concept-Word-Frame60117 now-has (preposition NIL))
# (_Concept-Word-Frame60117 now-has (implied-participant NIL))
# (_Concept-Word-Frame60117 now-has (synonym-for (Come-Together)))
# (_Concept-Word-Frame60117 now-has (primary-nominalization-for (Come-Together)))
# (_Concept-Word-Frame60117 now-has (primary-verb-for NIL))
# (_Concept-Word-Frame60117 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
#
# (_Concept-Word-Frame60057 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame60057 now-has (word ("lug")))
# (_Concept-Word-Frame60057 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60057 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame60057 now-has (grammatical-object NIL))
# (_Concept-Word-Frame60057 now-has (preposition NIL))
# (_Concept-Word-Frame60057 now-has (implied-participant NIL))
# (_Concept-Word-Frame60057 now-has (synonym-for (Block)))
# (_Concept-Word-Frame60057 now-has (primary-nominalization-for NIL))
# (_Concept-Word-Frame60057 now-has (primary-verb-for NIL))
# (_Concept-Word-Frame60057 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame60275 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60275 now-has (word ("dissipate")))
# (_Concept-Word-Frame60275 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60275 now-has (synonym-for (|Disperse|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61119 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61119 now-has (word ("inherit")))
# (_Concept-Word-Frame61119 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61119 now-has (primary-verb-for (|X-Linked-Inheritance-From-Homozygous-Dominant-Female-Parent|)))
# (_Concept-Word-Frame61119 now-has (primary-nominalization-for (|X-Linked-Inheritance-From-Homozygous-Dominant-Female-Parent|)))
# (_Concept-Word-Frame61119 now-has (synonym-for (|X-Linked-Inheritance-From-Homozygous-Dominant-Female-Parent|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame61288 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame61288 now-has (word ("synthesize")))
# (_Concept-Word-Frame61288 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61288 now-has (grammatical-subject (agent)))
# (_Concept-Word-Frame61288 now-has (grammatical-object (result)))
# (_Concept-Word-Frame61288 now-has (preposition ((:pair raw-material "using"))))
# (_Concept-Word-Frame61288 now-has (implied-participant NIL))
# (_Concept-Word-Frame61288 now-has (synonym-for (Synthesis-of-ATP)))
# (_Concept-Word-Frame61288 now-has (primary-nominalization-for NIL))
# (_Concept-Word-Frame61288 now-has (primary-verb-for NIL))
# (_Concept-Word-Frame61288 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
#
# (_Concept-Word-Frame52714 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame52714 now-has (word ("inhibit")))
# (_Concept-Word-Frame52714 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame52714 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame52714 now-has (grammatical-object NIL))
# (_Concept-Word-Frame52714 now-has (preposition NIL))
# (_Concept-Word-Frame52714 now-has (implied-participant NIL))
# (_Concept-Word-Frame52714 now-has (synonym-for (Feedback-Inhibition-Of-Glycolysis)))
# (_Concept-Word-Frame52714 now-has (primary-nominalization-for (Feedback-Inhibition-Of-Glycolysis)))
# (_Concept-Word-Frame52714 now-has (primary-verb-for (Feedback-Inhibition-Of-Glycolysis)))
# (_Concept-Word-Frame52714 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame60335 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60335 now-has (word ("enlarge")))
# (_Concept-Word-Frame60335 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60335 now-has (synonym-for (|Expand|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60224 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60224 now-has (word ("destroy")))
# (_Concept-Word-Frame60224 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60224 now-has (primary-verb-for (|Destroy|)))
# (_Concept-Word-Frame60224 now-has (primary-nominalization-for (|Destroy|)))
# (_Concept-Word-Frame60224 now-has (synonym-for (|Destroy|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61148 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61148 now-has (word ("anchor")))
# (_Concept-Word-Frame61148 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61148 now-has (primary-verb-for (|Anchoring-of-organelles|)))
# (_Concept-Word-Frame61148 now-has (primary-nominalization-for (|Anchoring-of-organelles|)))
# (_Concept-Word-Frame61148 now-has (synonym-for (|Anchoring-of-organelles|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61008 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61008 now-has (word ("regulate")))
# (_Concept-Word-Frame61008 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61008 now-has (primary-verb-for (|Regulation|)))
# (_Concept-Word-Frame61008 now-has (primary-nominalization-for (|Regulation|)))
# (_Concept-Word-Frame61008 now-has (synonym-for (|Regulation|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame61399 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame61399 now-has (word ("freeze-fracture")))
# (_Concept-Word-Frame61399 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame61399 now-has (primary-verb-for (|Freeze-Fracture-Of-Membrane|)))
# (_Concept-Word-Frame61399 now-has (primary-nominalization-for (|Freeze-Fracture-Of-Membrane|)))
# (_Concept-Word-Frame61399 now-has (synonym-for (|Freeze-Fracture-Of-Membrane|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60364 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60364 now-has (word ("gesture")))
# (_Concept-Word-Frame60364 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60364 now-has (synonym-for (|Gesticulate|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60063 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60063 now-has (word ("gap")))
# (_Concept-Word-Frame60063 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60063 now-has (synonym-for (|Breach|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60123 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60123 now-has (word ("command")))
# (_Concept-Word-Frame60123 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60123 now-has (primary-verb-for (|Command|)))
# (_Concept-Word-Frame60123 now-has (primary-nominalization-for (|Command|)))
# (_Concept-Word-Frame60123 now-has (synonym-for (|Command|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60172 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60172 now-has (word ("shrink")))
# (_Concept-Word-Frame60172 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60172 now-has (synonym-for (|Contract|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60350 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60350 now-has (word ("grub")))
# (_Concept-Word-Frame60350 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60350 now-has (synonym-for (|Feed|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60210 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60210 now-has (word ("lead astray")))
# (_Concept-Word-Frame60210 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60210 now-has (synonym-for (|Deceive|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60181 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60181 now-has (word ("cool down")))
# (_Concept-Word-Frame60181 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60181 now-has (synonym-for (|Cool|)))
# (enable-classification)
#
# (disable-classification)
# (_Concept-Word-Frame60301 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60301 now-has (word ("donate")))
# (_Concept-Word-Frame60301 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60301 now-has (synonym-for (|Donate|)))
# (enable-classification)
#
# (disable-classification)
#
# (_Concept-Word-Frame60090 now-has (instance-of (Concept-Word-Frame)))
# (_Concept-Word-Frame60090 now-has (word ("alter")))
# (_Concept-Word-Frame60090 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60090 now-has (grammatical-subject NIL))
# (_Concept-Word-Frame60090 now-has (grammatical-object NIL))
# (_Concept-Word-Frame60090 now-has (preposition NIL))
# (_Concept-Word-Frame60090 now-has (implied-participant NIL))
# (_Concept-Word-Frame60090 now-has (synonym-for (Change)))
# (_Concept-Word-Frame60090 now-has (primary-nominalization-for NIL))
# (_Concept-Word-Frame60090 now-has (primary-verb-for NIL))
# (_Concept-Word-Frame60090 now-has (primary-noun-for NIL))
# (enable-classification)
#
#
# (disable-classification)
# (_Concept-Word-Frame60241 now-has (instance-of (|Concept-Word-Frame|)))
# (_Concept-Word-Frame60241 now-has (word ("degenerate")))
# (_Concept-Word-Frame60241 now-has (part-of-speech ("v")))
# (_Concept-Word-Frame60241 now-has (synonym-for (|Deterioration|)))
# (enable-classification)

# %% [markdown]
# # Distant Supervision Relation Extraction EDA
#
# This notebook explores approaches for relationship extraction. Formulated as follows:
#
#     Given a set of sentences & key term pairs ->
#     Clas# Distant Supervision
#
# Here, we leverage an existing partial knowledge base (from Inquire in this case) and use to it to train a model to predict further relations between key terms.This is known as distant supervision because we construct labels noisily assuming every pair of terms exhibiting a relationship in the knowledge base will exhibit that relationship for all instances in the text.
#
# Key Limitations:
# - Does not generalize to new relations. Thus this might not generalize well to other textbooks/subject matters, especially if they have additional new relations that would need to be added.
#
# Questions to Investigate:
# - How many training examples are needed to reliably learn a relation?sify any relations present between each pair of terms

# %% [markdown]
# # Read Data

# %% [markdown]
# ## KB Terms

# %%
with open(f"{data_dir}/concepts.txt", "r") as f:
    terms = f.readlines()
terms = set([c.split('|')[1].strip() for c in terms])
print(f"Number of Manually Extracted KB Terms: {len(terms)}")
# Out:
# Number of Manually Extracted KB Terms: 5933

# %% [markdown]
# ## KB Relationships

# %%
def wrangle_relations(triples):
    relations = defaultdict(lambda: [])
    for triple in triples:
        relation = triple[1]
        relations[relation].append(triple)

    relation_words = list(relations.keys())
    relation_counts = [len(relations[rel]) for rel in relation_words]
    relation_table = pd.DataFrame({'relations': relation_words, 'triples_count': relation_counts})
    return relations, relation_table.sort_values('triples_count', ascending=False).reset_index(drop=True)

# %% [markdown]
# #### Structure Relations

# %%
with open(f"{data_dir}/structure.txt", "r") as f:
    structure_triples = f.readlines()
structure_triples = [s.split("|") for s in structure_triples]
structure_triples = set([(s[3].strip(), s[4].strip(), s[-1].strip()) for s in structure_triples])

structure_relations, structure_info = wrangle_relations(structure_triples)
structure_info["relation_type"] = "structure"
print(f"Number of Unique KB Structure Relations: {structure_info.shape[0]}")
structure_info
# Out:
# Number of Unique KB Structure Relations: 44
#                 relations  triples_count relation_type
# 0                has-part           4281     structure
# 1              has-region           1561     structure
# 2               possesses            784     structure
# 3               is-inside            604     structure
# 4                encloses            603     structure
# 5                 element            497     structure
# 6                    size            349     structure
# 7              is-between            267     structure
# 8                   is-at            246     structure
# 9        does-not-enclose            169     structure
# 10             is-outside            166     structure
# 11          atomic-weight            130     structure
# 12                  shape            126     structure
# 13                  abuts            110     structure
# 14  structural-complexity            106     structure
# 15                 volume            102     structure
# 16              is-across             79     structure
# 17               is-along             55     structure
# 18                is-near             54     structure
# 19                 length             52     structure
# 20               is-below             25     structure
# 21               is-above             25     structure
# 22              thickness             19     structure
# 23             wavelength             18     structure
# 24               diameter             18     structure
# 25                has-ion             14     structure
# 26            is-opposite             12     structure
# 27                   mass             11     structure
# 28                 height             11     structure
# 29                  is-on             10     structure
# 30              has-on-it             10     structure
# 31              is-beside              8     structure
# 32     is-oriented-toward              8     structure
# 33                  width              7     structure
# 34                   area              6     structure
# 35              is-facing              6     structure
# 36           surface-area              6     structure
# 37  specific-surface-area              4     structure
# 38                  depth              3     structure
# 39         is-parallel-to              2     structure
# 40                is-over              2     structure
# 41               is-under              2     structure
# 42                  angle              1     structure
# 43              is-behind              1     structure

# %% [markdown]
# #### Process Relations

# %%
with open(f"{data_dir}/process.txt", "r") as f:
    process_triples = f.readlines()
process_triples = [s.split("|") for s in process_triples]
process_triples = set([(s[3].strip(), s[4].strip(), s[-1].strip()) for s in process_triples])

process_relations, process_info = wrangle_relations(process_triples)
process_info["relation_type"] = "process"
print(f"Number of Unique KB Process Relations: {process_info.shape[0]}")
process_info
# Out:
# Number of Unique KB Process Relations: 13
#          relations  triples_count relation_type
# 0           object           2520       process
# 1         subevent           1839       process
# 2             base           1784       process
# 3           result           1678       process
# 4            agent           1488       process
# 5     raw-material            827       process
# 6       next-event            613       process
# 7   first-subevent            330       process
# 8       instrument            255       process
# 9            donor            164       process
# 10       recipient            132       process
# 11     experiencer            100       process
# 12     beneficiary             20       process

# %% [markdown]
# #### Combine Relations

# %%
relations = {**process_relations, **structure_relations}
relation_triples = list(structure_triples) + list(process_triples)
relations_info = pd.concat([structure_info, process_info]).sort_values("triples_count", ascending=False).reset_index(drop=True)
relations_info
# Out:
#                 relations  triples_count relation_type
# 0                has-part           4281     structure
# 1                  object           2520       process
# 2                subevent           1839       process
# 3                    base           1784       process
# 4                  result           1678       process
# 5              has-region           1561     structure
# 6                   agent           1488       process
# 7            raw-material            827       process
# 8               possesses            784     structure
# 9              next-event            613       process
# 10              is-inside            604     structure
# 11               encloses            603     structure
# 12                element            497     structure
# 13                   size            349     structure
# 14         first-subevent            330       process
# 15             is-between            267     structure
# 16             instrument            255       process
# 17                  is-at            246     structure
# 18       does-not-enclose            169     structure
# 19             is-outside            166     structure
# 20                  donor            164       process
# 21              recipient            132       process
# 22          atomic-weight            130     structure
# 23                  shape            126     structure
# 24                  abuts            110     structure
# 25  structural-complexity            106     structure
# 26                 volume            102     structure
# 27            experiencer            100       process
# 28              is-across             79     structure
# 29               is-along             55     structure
# 30                is-near             54     structure
# 31                 length             52     structure
# 32               is-above             25     structure
# 33               is-below             25     structure
# 34            beneficiary             20       process
# 35              thickness             19     structure
# 36             wavelength             18     structure
# 37               diameter             18     structure
# 38                has-ion             14     structure
# 39            is-opposite             12     structure
# 40                 height             11     structure
# 41                   mass             11     structure
# 42                  is-on             10     structure
# 43              has-on-it             10     structure
# 44              is-beside              8     structure
# 45     is-oriented-toward              8     structure
# 46                  width              7     structure
# 47           surface-area              6     structure
# 48                   area              6     structure
# 49              is-facing              6     structure
# 50  specific-surface-area              4     structure
# 51                  depth              3     structure
# 52               is-under              2     structure
# 53                is-over              2     structure
# 54         is-parallel-to              2     structure
# 55              is-behind              1     structure
# 56                  angle              1     structure

# %% [markdown]
# ## Textbook Sentences

# %%
with open(f"{data_dir}/selected_textbook_sentences.txt", "r") as f:
    sentences = f.readlines()
sentences = [" ".join(sent.split("\t")[1:]) for sent in sentences]
print(f"Number of Textbook Sentences: {len(sentences)}")
# Out:
# Number of Textbook Sentences: 18730

# %% [markdown]
# # Tag Terms & Relations

# %% [markdown]
# ## Spacy Preprocessing

# %% [markdown]
# #### Pre-process Terms

# %%
processed_terms = []
for i, term in enumerate(terms):
    if i % 1000 == 0:
        print(f"{i}/{len(terms)} processed")
    processed_terms.append(nlp(term))
write_spacy_docs(processed_terms, f"{data_dir}/processed_terms")
# Out:
# 0/5933 processed
# 1000/5933 processed
# 2000/5933 processed
# 3000/5933 processed
# 4000/5933 processed
# 5000/5933 processed

# %% [markdown]
# #### Pre-process Sentences

# %%
processed_sentences = []
for i, sentence in enumerate(sentences):
    if i % 1000 == 0:
        print(f"{i}/{len(sentences)} processed")
    processed_sentences.append(nlp(sentence))
write_spacy_docs(processed_sentences, f"{data_dir}/processed_sentences")
# Out:
# 0/18730 processed
# 1000/18730 processed
# 2000/18730 processed
# 3000/18730 processed
# 4000/18730 processed
# 5000/18730 processed
# 6000/18730 processed
# 7000/18730 processed
# 8000/18730 processed
# 9000/18730 processed
# 10000/18730 processed
# 11000/18730 processed
# 12000/18730 processed
# 13000/18730 processed
# 14000/18730 processed
# 15000/18730 processed
# 16000/18730 processed
# 17000/18730 processed
# 18000/18730 processed

# %% [markdown]
# #### Pre-process Relations

# %%
processed_relations = []
for i, relation in enumerate(relation_triples):
    if i % 1000 == 0:
        print(f"{i}/{len(relation_triples)} processed")
    processed_triple = (" ".join([tok.lemma_ for tok in nlp(relation[0])]),
                        relation[1],
                        " ".join([tok.lemma_ for tok in nlp(relation[2])]))
    processed_relations.append(processed_triple)
# Out:
# 0/22320 processed
# 1000/22320 processed
# 2000/22320 processed
# 3000/22320 processed
# 4000/22320 processed
# 5000/22320 processed
# 6000/22320 processed
# 7000/22320 processed
# 8000/22320 processed
# 9000/22320 processed
# 10000/22320 processed
# 11000/22320 processed
# 12000/22320 processed
# 13000/22320 processed
# 14000/22320 processed
# 15000/22320 processed
# 16000/22320 processed
# 17000/22320 processed
# 18000/22320 processed
# 19000/22320 processed
# 20000/22320 processed
# 21000/22320 processed
# 22000/22320 processed

# %% [markdown]
# ## Tag Sentences w/ Terms & Relations

# %%
tagged_sentences = []
for i, sentence in enumerate(processed_sentences):
    if i % 1000 == 0:
        print(f"{i}/{len(processed_sentences)} processed")
    tagged_sentences.append(tag_text(sentence, processed_terms, processed_relations, nlp=nlp))

with open(f"{data_dir}/tagged_sentences.json", "w") as f:
    json.dump(tagged_sentences, f)
# Out:
# 0/18730 processed
# 1000/18730 processed
# 2000/18730 processed
# 3000/18730 processed
# 4000/18730 processed
# 5000/18730 processed
# 6000/18730 processed
# 7000/18730 processed
# 8000/18730 processed
# 9000/18730 processed
# 10000/18730 processed
# 11000/18730 processed
# 12000/18730 processed
# 13000/18730 processed
# 14000/18730 processed
# 15000/18730 processed
# 16000/18730 processed
# 17000/18730 processed
# 18000/18730 processed

# %% [markdown]
# # Summary Statistics
#
# - How many negative examples?
# - How many duplicate relations for same pair?
# - How many examples / relation?
# - How many sentences / relation?
# - How many sentences / example / relation?

# %%
with open(f"{data_dir}/tagged_sentences.json", "r") as f:
    json.load(tagged_sentences, f)
relation_counts = defaultdict(lambda: {})
for tagged_sentence in tagged_sentences:
    for relation in tagged_sentence["relations"]:
        word_pair = (relation[0], relation[2])
        if word_pair in relation_counts[relation[1]]:
            relation_counts[relation[1]][word_pair] += 1
        else:
            relation_counts[relation[1]][word_pair] = 1

df = {'relation': [], 'examples': [], 'triples': [], 'examples/triple': []}
for r in dict(relation_counts).keys():
    rc = relation_counts[r]
    df['relation'].append(r)
    df['triples'].append(len(rc.keys()))
    df['examples'].append(sum(rc.values()))
    df['examples/triple'].append(sum(rc.values()) / len(rc.keys()))

df = pd.DataFrame(df)
df
# Out:
#             relation  examples  triples  examples/triple
# 0        no-relation     70288    34153         2.058033
# 1              agent       187       53         3.528302
# 2             object       367       82         4.475610
# 3           has-part      2319      356         6.514045
# 4       raw-material       232       53         4.377358
# 5         is-between       171       48         3.562500
# 6              is-at        98       20         4.900000
# 7         has-region       385       92         4.184783
# 8             result       304       84         3.619048
# 9               base       306       75         4.080000
# 10          encloses       399       70         5.700000
# 11         is-inside       399       70         5.700000
# 12         possesses       233       39         5.974359
# 13        is-outside        58       18         3.222222
# 14  does-not-enclose        58       18         3.222222
# 15           element       139       44         3.159091
# 16             abuts        64       18         3.555556
# 17       experiencer        30        4         7.500000
# 18          subevent        59       19         3.105263
# 19         recipient        39        9         4.333333
# 20     atomic-weight         2        1         2.000000
# 21             shape        95       12         7.916667
# 22           is-near        12        4         3.000000
# 23             is-on        19        5         3.800000
# 24         has-on-it        19        5         3.800000
# 25          is-below        12        3         4.000000
# 26          is-above        12        3         4.000000
# 27              size        14        3         4.666667
# 28            volume        35        5         7.000000
# 29             donor        47       16         2.937500
# 30        wavelength         9        2         4.500000
# 31       is-opposite         2        2         1.000000
# 32        instrument        27       10         2.700000
# 33      surface-area         2        1         2.000000
# 34         is-across        38        6         6.333333
# 35         is-beside         6        2         3.000000
# 36    first-subevent        27        3         9.000000
# 37        next-event        43        8         5.375000
# 38           has-ion         1        1         1.000000
# 39            length         4        2         2.000000
# 40       beneficiary         2        1         2.000000

# %%
import numpy as np
pair_counts = defaultdict(lambda: [])
for r in relation_counts:
    for pair in relation_counts[r]:
        pair_counts[pair].append(r)
pair_counts = [(pair, pair_counts[pair]) for pair in pair_counts if len(pair_counts[pair]) > 1]
print(f"{len(pair_counts)} term pairs have multiple relations")
for pc in pair_counts:
    print(pc)
# Out:
# 96 term pairs have multiple relations
# (('attract', 'water molecule'), ['agent', 'object'])
# (('cohesion', 'water molecule'), ['agent', 'object'])
# (('attract', 'molecule'), ['agent', 'object'])
# (('gene expression', 'gene'), ['agent', 'object', 'base'])
# (('reproduce', 'cell'), ['agent', 'result', 'base'])
# (('diffusion', 'concentration gradient'), ['agent', 'base'])
# (('signal transduction', 'cell'), ['agent', 'base'])
# (('gene expression', 'transcription factor'), ['agent', 'result'])
# (('cellular response', 'cell'), ['agent', 'result', 'base'])
# (('code for', 'gene'), ['agent', 'donor'])
# (('reproduce', 'cancer cell'), ['agent', 'result', 'base'])
# (('metabolism', 'cell'), ['agent', 'object'])
# (('cell communication', 'cell'), ['agent', 'object'])
# (('endocytosis', 'phagocyte'), ['agent', 'base'])
# (('phagocytosis', 'macrophage'), ['agent', 'base'])
# (('cell signal', 'cell'), ['agent', 'base'])
# (('neural signal', 'cell'), ['agent', 'object'])
# (('nutrition', 'animal'), ['agent', 'raw-material', 'beneficiary'])
# (('code for', 'ob gene'), ['agent', 'donor'])
# (('dissolve', 'water'), ['object', 'base'])
# (('cell division', 'cell'), ['object', 'result', 'base'])
# (('gene expression', 'cell'), ['object', 'base'])
# (('dissolve', 'chemical'), ['object', 'base'])
# (('dna replication', 'dna'), ['object', 'result', 'base'])
# (('culture', 'cell'), ['object', 'element'])
# (('fusion', 'vesicle'), ['object', 'base'])
# (('fusion', 'membrane'), ['object', 'base'])
# (('fusion', 'mammalian cell'), ['object', 'base'])
# (('endocytosis', 'vesicle'), ['object', 'instrument'])
# (('cell division', 'egg'), ['object', 'base'])
# (('boiling', 'water'), ['object', 'base'])
# (('oxidation', 'fadh2'), ['object', 'recipient', 'donor'])
# (('muscle contraction', 'muscle'), ['object', 'instrument'])
# (('dna sequence', 'dna piece'), ['object', 'has-part'])
# (('fusion', 'myoblast'), ['object', 'base'])
# (('toe', 'hair'), ['has-part', 'has-on-it'])
# (('eukaryotic cell', 'cytoplasm'), ['has-part', 'is-between', 'encloses'])
# (('eukaryotic cell', 'protein'), ['has-part', 'encloses'])
# (('eukaryotic cell', 'nucleus'), ['has-part', 'encloses'])
# (('nucleus', 'nucleolus'), ['has-part', 'is-between', 'encloses'])
# (('chloroplast', 'stroma'), ['has-part', 'encloses'])
# (('animal cell', 'cytoplasm'), ['has-part', 'encloses'])
# (('peroxisome', 'peroxidase'), ['has-part', 'encloses'])
# (('water molecule', 'chemical'), ['has-part', 'abuts'])
# (('heterozygous', 'allele'), ['has-part', 'element'])
# (('chemical reaction', 'protein'), ['raw-material', 'result'])
# (('chemical reaction', 'chemical'), ['raw-material', 'result'])
# (('reversible reaction', 'chemical'), ['raw-material', 'result'])
# (('condensation reaction', 'molecule'), ['raw-material', 'result'])
# (('hydrolysis', 'chemical'), ['raw-material', 'result'])
# (('phosphorylation', 'protein'), ['raw-material', 'result'])
# (('phosphorylation', 'protein kinase'), ['raw-material', 'result'])
# (('phosphorylation', 'atp'), ['raw-material', 'result'])
# (('hydrolysis', 'disaccharide'), ['raw-material', 'result'])
# (('anabolism', 'molecule'), ['raw-material', 'result'])
# (('catabolism', 'molecule'), ['raw-material', 'result'])
# (('redox reaction', 'molecule'), ['raw-material', 'result'])
# (('metabolic pathway', 'chemical'), ['raw-material', 'result'])
# (('glycolysis', 'glucose'), ['raw-material', 'result'])
# (('redox reaction', 'NADH'), ['raw-material', 'result'])
# (('glycolysis', 'atp'), ['raw-material', 'result'])
# (('phosphorylation', 'adp'), ['raw-material', 'result'])
# (('phosphorylation', 'chemical'), ['raw-material', 'result'])
# (('cascade', 'chemical'), ['raw-material', 'result'])
# (('water', 'surface'), ['is-between', 'is-at', 'has-region'])
# (('molecule', 'region'), ['is-between', 'has-region', 'does-not-enclose'])
# (('nucleus', 'cytoplasm'), ['is-between', 'does-not-enclose'])
# (('cytoplasm', 'nucleus'), ['is-between', 'is-outside'])
# (('er membrane', 'cytosol'), ['is-between', 'encloses', 'does-not-enclose'])
# (('water', 'ground'), ['is-between', 'is-at'])
# (('mitochondrion', 'cytoplasm'), ['is-between', 'is-inside', 'does-not-enclose'])
# (('water molecule', 'surface'), ['is-at', 'is-below'])
# (('membrane protein', 'phospholipid bilayer'), ['is-at', 'is-inside', 'is-outside', 'is-beside'])
# (('transmembrane protein', 'membrane'), ['is-at', 'is-across'])
# (('gene', 'chromosome'), ['is-at', 'is-on'])
# (('mitochondrion', 'mitochondrial matrix'), ['has-region', 'encloses'])
# (('reproduction', 'organism'), ['result', 'base'])
# (('plant development', 'plant'), ['result', 'experiencer'])
# (('oxidation', 'pyruvate'), ['result', 'recipient'])
# (('transcription', 'cell'), ['base', 'experiencer'])
# (('gain', 'atom'), ['base', 'recipient'])
# (('inner membrane', 'mitochondrial matrix'), ['encloses', 'is-outside'])
# (('phospholipid bilayer', 'membrane protein'), ['encloses', 'does-not-enclose', 'is-beside'])
# (('cytoplasm', 'mitochondrion'), ['encloses', 'is-outside'])
# (('layer', 'muscle'), ['encloses', 'element'])
# (('mitochondrial matrix', 'inner membrane'), ['is-inside', 'does-not-enclose'])
# (('cytosol', 'er membrane'), ['is-inside', 'is-outside'])
# (('cellular respiration', 'glycolysis'), ['subevent', 'first-subevent'])
# (('fermentation', 'glycolysis'), ['subevent', 'first-subevent'])
# (('Calvin cycle', 'carbon fixation'), ['subevent', 'first-subevent'])
# (('oxidation', 'molecule'), ['recipient', 'donor'])
# (('oxidation', 'fad'), ['recipient', 'donor'])
# (('reduction', 'molecule'), ['recipient', 'donor'])
# (('oxidation', 'chemical'), ['recipient', 'donor'])
# (('reduction', 'chemical'), ['recipient', 'donor'])
# (('reduction', 'NADH'), ['recipient', 'donor'])

# %%
with open(f"{data_dir}/tagged_sentences.json", "r") as f:
    tagged_sentences = json.load(f)
relation_counts = defaultdict(lambda: {})
for tagged_sentence in tagged_sentences:
    for relation in tagged_sentence["relations"]:
        word_pair = (relation[0], relation[2])
        if word_pair in relation_counts[relation[1]]:
            relation_counts[relation[1]][word_pair] += 1
        else:
            relation_counts[relation[1]][word_pair] = 1

df = {'relation': [], 'examples': [], 'triples': [], 'examples/triple': []}
for r in dict(relation_counts).keys():
    rc = relation_counts[r]
    df['relation'].append(r)
    df['triples'].append(len(rc.keys()))
    df['examples'].append(sum(rc.values()))
    df['examples/triple'].append(sum(rc.values()) / len(rc.keys()))

df = pd.DataFrame(df)
df
# Out:
#             relation  examples  triples  examples/triple
# 0        no-relation     70288    34153         2.058033
# 1              agent       187       53         3.528302
# 2             object       367       82         4.475610
# 3           has-part      2319      356         6.514045
# 4       raw-material       232       53         4.377358
# 5         is-between       171       48         3.562500
# 6              is-at        98       20         4.900000
# 7         has-region       385       92         4.184783
# 8             result       304       84         3.619048
# 9               base       306       75         4.080000
# 10          encloses       399       70         5.700000
# 11         is-inside       399       70         5.700000
# 12         possesses       233       39         5.974359
# 13        is-outside        58       18         3.222222
# 14  does-not-enclose        58       18         3.222222
# 15           element       139       44         3.159091
# 16             abuts        64       18         3.555556
# 17       experiencer        30        4         7.500000
# 18          subevent        59       19         3.105263
# 19         recipient        39        9         4.333333
# 20     atomic-weight         2        1         2.000000
# 21             shape        95       12         7.916667
# 22           is-near        12        4         3.000000
# 23             is-on        19        5         3.800000
# 24         has-on-it        19        5         3.800000
# 25          is-below        12        3         4.000000
# 26          is-above        12        3         4.000000
# 27              size        14        3         4.666667
# 28            volume        35        5         7.000000
# 29             donor        47       16         2.937500
# 30        wavelength         9        2         4.500000
# 31       is-opposite         2        2         1.000000
# 32        instrument        27       10         2.700000
# 33      surface-area         2        1         2.000000
# 34         is-across        38        6         6.333333
# 35         is-beside         6        2         3.000000
# 36    first-subevent        27        3         9.000000
# 37        next-event        43        8         5.375000
# 38           has-ion         1        1         1.000000
# 39            length         4        2         2.000000
# 40       beneficiary         2        1         2.000000
